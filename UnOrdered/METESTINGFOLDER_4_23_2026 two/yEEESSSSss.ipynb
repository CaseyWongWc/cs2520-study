# %% [markdown]
# ### ~

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import builtins

# Store the original input function once, globally, to avoid re-capturing a mocked input
if not hasattr(builtins, '_original_input_backup'):
    builtins._original_input_backup = builtins.input

def set_test_inputs(inputs_list):
    """
    Sets up a mock input function that draws from a list of inputs.
    If inputs_list is None or empty, restores the original input function.
    """
    if inputs_list:
        input_iter = iter(inputs_list)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup

# Define test_inputs, this is where you can change your desired inputs
test_inputs = [1]  # <--- Change this list to provide your test inputs

# Apply the test inputs automatically when this cell is run
set_test_inputs(test_inputs)

# Example of how to revert to normal input:
# set_test_inputs(None)
# Or to set new inputs dynamically:
# set_test_inputs(["new_input_1", "new_input_2"])

#===

def setin(*inputs):
    """
    A helper function to set test inputs for the input() function.
    Usage:
    setin("input1", "input2", "input3")
    This will set up the input() function to return "input1" on the first call,
    "input2" on the second call, and so on.
    To reset to normal input behavior, call setin() with no arguments or None:
    setin()
    """
    if inputs:
        input_iter = iter(inputs)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup

# %%
setin("1","2","3")  # Example usage, you can change the input value as needed
input()
input()
input()
# Out:
# 1
# '1'
# 2
# '2'
# 3
# '3'

# %% [markdown]
# ###
# ---

# %%
# %%writefile my_file.py
print("hello")
# Out:
# Overwriting my_file.py

# %%
# !python my_file.py
# Out:
# hello

# %%
# %%writefile ball.py
x = 10
y = 20
print(x + y)
# Out:
# Writing ball.py

# %%
# !python ball.py
# Out:
# 30

# %%
# how make dir
import os
os.mkdir("my_dir")
os.listdir(".")
os.rmdir("my_dir")
# Out:
# ['ball.py', 'my_file.py', 'my_dir', 'yEEESSSSss.ipynb']

# %%
# !find . -maxdepth 1

'''.
./ball.py
./my_file.py
./yEEESSSSss.ipynb'''
# Out:
# .
# ./ball.py
# ./my_file.py
# ./yEEESSSSss.ipynb
# '.\n./ball.py\n./my_file.py\n./yEEESSSSss.ipynb'

# %%
# !rm ball.py
# !rm my_file.py

# %%
"----------------------"
# Out:
# '----------------------'

# %% [markdown]
# ---

# %%
# %%writefile file_.py
print("This is a test file for running in the notebook.")
# Out:
# Writing file_.py

# %%
# !ls          # list files in current folder (like `dir` on Windows)
# !pwd         # show where this notebook is running
# !python file_.py  # run a Python script
# Out:
# file_.py  yEEESSSSss.ipynb
# /workspaces/cs2520-study/UnOrdered/METESTINGFOLDER_4_23_2026
# This is a test file for running in the notebook.

# %%
# %%writefile my_script.py
print("hello from file")
# Out:
# Writing my_script.py

# %% [markdown]
# ---

# %%
"-----------------------"
# Out:
# '-----------------------'

# %%
def my_function():
    print("This is a test function.")
pass

# %%
# %time my_function()        # time one expression
# Out:
# This is a test function.
# CPU times: user 427 μs, sys: 86 μs, total: 513 μs
# Wall time: 590 μs

# %%
# %%time
# time the whole cell
# Out:
# CPU times: user 4 μs, sys: 0 ns, total: 4 μs
# Wall time: 8.82 μs

# %%
# %run my_script.py
# Out:
# hello from file

# %%
# %history
# Out:
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
# import builtins
#
# # Store the original input function once, globally, to avoid re-capturing a mocked input
# if not hasattr(builtins, '_original_input_backup'):
#     builtins._original_input_backup = builtins.input
#
# def set_test_inputs(inputs_list):
#     """
#     Sets up a mock input function that draws from a list of inputs.
#     If inputs_list is None or empty, restores the original input function.
#     """
#     if inputs_list:
#         input_iter = iter(inputs_list)
#         def mock_input(prompt=""):
#             try:
#                 value = next(input_iter)
#                 print(f"{prompt}{value}")
#                 return value
#             except StopIteration:
#                 raise EOFError("No more inputs for testing")
#         builtins.input = mock_input
#     else:
#         builtins.input = builtins._original_input_backup
#
# # Define test_inputs, this is where you can change your desired inputs
# test_inputs = [1]  # <--- Change this list to provide your test inputs
#
# # Apply the test inputs automatically when this cell is run
# set_test_inputs(test_inputs)
#
# # Example of how to revert to normal input:
# # set_test_inputs(None)
# # Or to set new inputs dynamically:
# # set_test_inputs(["new_input_1", "new_input_2"])
#
# #===
#
# def setin(*inputs):
#     """
#     A helper function to set test inputs for the input() function.
#     Usage:
#     setin("input1", "input2", "input3")
#     This will set up the input() function to return "input1" on the first call,
#     "input2" on the second call, and so on.
#     To reset to normal input behavior, call setin() with no arguments or None:
#     setin()
#     """
#     if inputs:
#         input_iter = iter(inputs)
#         def mock_input(prompt=""):
#             try:
#                 value = next(input_iter)
#                 print(f"{prompt}{value}")
#                 return value
#             except StopIteration:
#                 raise EOFError("No more inputs for testing")
#         builtins.input = mock_input
#     else:
#         builtins.input = builtins._original_input_backup
# setin("1","2","3")  # Example usage, you can change the input value as needed
# input()
# input()
# input()
# %%writefile my_file.py
# print("hello")
# !python my_file.py
# %%writefile ball.py
# x = 10
# y = 20
# print(x + y)
# !python ball.py
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# #os.rmdir("my_dir")
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# # how make dir
# import os
# #os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# ########
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# !find . -maxdepth 1
# !find . -maxdepth 1
#
# '''.
# ./ball.py
# ./my_file.py
# ./yEEESSSSss.ipynb'''
# !rm ball.py
# !rm my_file.py
# %%writefile my_file.py
# print("hello")
# !python my_file.py
# !ls          # list files in current folder (like `dir` on Windows)
# !pwd         # show where this notebook is running
# !python file.py  # run a Python script
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
# import builtins
#
# # Store the original input function once, globally, to avoid re-capturing a mocked input
# if not hasattr(builtins, '_original_input_backup'):
#     builtins._original_input_backup = builtins.input
#
# def set_test_inputs(inputs_list):
#     """
#     Sets up a mock input function that draws from a list of inputs.
#     If inputs_list is None or empty, restores the original input function.
#     """
#     if inputs_list:
#         input_iter = iter(inputs_list)
#         def mock_input(prompt=""):
#             try:
#                 value = next(input_iter)
#                 print(f"{prompt}{value}")
#                 return value
#             except StopIteration:
#                 raise EOFError("No more inputs for testing")
#         builtins.input = mock_input
#     else:
#         builtins.input = builtins._original_input_backup
#
# # Define test_inputs, this is where you can change your desired inputs
# test_inputs = [1]  # <--- Change this list to provide your test inputs
#
# # Apply the test inputs automatically when this cell is run
# set_test_inputs(test_inputs)
#
# # Example of how to revert to normal input:
# # set_test_inputs(None)
# # Or to set new inputs dynamically:
# # set_test_inputs(["new_input_1", "new_input_2"])
#
# #===
#
# def setin(*inputs):
#     """
#     A helper function to set test inputs for the input() function.
#     Usage:
#     setin("input1", "input2", "input3")
#     This will set up the input() function to return "input1" on the first call,
#     "input2" on the second call, and so on.
#     To reset to normal input behavior, call setin() with no arguments or None:
#     setin()
#     """
#     if inputs:
#         input_iter = iter(inputs)
#         def mock_input(prompt=""):
#             try:
#                 value = next(input_iter)
#                 print(f"{prompt}{value}")
#                 return value
#             except StopIteration:
#                 raise EOFError("No more inputs for testing")
#         builtins.input = mock_input
#     else:
#         builtins.input = builtins._original_input_backup
# setin("1","2","3")  # Example usage, you can change the input value as needed
# input()
# input()
# input()
# %%writefile my_file.py
# print("hello")
# !python my_file.py
# %%writefile ball.py
# x = 10
# y = 20
# print(x + y)
# !python ball.py
# # how make dir
# import os
# os.mkdir("my_dir")
# os.listdir(".")
# os.rmdir("my_dir")
# !find . -maxdepth 1
#
# '''.
# ./ball.py
# ./my_file.py
# ./yEEESSSSss.ipynb'''
# !rm ball.py
# !rm my_file.py
# "----------------------"
# !ls          # list files in current folder (like `dir` on Windows)
# !pwd         # show where this notebook is running
# !python file.py  # run a Python script
# %%writefile file_.py
# %%writefile file_.py
# print("This is a test file for running in the notebook.")
# !ls          # list files in current folder (like `dir` on Windows)
# !pwd         # show where this notebook is running
# !python file_.py  # run a Python script
# %%writefile my_script.py
# print("hello from file")
# %time my_function()        # time one expression
# %%time
# # time the whole cell
# do_slow_stuff()
# %%time
# # time the whole cell
# do_slow_stuff()
# "-----------------------"
# def my_function():
#     print("This is a test function.")
# pass
# %time my_function()        # time one expression
# %%time
# # time the whole cell
# do_slow_stuff()
# %%time
# # time the whole cell
# do_slow_stuff()
# %%time
# # time the whole cell
# #do_slow_stuff()
# %%time
# # time the whole cell
# %time my_function()        # time one expression
# %run my_script.py
# %history
# %history

# %%
# %pwd      # print current directory
# %cd ..    # change directory
# Out:
# '/workspaces/cs2520-study/UnOrdered/METESTINGFOLDER_4_23_2026'
# [Errno 2] No such file or directory: '.. # change directory'
# /workspaces/cs2520-study/UnOrdered/METESTINGFOLDER_4_23_2026

# %%
# %rm my_script.py
# %rm file_.py
# %ls
# Out:
# yEEESSSSss.ipynb

# %% [markdown]
# ---

# %%
# ==== Notebook cheat sheet ====

## 1) Pure Python (portable)
# import os
# os.listdir(".")
# os.mkdir("new_folder")
# os.remove("file.py")
# os.rmdir("empty_folder")   # folder must be empty

## 2) Shell / terminal style
# !ls
# !python file.py
# !rm file.py
# !rm -r foldername

## 3) Cell magics
# %%writefile file.py
# print("hello from notebook")
#
# %time some_function()
# %%time
# long_running_code()

# %%
# %%bash
# echo "listing files"
# ls
# ls -l
# ls -alF
# Out:
# listing files
# yEEESSSSss.ipynb
# total 24
# -rw-rw-rw- 1 codespace codespace 23230 Apr 24 02:18 yEEESSSSss.ipynb
# total 32
# drwxrwxrwx+ 2 codespace codespace  4096 Apr 24 02:17 ./
# drwxrwxrwx+ 3 codespace codespace  4096 Apr 24 01:51 ../
# -rw-rw-rw-  1 codespace codespace 23230 Apr 24 02:18 yEEESSSSss.ipynb
