# %% [markdown]
# ### ~

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import builtins

# Store the original input function once, globally, to avoid re-capturing a mocked input
if not hasattr(builtins, '_original_input_backup'):
    builtins._original_input_backup = builtins.input

def set_test_inputs(inputs_list):
    """
    Sets up a mock input function that draws from a list of inputs.
    If inputs_list is None or empty, restores the original input function.
    """
    if inputs_list:
        input_iter = iter(inputs_list)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup

# Define test_inputs, this is where you can change your desired inputs
test_inputs = [1]  # <--- Change this list to provide your test inputs

# Apply the test inputs automatically when this cell is run
set_test_inputs(test_inputs)

# Example of how to revert to normal input:
# set_test_inputs(None)
# Or to set new inputs dynamically:
# set_test_inputs(["new_input_1", "new_input_2"])

#===

def setin(*inputs):
    """
    A helper function to set test inputs for the input() function.
    Usage:
    setin("input1", "input2", "input3")
    This will set up the input() function to return "input1" on the first call,
    "input2" on the second call, and so on.
    To reset to normal input behavior, call setin() with no arguments or None:
    setin()
    """
    if inputs:
        input_iter = iter(inputs)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup

# %%
setin("1","2","3")  # Example usage, you can change the input value as needed
input()
input()
input()
# Out:
# 1
# '1'
# 2
# '2'
# 3
# '3'

# %% [markdown]
# ###
# ---

# %%
# %%bash
# mkdir -p demo
# echo "This is a demo file." > demo/demo.txt
# cat demo/demo.txt
# Out:
# This is a demo file.

# %%
# %%writefile test_input.py
def setin(*inputs):
    """
    A helper function to set test inputs for the input() function.
    Usage:
    setin("input1", "input2", "input3")
    This will set up the input() function to return "input1" on the first call,
    "input2" on the second call, and so on.
    To reset to normal input behavior, call setin() with no arguments or None:
    setin()
    """
    import builtins
    if not hasattr(builtins, '_original_input_backup'):
        builtins._original_input_backup = builtins.input

    if inputs:
        input_iter = iter(inputs)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup
# Out:
# Overwriting test_input.py

# %%
# how do i display the contents of a file in a jupyter notebook?
# You can use the built-in `open()` function to read the contents of a file and display it in a Jupyter notebook. Here's an example of how to do this:
# To display the contents of a file in a Jupyter notebook, you can use the following code:
'''
with open('demo/demo.txt', 'r') as file:
    contents = file.read()
    print(contents)

'''
with open('demo/demo.txt', 'r') as file:
    contents = file.read()
    print(contents)

def showme(path):
    with open(path, 'r') as file:
        contents = file.read()
        print(contents)
# Out:
# "\nwith open('demo/demo.txt', 'r') as file:\n    contents = file.read()\n    print(contents)\n\n"
# This is a demo file.

# %%
# %%writefile showme.py
def showme(path):
    with open(path, 'r') as file:
        contents = file.read()
        print(contents)
# Out:
# Overwriting showme.py

# %%
# %%writefile demo/person.py
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        return f"Hello, my name is {self.name} and I am {self.age} years old."
# Out:
# Overwriting demo/person.py

# %%
from test_input import setin
setin("Alice", "30")
from demo.person import Person
person = Person(input("Enter name: "), input("Enter age: "))
print(person.greet())
# Out:
# Enter name: Alice
# Enter age: 30
# Hello, my name is Alice and I am 30 years old.

# %%
# %%writefile demo/demo.py
#from test_input import setin
#setin("Alice", "30")
from demo.person import Person
person = Person(input("Enter name: "), input("Enter age: "))
print(person.greet())
# Out:
# Overwriting demo/demo.py

# %%
from test_input import setin

# %%
setin("Alice", "30")
# %run demo/demo.py
# Out:
# Enter name: Alice
# Enter age: 30
# Hello, my name is Alice and I am 30 years old.

# %% [markdown]
# ###

# %%
# !rm -rf demo
!

# %%
'''!mkdir -p demo'''
# Out:
# '!mkdir -p demo'

# %%
'''%%writefile demo/person.py
class Person:
    def __init__(self, name="Unknown", age=1):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def set_name(self, new_name):
        self.__name = new_name

p1 = Person("Mickey", 100)
print(p1.get_name())
p1.set_name("Mouse")
print(p1.get_name())'''
# Out:
# '%%writefile demo/person.py\nclass Person:\n    def __init__(self, name="Unknown", age=1):\n        self.__name = name\n        self.__age = age\n\n    def get_name(self):\n        return self.__name\n\n    def set_name(self, new_name):\n        self.__name = new_name\n\np1 = Person("Mickey", 100)\nprint(p1.get_name())\np1.set_name("Mouse")\nprint(p1.get_name())'

# %%
# !rm -rf demo
!

# %%
# %%writefile showme.py
def showme(path):
    with open(path, 'r') as file:
        contents = file.read()
        print(contents)
# Out:
# Overwriting showme.py

# %%
# %%writefile test_input.py
def setin(*inputs):
    """
    A helper function to set test inputs for the input() function.
    Usage:
    setin("input1", "input2", "input3")
    This will set up the input() function to return "input1" on the first call,
    "input2" on the second call, and so on.
    To reset to normal input behavior, call setin() with no arguments or None:
    setin()
    """
    import builtins
    if not hasattr(builtins, '_original_input_backup'):
        builtins._original_input_backup = builtins.input

    if inputs:
        input_iter = iter(inputs)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup
# Out:
# Overwriting test_input.py

# %%
from test_input import setin
from showme import showme

# %%
# %%bash
# rm -rf demo
# mkdir -p demo
#
# cat > demo/person.py << 'EOF_'
# class Person:
#     def __init__(self, name="Unknown", age=1):
#         self.__name = name
#         self.__age = age
#
#     def get_name(self):
#         return self.__name
#
#     def set_name(self, new_name):
#         self.__name = new_name
# EOF_
# cat > demo/demo.py << 'EOF_'
# from demo.person import Person
#
# person = Person(input("Enter name: "), input("Enter age: "))
# print(person.greet())
# EOF_

# %%
setin("Alice", "30")
# %run demo/demo.py
# Out:
# Enter name: Alice
# Enter age: 30
# Hello, my name is Alice and I am 30 years old.

# %% [markdown]
# ---

# %%
!

# %%
# %%bash
# rm -rf demo
# mkdir -p demo

# %%
# %%writefile module_a.py
def echo(name):
    print(f"Echo: {name}")
# Out:
# Overwriting module_a.py

# %%
# %%writefile module_b.py
import module_a
module_a.echo("Go Broncooo!")
# Out:
# Writing module_b.py

# %%
#how move module_a.py to demo folder?
# You can move the module_a.py file to the demo folder using the following command in a bash cell:
# mv module_a.py demo/

#!mv module_a.py demo/

# %%
# %%bash
# mv module_a.py demo/
# mv module_b.py demo/
# ls demo
# Out:
# mv: cannot stat 'module_a.py': No such file or directory
# mv: cannot stat 'module_b.py': No such file or directory
# module_a.py
# module_b.py

# %%
showme("demo/module_a.py")
showme("demo/module_b.py")
# Out:
# def echo(name):
#     print(f"Echo: {name}")
#
# import module_a
# module_a.echo("Go Broncooo!")

# %%
# %run demo/module_b.py
# Out:
# Echo: Go Broncooo!

# %%
#i cant make up my mind on how to organize my files, should i put all my modules in a folder called demo? or should i just keep them in the root directory? what are the pros and cons of each approach? also should i use proper fileio?
# --- IGNORE ---
#Pros of organizing modules in a folder (e.g., demo):
#1. Better organization: Grouping related modules together in a folder can make it easier tonavigate and manage your project, especially as it grows in size.
#2. Avoids clutter: Keeping modules in a separate folder can help prevent the root directory from becoming cluttered with too many files, making it easier to find specific files.
#3. Namespace management: Using folders can help with namespace management, especially if you have many modules. It can help prevent naming conflicts and make it clear which modules are related to each other.
#4. Easier to share: If you want to share your code with others, having a well-organized folder structure can make it easier for others to understand and use your code.
#5. Scalability: As your project grows, having a structured folder organization can make it easier to manage and maintain your codebase.
#6. Separation of concerns: Organizing modules into folders can help separate different components or functionalities of your project, making it clearer and more modular.
# --- IGNORE ---

# %%
# %%bash
# rm -rf demo
# mkdir -p demo
# #go inside
# cd demo
#
# cat > temp.py << 'EOF_'
# print(1+1)
# EOF_
# python temp.py
# Out:
# 2

# %%
# %run demo/temp.py
# Out:
# 2

# %%
# %%bash
# rm -rf demo
# mkdir -p demo

# %%
#can we use %%writefile to make demo/temp.py and then run it? im getting errors when i try to do that, it says "No module named 'demo.temp'"
# Yes, you can use %%writefile to create demo/temp.py and then run it. However, when you run it using %run demo/temp.py, it may not work because the current working directory of the Jupyter notebook might not be set to the parent directory of demo. To fix
# this, you can either change the working directory to the parent directory of demo before running the script, or you can run the script using its relative path from the current working directory. For example:
# %run demo/temp.py

# %%
# %%writefile demo/calc.py
"""4/21 ~1:25-1:29 PM - Calculator class."""


class Calculator:
    def add(self, numbers):
        return sum(numbers)

    def subtract(self, a, b):
        return a - b


if __name__ == "__main__":
    c = Calculator()
    print(c.add([1, 2]))
    print(c.add([1, 2, 3, 4]))
    print(c.subtract(10, 4))
# Out:
# Writing demo/temp.py
