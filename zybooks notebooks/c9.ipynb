# %% [markdown]
# ### ~

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import builtins

# Store the original input function once, globally, to avoid re-capturing a mocked input
if not hasattr(builtins, '_original_input_backup'):
    builtins._original_input_backup = builtins.input

def set_test_inputs(inputs_list):
    """
    Sets up a mock input function that draws from a list of inputs.
    If inputs_list is None or empty, restores the original input function.
    """
    if inputs_list:
        input_iter = iter(inputs_list)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup

# Define test_inputs, this is where you can change your desired inputs
test_inputs = [1]  # <--- Change this list to provide your test inputs

# Apply the test inputs automatically when this cell is run
set_test_inputs(test_inputs)

# Example of how to revert to normal input:
# set_test_inputs(None)
# Or to set new inputs dynamically:
# set_test_inputs(["new_input_1", "new_input_2"])

#===

def setin(*inputs):
    """
    A helper function to set test inputs for the input() function.
    Usage:
    setin("input1", "input2", "input3")
    This will set up the input() function to return "input1" on the first call,
    "input2" on the second call, and so on.
    To reset to normal input behavior, call setin() with no arguments or None:
    setin()
    """
    if inputs:
        input_iter = iter(inputs)
        def mock_input(prompt=""):
            try:
                value = next(input_iter)
                print(f"{prompt}{value}")
                return value
            except StopIteration:
                raise EOFError("No more inputs for testing")
        builtins.input = mock_input
    else:
        builtins.input = builtins._original_input_backup

# %%
setin("1","2","3")  # Example usage, you can change the input value as needed
input()
input()
input()
# Out:
# 1
# '1'
# 2
# '2'
# 3
# '3'

# %% [markdown]
# ###
# ---

# %% [markdown]
# # C9

# %%
__= "-" * 20

# %% [markdown]
# ## 9.1 Classes: Introduction
# https://fluffy-telegram-jj566wr4r565cp796.github.dev/

# %%
ohokay='''9.1 Classes: Introduction
Grouping related items into objects
The physical world is made up of material items such as wood, metal, plastic, fabric, etc. To keep the world understandable, people think in terms of higher-level objects, like chairs, tables, and TVs. Those objects are groupings of the lower-level items.

Likewise, a program is made up of lower-level items like variables and functions. To keep programs understandable, programmers often deal with higher-level groupings of those items, known as objects. In programming, an object is a grouping of data (variables) and operations that can be performed on that data (functions or methods).

participation activity
9.1.1: The world is viewed not as materials, but rather as objects.


1

2

3

Static Figure: An image of a seating area, with chairs and couches. A list of materials: Green fabric, Wood, Red fabric, Wood, Wood, Metal bar. A box representing a Chair object has: Sit, Green fabric, Wood. A box representing a Couch object has: Sit, Lie Down, Red fabric, Wood A box representing a Drawer object has: Put stuff in, Take stuff out, Wood, Metal bar Step 1: The world consists of items such as wood, metal, fabric, etc. A list of materials displayed in an image of a seating area reads: green fabric, wood, red fabric, wood, wood, metal bar. Step 2: But people think in terms of higher-level objects, like chairs, couches, and drawers. The material list is separated into object categories. The chair category includes the materials green fabric and wood. The couch category includes red fabric and wood. The drawer category includes wood and metal bar. Step 3: In fact, people think mostly of the operations that can be done with the objects. For a drawer, operations include putting stuff in and taking stuff out. Operations are added to each of the categories. Sit is added to the chair category. Sit and lie down are added to the couch category. Put stuff in and take stuff out are added to the drawer category.

Captions
The world consists of items such as wood, metal, fabric, etc.
But people think in terms of higher-level objects, like chairs, couches, and drawers.
In fact, people think mostly of the operations that can be done with the objects. For a drawer, operations include putting stuff in and taking stuff out.
Playing step 3: In fact, people think mostly of the operations that can be done with the objects. For a drawer, operations include putting stuff in and taking stuff out. Step finished playing

Feedback?
participation activity
9.1.2: Programs are not viewed as variables and functions/methods but as objects.


1

2

Programmers think mostly of the operations that can be done with the object, such as giving a hotel or restaurant a name or adding a review. 
RestaurantNamePhoneReviewsAdd reviewHotelNamePhoneReviewsCuisinesAmenitiesSet name/phone numberPrint allSet name/phone numberAdd amenityAdd reviewPrint allNamePhoneReviewsNamePhoneReviewsCuisinesAmenitiesAdd cuisine
Static Figure: A list of properties is displayed: Name, Phone, Cuisines, Reviews, Name, Phone, Amenities, Reviews A box representing a Restaurant object has the text: Restaurant Set name/phone number Add cuisine Add review Print all Name, Phone, Cuisines, Reviews A box representing a Hotel object has the text: Hotel Set name/phone number Add amenity Add review Print all Name, Phone, Amenities, Reviews Step 1: A program consists of variables and functions or methods. But programmers may prefer to think of higher-level objects such as restaurants and hotels. A list of properties is displayed: Name, Phone, Cuisines, Reviews, Name, Phone, Amenities, Reviews A box representing a Restaurant object has the text: Restaurant Name, Phone, Cuisines, Reviews A box representing a Hotel object has the text: Hotel Name, Phone, Amenities, Reviews Step 2: Programmers think mostly of the operations that can be done with the object, such as giving a hotel or restaurant a name or adding a review. The box representing a Restaurant object now has the text: Restaurant Set name/phone number Add cuisine Add review Print all Name, Phone, Cuisines, Reviews The box representing a Hotel object now has the text: Hotel Set name/phone number Add amenity Add review Print all Name, Phone, Amenities, Reviews

Captions
A program consists of variables and functions or methods. But programmers may prefer to think of higher-level objects such as restaurants and hotels.
Programmers think mostly of the operations that can be done with the object, such as giving a hotel or restaurant a name or adding a review.
Playing step 2: Programmers think mostly of the operations that can be done with the object, such as giving a hotel or restaurant a name or adding a review. Step finished playing

Feedback?
Creating a program as a collection of objects can lead to a more understandable, manageable, and properly executing program.'''
ohokay
# Out:
# '9.1 Classes: Introduction\nGrouping related items into objects\nThe physical world is made up of material items such as wood, metal, plastic, fabric, etc. To keep the world understandable, people think in terms of higher-level objects, like chairs, tables, and TVs. Those objects are groupings of the lower-level items.\n\nLikewise, a program is made up of lower-level items like variables and functions. To keep programs understandable, programmers often deal with higher-level groupings of those items, known as objects. In programming, an object is a grouping of data (variables) and operations that can be performed on that data (functions or methods).\n\nparticipation activity\n9.1.1: The world is viewed not as materials, but rather as objects.\n\n\n1\n\n2\n\n3\n\nStatic Figure: An image of a seating area, with chairs and couches. A list of materials: Green fabric, Wood, Red fabric, Wood, Wood, Metal bar. A box representing a Chair object has: Sit, Green fabric, Wood. A box representin
# ...

# %%
'''participation activity

## 

9.1.3: Objects.

Some of the variables and functions for a used-car inventory program are grouped into an object type named CarOnLot. Select True if the item should become part of the CarOnLot object type, and select False otherwise.

1)

car\_sticker\_price

True

False

2)

todays\_temperature

True

False

3)

days\_on\_lot

True

False

4)

orig\_purchase\_price

True

False

5)

num\_salespeople

True

False

6)

increment\_car\_days\_on\_lot()

True

False

7)

decrease\_sticker\_price()

True

False

8)

determine\_top\_salesman()

True

False

Feedback?

'''
setin("True","False","True","True","False","True","True","False")  # Example usage, you can change the input value as needed
def participation_activity_9_1_3():
    questions = [
        ("car_sticker_price", True),
        ("todays_temperature", False),
        ("days_on_lot", True),
        ("orig_purchase_price", True),
        ("num_salespeople", False),
        ("increment_car_days_on_lot()", True),
        ("decrease_sticker_price()", True),
        ("determine_top_salesman()", False)
    ]
    
    for i, (item, expected) in enumerate(questions, 1):
        answer = input(f"{i}) {item}\nTrue\nFalse\nYour answer: ")
        if answer.strip().lower() == str(expected).lower():
            print("Correct!")
        else:
            print(f"Incorrect. The correct answer is {'True' if expected else 'False'}.")   
participation_activity_9_1_3()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipykernel_21732/2963662942.py:1: SyntaxWarning: invalid escape sequence '\_'
#   '''participation activity
# 'participation activity\n\n## \n\n9.1.3: Objects.\n\nSome of the variables and functions for a used-car inventory program are grouped into an object type named CarOnLot. Select True if the item should become part of the CarOnLot object type, and select False otherwise.\n\n1)\n\ncar\\_sticker\\_price\n\nTrue\n\nFalse\n\n2)\n\ntodays\\_temperature\n\nTrue\n\nFalse\n\n3)\n\ndays\\_on\\_lot\n\nTrue\n\nFalse\n\n4)\n\norig\\_purchase\\_price\n\nTrue\n\nFalse\n\n5)\n\nnum\\_salespeople\n\nTrue\n\nFalse\n\n6)\n\nincrement\\_car\\_days\\_on\\_lot()\n\nTrue\n\nFalse\n\n7)\n\ndecrease\\_sticker\\_price()\n\nTrue\n\nFalse\n\n8)\n\ndetermine\\_top\\_salesman()\n\nTrue\n\nFalse\n\nFeedback?\n\n'
# 1) car_sticker_price
# True
# False
# Your answer: True
# Correct!
# ...

# %%
ohokay='''Abstraction / Information hiding
Abstraction occurs when a user interacts with an object at a high level, allowing lower-level internal details to remain hidden (aka information hiding or encapsulation). Ex: An oven supports an abstraction of a food compartment and a knob to control heat. An oven's user does not need to interact with the internal parts of an oven.

Objects support abstraction by hiding entire groups of functions and variables and exposing only certain functions to a user.

An abstract data type (ADT) is a data type whose creation and update are constrained to specific well-defined operations. A class can be used to implement an ADT.

participation activity
9.1.4: Objects strongly support abstraction or information hiding.


1

2

3

Similarly, an object has operations that a user applies. The object's internal data, and possibly other operations, are hidden from the user. 
Don't do thisRestaurantSet main infoAdd reviewNamePhoneReviews...Hidden
Step 1 shows an image of an oven. Step 2 shows an image of a person reaching into the oven to adjust the heat with text underneath saying, "Don't do this." Step 3 shows an abstraction of a restaurant object: A box with the word Restaurant at the top, the phrases "Set main info" and "Add review" indented on the next 2 lines with an ellipses; and in the bottom, areas for the Name, Phone number, and Reviews for the restaurant object.

Captions
Abstraction simplifies our world. An oven is viewed as having a compartment for food and a knob is turned to heat the food.
People need not be concerned with an oven's internal workings. Ex: People don't reach inside to adjust the flame.
Similarly, an object has operations that a user applies. The object's internal data, and possibly other operations, are hidden from the user.
Playing step 3: Similarly, an object has operations that a user applies. The object's internal data, and possibly other operations, are hidden from the user. Step finished playing

'''

# %%
'''participation activity
9.1.5: Abstraction.
1)
A car presents an abstraction to a user, including a steering wheel, gas pedal, and brake.
Correct
A car's internal workings are complex, but the user need not know those details. Instead, the user focuses on just a few operations: steering, accelerating, and braking.
2)
A refrigerator presents an abstraction to a user, including refrigerant gas, a compressor, and a fan.
Correct
Those items relate to the inner workings of a refrigerator. Instead, the abstraction presented to a user involves operations like putting things in, taking things out, and adjusting the temperature.
3)
A software object is created for a soccer team. A reasonable abstraction allows setting the team's name, adding or deleting players, and printing a roster.
Correct
The internal variables of such an object are not relevant to the user. Rather, the object's user just focuses on the operations of setting the name, adding players or deleting players, and printing a team roster.
4)
A software object is created for a university class. A reasonable abstraction allows viewing and modifying variables for the teacher's name, and variables implementing a list of every student's name.
Correct
Variables relate to the inner workings of a university class object. A more reasonable abstraction would be operations for setting a teacher's name, adding or deleting students, and printing a class roster.'''
# Out:
# "participation activity\n9.1.5: Abstraction.\n1)\nA car presents an abstraction to a user, including a steering wheel, gas pedal, and brake.\nCorrect\nA car's internal workings are complex, but the user need not know those details. Instead, the user focuses on just a few operations: steering, accelerating, and braking.\n2)\nA refrigerator presents an abstraction to a user, including refrigerant gas, a compressor, and a fan.\nCorrect\nThose items relate to the inner workings of a refrigerator. Instead, the abstraction presented to a user involves operations like putting things in, taking things out, and adjusting the temperature.\n3)\nA software object is created for a soccer team. A reasonable abstraction allows setting the team's name, adding or deleting players, and printing a roster.\nCorrect\nThe internal variables of such an object are not relevant to the user. Rather, the object's user just focuses on the operations of setting the name, adding players or deleting players, and p
# ...

# %%
ohokay='''Python built-in objects
Python automatically creates built-in objects for a programmer to use and include the basic data types like integers and strings.

A programmer always interacts with built-in objects when writing Python code. Ex: A string object created with mystr = "Hello!". The value of the string "Hello!" is one part of the object, as are functions to operate on that string like str.isdigit() and str.lower().

participation activity
9.1.6: Built in objects.


1

2

Defining a new integer i1 creates a new built-in int object. The implementation of the int object abstracts many details that a programmer doesn't need.
s1 = "Hello!!"

i1 = 130
s1
value:    "Hello!!"isdigit() isascii() islower()
startswith() isupper() split()
format() swapcase() ...
i1
value:    130abs() float() complex()
pow() ...
Defining a new string or integer variable uses the built-in string and integer data-type objects. These objects group together the value of the variable along with useful functions for operating on that variable.

Captions
Defining a new string s1 creates a new built-in str object. The str object groups together the string value "Hello!!" along with useful functions.
Defining a new integer i1 creates a new built-in int object. The implementation of the int object abstracts many details that a programmer doesn't need.'''

# %%
'''participation activity
9.1.7: Built-in objects.
1)
The Python programming language provides a built-in object for strings.
Correct
Python provides basic data types for a programmer to use, like integers, strings, decimals, lists, dictionaries, etc.
2)
Built-in objects often include useful functions.
Correct
An object includes functions that can manipulate or provide additional information about object values.
3)
The built-in string object includes every function a programmer could ever find useful for dealing with strings.
Correct
While many useful functions are indeed provided, a programmer often must write their own functions to complete a specific task.
'''
# Out:
# 'participation activity\n9.1.7: Built-in objects.\n1)\nThe Python programming language provides a built-in object for strings.\nCorrect\nPython provides basic data types for a programmer to use, like integers, strings, decimals, lists, dictionaries, etc.\n2)\nBuilt-in objects often include useful functions.\nCorrect\nAn object includes functions that can manipulate or provide additional information about object values.\n3)\nThe built-in string object includes every function a programmer could ever find useful for dealing with strings.\nCorrect\nWhile many useful functions are indeed provided, a programmer often must write their own functions to complete a specific task.\n'

# %% [markdown]
# ## 9.2 Classes: Grouping data
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/2

# %%
ohokay='''9.2 Classes: Grouping data
Multiple variables are frequently closely related and should be treated as one variable with multiple parts. For example, two variables called hours and minutes might be grouped together in a single variable called time. The class keyword can be used to create a user-defined type of object containing groups of related variables and functions.

Construct 9.2.1: The class keyword.
class ClassName:
    # Statement-1
    # Statement-2
    # ...
    # Statement-N

Feedback?
A class defines a new type that can group data and functions to form an object. The object maintains a set of attributes that determines the data and behavior of the class. For example, the following code defines a new class containing two attributes, hours and minutes, whose values are initially 0:

Figure 9.2.1: Defining a new class object with two data attributes.
class Time:
    """ A class that represents a time of day """
    def __init__(self):
        self.hours = 0
        self.minutes = 0

Feedback?
The programmer can then use instantiation to define a new Time class variable and access that variable's attributes. An instantiation operation is performed by "calling" the class, using parentheses like a function call as in my_time = Time(). An instantiation operation creates an instance, which is an individual object of the given class. An instantiation operation automatically calls the __init__ method defined in the class definition. A method is a function defined within a class. The __init__ method, commonly known as a constructor, is responsible for setting up the initial state of the new instance. In the example above, the __init__ method creates two new attributes, hours and minutes, and assigns default values of 0.

The __init__ method has a single parameter, "self", that automatically references the instance being created. A programmer writes an expression such as self.hours = 0 within the __init__ method to create a new attribute, hours.

Figure 9.2.2: Using instantiation to create a variable using the Time class.
class Time:
    """ A class that represents a time of day """
    def __init__(self):
        self.hours = 0
        self.minutes = 0


my_time = Time()
my_time.hours = 7
my_time.minutes = 15

print(f"{my_time.hours} hours", end=" ")
print(f"and {my_time.minutes} minutes")
7 hours and 15 minutes

Feedback?
Attributes can be accessed using the attribute reference operator "." (sometimes called the member operator or dot notation).

participation activity
9.2.1: Using classes and attribute reference.


1

2

class Time:
    def __init__(self):      
        self.hours = 0                  
        self.minutes = 0                   

time1 = Time()             
time1.hours = 7              
time1.minutes = 15
Static figure: Begin Python code: class Time: def __init__(self): self.hours = 0 self.minutes = 0 time1 = Time() time1.hours = 7 time1.minutes = 15 End Python code. Step 1: Time() calls the __init__ method of the Time class, creates a time object (time1), and initializes time1.hours and time1.minutes to 0.
Table summary of time1 after the following line of code is executed: time1 = Time()
time1 attribute	value
hours	0
minutes	0
Step 2: Attributes can be accessed using the "." attribute reference operator.
Table summary of time1 after the following lines of code are executed: time1.hours = 7 time1.minutes = 15
time1 attribute	value
hours	7
minutes	15

Captions
Time() calls the __init__ method of the Time class, creates a time object (time1), and initializes time1.hours and time1.minutes to 0.
Attributes can be accessed using the "." attribute reference operator.
Playing step 2: Attributes can be accessed using the "." attribute reference operator. Step finished playing

Feedback?
A programmer can create multiple instances of a class in a program, with each instance having different attribute values.

Figure 9.2.3: Multiple instances of a class.
class Time:
    """ A class that represents a time of day """
    def __init__(self):
        self.hours = 0
        self.minutes = 0


time1 = Time()  # Create an instance of the Time class called time1
time1.hours = 7
time1.minutes = 30

time2 = Time()  # Create a second instance called time2
time2.hours = 12
time2.minutes = 45

print(f"{time1.hours} hours and {time1.minutes} minutes")
print(f"{time2.hours} hours and {time2.minutes} minutes")
7 hours and 30 minutes
12 hours and 45 minutes

Feedback?
Good practice is to use initial capitalization for each word in a class name. So, appropriate names might include LunchMenu, CoinAmounts, or PDFFileContents.'''

# %%
'''participation activity

## 

9.2.2: Class terms.

How to use this tool

Mouse: Drag/drop  
Keyboard: Grab/release Spacebar (or Enter). Move ↑↓←→. Cancel Esc

instance

class

\_\_init\_\_

attribute

self

* * *

A name following a "." symbol.

A method parameter that refers to the class instance.

An instantiation of a class.

A constructor method that initializes a class instance.

A group of related variables and functions.

Reset

Feedback?

'''
setin("An instantiation of a class.", "A group of related variables and functions.", "A constructor method that initializes a class instance.", "A name following a '.' symbol.", "A method parameter that refers to the class instance.")
def participation_activity_9_2_2():
    terms = {
        "instance": "An instantiation of a class.",
        "class": "A group of related variables and functions.",
        "__init__": "A constructor method that initializes a class instance.",
        "attribute": "A name following a '.' symbol.",
        "self": "A method parameter that refers to the class instance."
    }
    
    for term, definition in terms.items():
        answer = input(f"What is the definition of '{term}'?\nYour answer: ")
        if answer.strip().lower() == definition.lower():
            print("Correct!")
        else:
            print(f"Incorrect. The correct definition is: {definition}")
participation_activity_9_2_2()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipykernel_21732/2485940317.py:1: SyntaxWarning: invalid escape sequence '\_'
#   '''participation activity
# 'participation activity\n\n## \n\n9.2.2: Class terms.\n\nHow to use this tool\n\nMouse: Drag/drop  \nKeyboard: Grab/release Spacebar (or Enter). Move ↑↓←→. Cancel Esc\n\ninstance\n\nclass\n\n\\_\\_init\\_\\_\n\nattribute\n\nself\n\n* * *\n\nA name following a "." symbol.\n\nA method parameter that refers to the class instance.\n\nAn instantiation of a class.\n\nA constructor method that initializes a class instance.\n\nA group of related variables and functions.\n\nReset\n\nFeedback?\n\n'
# What is the definition of 'instance'?
# Your answer: An instantiation of a class.
# Correct!
# What is the definition of 'class'?
# Your answer: A group of related variables and functions.
# Correct!
# What is the definition of '__init__'?
# ...

# %%
def participation_activity_9_2_3():
    '''participation activity
    9.2.3: Classes.
    1)True
    A class can be used to group related variables together.
    Correct
    Programmers often use classes to model a real-world concept, such as a specific point in time.
    2)True
    The __init__ method is called automatically.
    Correct
    Instantiating a class instance, such as t = Time(), automatically calls the __init__ method of the Time class.
    3)True
    Following the statement t = Time(), t references an instance of the Time class.
    Correct
    Multiple instances of a class can be created.

    Feedback?'''
    #1) True
    #2) True
    #3) True
participation_activity_9_2_3()

# %%
def participation_activity_9_2_4():
    '''participation activity
    9.2.4: Classes.
    1)
    Given the above definition of the Time class, what is the value of time1.hours after the following code executes?
    time1 = Time()

    Check

    Show answer
    2)
    Given the above definition of the Time class, what is the value of time1.hours after the following code executes?
    time1 = Time()
    time1.hours = 7

    Check

    Show answer
    3)
    Given the above definition of the Time class, what is the value of time2.hours after the following code executes?
    time1 = Time()
    time1.hours = 7

    time2 = time1

    Check

    Show answer

    Feedback?'''

    class Time:
        """ A class that represents a time of day """
        def __init__(self):
            self.hours = 0
            self.minutes = 0

    #1) Given the above definition of the Time class, what is the value of time1.hours after the following code executes?
    time1 = Time()
    print(time1.hours)  # Output: 0
    #2) Given the above definition of the Time class, what is the value of time1.hours after the following code executes?
    time1 = Time()
    time1.hours = 7
    print(time1.hours)  # Output: 7
    #3) Given the above definition of the Time class, what is the value of time2.hours after the following code executes?
    time1 = Time()
    time1.hours = 7

    time2 = time1
    print(time2.hours)  # Output: 7
participation_activity_9_2_4()
# Out:
# 0
# 7
# 7

# %%
def challenge_activity_9_2_1_1():
    '''challenge activity
    9.2.1: Enter the output of grouping data.
    712910.5105864.qx3zqy7
    Jump to level 1
    Type the program's output

    class Person:
    def __init__(self):
        self.name = ""

    person1 = Person()
    username = "Ava"

    person1.name = username
    print(f"You are {person1.name}")
    1
    2
    3
    Check
    Next
    1
    2
    3

    Feedback?'''


    class Person:
        def __init__(self):
            self.name = ""

    person1 = Person()
    username = "Ava"

    person1.name = username
    print(f"You are {person1.name}")
challenge_activity_9_2_1_1()

def challenge_activity_9_2_1_2():
    '''challenge activity
    9.2.1: Enter the output of grouping data.
    712910.5105864.qx3zqy7
    Jump to level 1
    Type the program's output

    class Person:
    def __init__(self):
        self.name = ""

    person1 = Person()
    username = "Amy"
    different_username = "Ben"

    person1.name = username
    print(person1.name)
    person1.name = different_username
    print(person1.name)
    1
    2
    3
    Check
    Next
    1
    2
    3

    Feedback?'''
    class Person:
        def __init__(self):
            self.name = ""

    person1 = Person()
    username = "Amy"
    different_username = "Ben"

    person1.name = username
    print(person1.name)
    person1.name = different_username
    print(person1.name)
challenge_activity_9_2_1_2()

def challenge_activity_9_2_1_3():
    '''challenge activity
    9.2.1: Enter the output of grouping data.
    712910.5105864.qx3zqy7
    Jump to level 1
    Type the program's output

    class Person:
    def __init__(self):
        self.first = ""
        self.last = ""

    def get_full_name(self):
        return f"{self.first} {self.last}"

    person1 = Person()
    user_first_name = "Ina"
    user_last_name = "Wayne"

    person1.first = user_first_name
    person1.last = user_last_name
    print(person1.get_full_name())
    1
    2
    3
    Check
    Next
    1
    2
    3

    Feedback?'''

    class Person:
        def __init__(self):
            self.first = ""
            self.last = ""

        def get_full_name(self):
            return f"{self.first} {self.last}"

    person1 = Person()
    user_first_name = "Ina"
    user_last_name = "Wayne"

    person1.first = user_first_name
    person1.last = user_last_name
    print(person1.get_full_name())

challenge_activity_9_2_1_3()
# Out:
# You are Ava
# Amy
# Ben
# Ina Wayne

# %%
class myclass:
    def __init__(self):
        self.name = ""

myinstance = myclass()
myinstance.name

myinstance.name = "Hello"
myinstance.name

"-" * 20


class myclass2:
    def __init__(self):
        self.attribute1 = ""
        self.attribute2 = 0

myinstance2 = myclass2()

myinstance2.attribute1, myinstance2.attribute2

myinstance2.attribute1 = "World"
myinstance2.attribute2 = 42
myinstance2.attribute1, myinstance2.attribute2

myinstance2

myinstance2.attribute1, myinstance2.attribute2

"-" * 20

class point:
    def __init__(self):
        self.x = 0
        self.y = 0
        self.z = 0
point1 = point()
point1.x, point1.y, point1.z
point1.x = 1
point1.y = 2
point1.z = 3
point1.x, point1.y, point1.z
# Out:
# ''
# 'Hello'
# '--------------------'
# ('', 0)
# ('World', 42)
# ('World', 42)
# '--------------------'
# (0, 0, 0)
# (1, 2, 3)

# %% [markdown]
# ![Screenshot 2025-11-20 025628.png](<attachment:Screenshot 2025-11-20 025628.png>)

# %%
def challenge_activity_9_2_2_1():

    '''challenge activity
    9.2.2: Classes: Grouping data.
    712910.5105864.qx3zqy7

    Jump to level 1
    Create an instance of the HouseDetails class called new_house. Then, read three values from input into new_house's attributes in the following order:

    owner_name (str)
    build_date (str)
    num_windows (int)
    Click here for example
    Ex: If the input is:
    Avi Cook
    7/2011
    22
    then the output is:

    House details: owned by Avi Cook, built 7/2011, 22 windows

    1

    2

    3

    4

    Check

    Next level
    1
    2
    3
    4

    Feedback?

    class HouseDetails:
        def __init__(self):
            self.owner_name = "unknown"
            self.build_date = "unknown"
            self.num_windows = 0

    """ Your code goes here """

    print("House details:", end=" ")
    print(f"owned by {new_house.owner_name},", end=" ")
    print(f"built {new_house.build_date},", end=" ")
    print(f"{new_house.num_windows} windows")'''

    setin("Avi Cook", "7/2011", "22")
    class HouseDetails:
        def __init__(self):
            self.owner_name = "unknown"
            self.build_date = "unknown"
            self.num_windows = 0

    new_house = HouseDetails()
    new_house.owner_name = input()
    new_house.build_date = input()
    new_house.num_windows = int(input())

    print("House details:", end=" ")
    print(f"owned by {new_house.owner_name},", end=" ")
    print(f"built {new_house.build_date},", end=" ")
    print(f"{new_house.num_windows} windows")
challenge_activity_9_2_2_1()

'''challenge activity
9.2.2: Classes: Grouping data.
712910.5105864.qx3zqy7

Jump to level 1
Output "Total sqft: " followed by house1's sqft attribute added with house2's sqft attribute.

Click here for example
Ex: If the input is:
1800
1804
then the output is:

Total sqft: 3604

1

2

3

4

Check

Next level
1
2
3
4

Feedback?
```class HouseInfo:
    def __init__(self):
        self.sqft = 0

house1 = HouseInfo()
house1.sqft = int(input())

house2 = HouseInfo()
house2.sqft = int(input())

""" Your code goes here """
```
'''
def challenge_activity_9_2_2_2():
    setin("1800", "1804")
    class HouseInfo:
        def __init__(self):
            self.sqft = 0

    house1 = HouseInfo()
    house1.sqft = int(input())

    house2 = HouseInfo()
    house2.sqft = int(input())

    total_sqft = house1.sqft + house2.sqft
    print(f"Total sqft: {total_sqft}")
challenge_activity_9_2_2_2()

'''challenge activity
9.2.2: Classes: Grouping data.
712910.5105864.qx3zqy7

Jump to level 1
The RectangularPrism class contains two attributes: base_area and base_height. RectangularPrism object prism1 is created with the base_area and base_height attributes read from input. Given that 
, use prism1's attributes, base_area and base_height, to calculate total_volume and assign the result to variable total_volume.

Click here for example
Ex: If the input is:
5
17
then the output is:

Total volume: 85
prism1.base_height = int(input())

""" Your code goes here """

print(f"Total volume: {total_volume}")





1

2

3

4

Check

Next level
1
2
3
4

Feedback?'''
def challenge_activity_9_2_2_3():
    setin("5", "17")
    class RectangularPrism:
        def __init__(self):
            self.base_area = 0
            self.base_height = 0

    prism1 = RectangularPrism()
    prism1.base_area = int(input())
    prism1.base_height = int(input())

    total_volume = prism1.base_area * prism1.base_height
    print(f"Total volume: {total_volume}")
challenge_activity_9_2_2_3()
'''challenge activity
9.2.2: Classes: Grouping data.
712910.5105864.qx3zqy7

Jump to level 1
Define a class named HouseDetails that contains the attributes num_doors, num_windows, and sqft. Initialize num_doors, num_windows, and sqft with 0.

Click here for example
Ex: If the input is:
18
32
2100
then the output is:

House details (before): 0 doors, 0 windows, 0 sqft
House details (after): 18 doors, 32 windows, 2100 sqft
 

1

2

3

4

Check

Next level
1
2
3
4

Feedback?

```
""" Your code goes here """

new_house = HouseDetails()

print("House details (before):", end=" ")
print(f"{new_house.num_doors} doors,", end=" ")
print(f"{new_house.num_windows} windows,", end=" ")
print(f"{new_house.sqft} sqft")

new_house.num_doors = int(input())
new_house.num_windows = int(input())
new_house.sqft = int(input())

print("House details (after):", end=" ")
print(f"{new_house.num_doors} doors,", end=" ")
print(f"{new_house.num_windows} windows,", end=" ")
print(f"{new_house.sqft} sqft")```
'''
def challenge_activity_9_2_2_4():
    setin("18", "32", "2100")
    class HouseDetails:
        def __init__(self):
            self.num_doors = 0
            self.num_windows = 0
            self.sqft = 0

    new_house = HouseDetails()

    print("House details (before):", end=" ")
    print(f"{new_house.num_doors} doors,", end=" ")
    print(f"{new_house.num_windows} windows,", end=" ")
    print(f"{new_house.sqft} sqft")

    new_house.num_doors = int(input())
    new_house.num_windows = int(input())
    new_house.sqft = int(input())

    print("House details (after):", end=" ")
    print(f"{new_house.num_doors} doors,", end=" ")
    print(f"{new_house.num_windows} windows,", end=" ")
    print(f"{new_house.sqft} sqft")
challenge_activity_9_2_2_4()
# Out:
# Avi Cook
# 7/2011
# 22
# House details: owned by Avi Cook, built 7/2011, 22 windows
# 'challenge activity\n9.2.2: Classes: Grouping data.\n712910.5105864.qx3zqy7\n\nJump to level 1\nOutput "Total sqft: " followed by house1\'s sqft attribute added with house2\'s sqft attribute.\n\nClick here for example\nEx: If the input is:\n1800\n1804\nthen the output is:\n\nTotal sqft: 3604\n\n1\n\n2\n\n3\n\n4\n\nCheck\n\nNext level\n1\n2\n3\n4\n\nFeedback?\n```class HouseInfo:\n    def __init__(self):\n        self.sqft = 0\n\nhouse1 = HouseInfo()\nhouse1.sqft = int(input())\n\nhouse2 = HouseInfo()\nhouse2.sqft = int(input())\n\n""" Your code goes here """\n```\n'
# 1800
# 1804
# Total sqft: 3604
# ...

# %% [markdown]
# ## 9.3 Instance methods
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/3

# %%
ohokay='''9.3 Instance methods
A function defined within a class is known as an instance method. An instance method can be referenced using dot notation. The following example illustrates:

Figure 9.3.1: A class definition may include user-defined functions.
class Time:
    def __init__(self):
        self.hours = 0
        self.minutes = 0

    def print_time(self):
        print(f"Hours: {self.hours}", end=" ")
        print(f"Minutes: {self.minutes}")


time1 = Time()
time1.hours = 7
time1.minutes = 15
time1.print_time()
Hours: 7 Minutes: 15

Feedback?
The definition of print_time() has a parameter "self" that provides a reference to the class instance. In the program above, "self" is bound to time1 when time1.print_time() is called. A programmer does not specify an argument for "self" when calling the function; (the argument list in time1.print_time() is empty.) The method's code can use "self" to access other attributes or methods of the instance. Ex: The print_time method uses "self.hours" and "self.minutes" to get the value of the time1 instance data attributes.'''

# %%
def participation_activity_9_3_1():
    '''participation activity
    9.3.1: Methods.
    Consider the following class definition:

    class Animal:
        def __init__(self):
            # ...

        def noise(self, sound):
            # ...
    1)
    Write a statement that creates an instance of Animal called "cat".

    Check

    Show answer
    2)
    Write a statement that calls the noise method of the cat instance with the argument "meow".

    Check

    Show answer
    3)
    What should the first item in the parameter list of every method be?

    Check

    Show answer

    Feedback?'''

    class Animal:
        def __init__(self):
            pass

        def noise(self, sound):
            pass
    #1) Write a statement that creates an instance of Animal called "cat".
    cat = Animal()
    #2) Write a statement that calls the noise method of the cat instance with the argument "meow".
    cat.noise("meow")
    #3) What should the first item in the parameter list of every method be?
    print("The first item in the parameter list of every method should be 'self', which is a reference to the instance of the class on which the method is being called.")  
participation_activity_9_3_1()
# Out:
# The first item in the parameter list of every method should be 'self', which is a reference to the instance of the class on which the method is being called.

# %%
class Class:
    def __init__(self):
        self.attribute = 0

    def method(self, value):
        self.attribute += value
instance = Class()
instance.method(5)
print(instance.attribute)  # Output: 5
instance.method(3)
print(instance.attribute)  # Output: 8
# Out:
# 5
# 8

# %%
ohokay='''Try 9.3.1: Adding methods to a class.

Full screen
Add a method calculate_pay() to the Employee class. The method should return the amount to pay the employee by multiplying the employee's wage and number of hours worked.
```
class Employee:
    def __init__(self):
        self.wage = 0
        self.hours_worked = 0

    # FIXME: Add new method here.


alice = Employee()
alice.wage = 9.25
alice.hours_worked = 35
print(f"Alice:\n Net pay: {alice.calculate_pay():.2f}")

barbara = Employee()
barbara.wage = 11.50
barbara.hours_worked = 20
print(f"Barbara:\n Net pay: {barbara.calculate_pay():.2f}")```

Model Solution
```
class Employee:
    def __init__(self):
        self.wage = 0
        self.hours_worked = 0

    def calculate_pay(self):
        return self.wage * self.hours_worked

alice = Employee()
alice.wage = 9.25
alice.hours_worked = 35
print(f"Alice:\n Net pay: {alice.calculate_pay():.2f}")

barbara = Employee()
barbara.wage = 11.50
barbara.hours_worked = 20
print(f"Barbara:\n Net pay: {barbara.calculate_pay():.2f}")```

Feedback?
Note that __init__ is also a method of the Time class; however, __init__ is a special method name, indicating that the method implements some special behavior of the class. In the case of __init__, that special behavior is the initialization of new instances. Special methods can always be identified by the double underscores __ that appear before and after an identifier. Good practice is to avoid using double underscores in identifiers to prevent collisions with special method names, which the Python interpreter recognizes and may handle differently. Later sections discuss special method names in more detail.

A common error for new programmers is to omit the self argument as the first parameter of a method. In such cases, calling the method produces an error indicating too many arguments were given by the programmer, because a method call automatically inserts an instance reference as the first argument.'''

# %%
ohokay='''Note that __init__ is also a method of the Time class; however, __init__ is a special method name, indicating that the method implements some special behavior of the class. In the case of __init__, that special behavior is the initialization of new instances. Special methods can always be identified by the double underscores __ that appear before and after an identifier. Good practice is to avoid using double underscores in identifiers to prevent collisions with special method names, which the Python interpreter recognizes and may handle differently. Later sections discuss special method names in more detail.

A common error for new programmers is to omit the self argument as the first parameter of a method. In such cases, calling the method produces an error indicating too many arguments were given by the programmer, because a method call automatically inserts an instance reference as the first argument.

Figure 9.3.2: Accidentally forgetting the self parameter of a method generates an error when calling the method.
class Employee:
    def __init__(self):
        self.wage = 0
        self.hours_worked = 0

    def calculate_pay():  # Programmer forgot self parameter
        return self.wage * self.hours_worked


alice = Employee()
alice.wage = 9.25
alice.hours_worked = 35
print(f"Alice earned {alice.calculate_pay():.2f}")
Traceback (most recent call last):
  File "<stdin>", line 13, in <module>
TypeError: calculate_pay() takes 0 positional arguments but 1 was given

Feedback?'''

# %%
'''participation activity
9.3.2: Method definitions.
1)
Write the definition of a method "add" that has no extra parameters.
class MyClass:
    # ...
    def add(self):
        return self.x + self.y

Check

Show answer
2)
Write the definition of a method "print_time" that has a parameter "gmt".
class Time:
    # ...
    def print_time(self, gmt):

:
        if gmt:
            print(f"Time is: {self.hours-8}:{self.minutes}
               GMT")
        else:
            print(f"Time is: {self.hours}:{self.minutes}")

Check

Show answer

Feedback?'''
# Out:
# 'participation activity\n9.3.2: Method definitions.\n1)\nWrite the definition of a method "add" that has no extra parameters.\nclass MyClass:\n    # ...\n    def add(self):\n        return self.x + self.y\n\nCheck\n\nShow answer\n2)\nWrite the definition of a method "print_time" that has a parameter "gmt".\nclass Time:\n    # ...\n    def print_time(self, gmt):\n\n:\n        if gmt:\n            print(f"Time is: {self.hours-8}:{self.minutes}\n               GMT")\n        else:\n            print(f"Time is: {self.hours}:{self.minutes}")\n\nCheck\n\nShow answer\n\nFeedback?'

# %%
class MyClass:
    def __init__(self):
        self.x = 0
        self.y = 0

    def add(self):
        return self.x + self.y
    def add1(self,  some):
        return some.x + some.y
a=MyClass()
a.x = 5
a.y = 10
print(a.add())  # Output: 15
# Out:
# 15

# %%
'''challenge activity
9.3.1: Enter the instance method's output.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Person:
   def __init__(self):
      self.first_name = ""

   def print_name(self):
      print(f"I am {self.first_name}")

person1 = Person()
person1.first_name = "Joe"
person1.print_name()
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_3_1_1():
    class Person:
        def __init__(self):
            self.first_name = ""

        def print_name(self):
            print(f"I am {self.first_name}")

    person1 = Person()
    person1.first_name = "Joe"
    person1.print_name()  # Output: I am Joe
challenge_activity_9_3_1_1()
'''challenge activity
9.3.1: Enter the instance method's output.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Person:
   def __init__(self):
      self.first_name = ""
      self.last_name = ""

   def get_full_name(self):
      return self.first_name + "-" + self.last_name

user_first_name = "Ron"
user_last_name = "Stark"

person1 = Person()
person1.first_name = user_first_name 
person1.last_name = user_last_name 
print(f"You are {person1.get_full_name()}")
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_3_1_2():
    class Person:
        def __init__(self):
            self.first_name = ""
            self.last_name = ""

        def get_full_name(self):
            return self.first_name + "-" + self.last_name

    user_first_name = "Ron"
    user_last_name = "Stark"

    person1 = Person()
    person1.first_name = user_first_name 
    person1.last_name = user_last_name 
    print(f"You are {person1.get_full_name()}")  # Output: You are Ron-Stark
challenge_activity_9_3_1_2()

'''challenge activity
9.3.1: Enter the instance method's output.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Person:
   def __init__(self):
      self.first_name = ""

   def get_first_name(self):
      return self.first_name

user_name = "Joe"
different_user_name = "Max"

person1 = Person()
person1.first_name = user_name 
print(f"I am not {person1.get_first_name()}")
person1.first_name = different_user_name 
print(f"I am {person1.get_first_name()}")
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_3_1_3():
    class Person:
        def __init__(self):
            self.first_name = ""

        def get_first_name(self):
            return self.first_name

    user_name = "Joe"
    different_user_name = "Max"

    person1 = Person()
    person1.first_name = user_name 
    print(f"I am not {person1.get_first_name()}")  # Output: I am not Joe
    person1.first_name = different_user_name 
    print(f"I am {person1.get_first_name()}")  # Output: I am Max
challenge_activity_9_3_1_3()
'''challenge activity
9.3.1: Enter the instance method's output.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Person:
   def __init__(self):
      self.first_name = ""
      self.last_name = ""

   def get_full_name(self):
      return self.last_name + " " + self.first_name

a_first_name = "Sam"
another_first_name = "Max"
a_last_name = "Wayne"
another_last_name = "Banner"

person1 = Person()
person2 = Person()

person1.last_name = a_last_name
person1.first_name = a_first_name
person2.last_name = another_last_name
person2.first_name = another_first_name

print(f"You are {person1.get_full_name()}")
print(f"I am {person2.get_full_name()}")
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_3_1_4():
    class Person:
        def __init__(self):
            self.first_name = ""
            self.last_name = ""

        def get_full_name(self):
            return self.last_name + " " + self.first_name

    a_first_name = "Sam"
    another_first_name = "Max"
    a_last_name = "Wayne"
    another_last_name = "Banner"

    person1 = Person()
    person2 = Person()

    person1.last_name = a_last_name
    person1.first_name = a_first_name
    person2.last_name = another_last_name
    person2.first_name = another_first_name

    print(f"You are {person1.get_full_name()}")  # Output: You are Wayne Sam
    print(f"I am {person2.get_full_name()}")  # Output: I am Banner Max
challenge_activity_9_3_1_4()
# Out:
# 'challenge activity\n9.3.1: Enter the instance method\'s output.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program\'s output\n\nclass Person:\n   def __init__(self):\n      self.first_name = ""\n\n   def print_name(self):\n      print(f"I am {self.first_name}")\n\nperson1 = Person()\nperson1.first_name = "Joe"\nperson1.print_name()\n1\n2\n3\n4\nCheck\nNext\n1\n2\n3\n4\n\nFeedback?'
# I am Joe
# 'challenge activity\n9.3.1: Enter the instance method\'s output.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program\'s output\n\nclass Person:\n   def __init__(self):\n      self.first_name = ""\n      self.last_name = ""\n\n   def get_full_name(self):\n      return self.first_name + "-" + self.last_name\n\nuser_first_name = "Ron"\nuser_last_name = "Stark"\n\nperson1 = Person()\nperson1.first_name = user_first_name \nperson1.last_name = user_last_name \nprint(f"You are {person1.get_full_name()}")\n1\n2\n3\n4\nCheck\nNext\n1\n2\n3\n4\n\nFeedback?'
# You are Ron-Stark
# ...

# %%
class Person:
    def __init__(self):
        self.name = ""

    def get_name(self):
        return self.name
me = Person()
me.name = "Alice"
print(me.get_name())  # Output: Alice

me.get_name()

me

__

class ClassinAClass:
    def __init__(self):
        self.attribute = 0

    def method(self, value):
        self.attribute += value
        return self.attribute
instance = ClassinAClass()
print(instance.method(5))  # Output: 5
print(instance.method(3))  # Output: 8

__
# Out:
# Alice
# 'Alice'
# '--------------------'
# 5
# 8
# '--------------------'

# %%
'''challenge activity
9.3.2: Instance methods.
712910.5105864.qx3zqy7

Jump to level 1
point1 and point2 are instances of the Coordinates3D class. Attributes x_coord, y_coord, and z_coord of both point1 and point2 are read from input. In the Coordinates3D class, define instance method print_coordinates() with self as the parameter to output the following in one line:

The value of attribute x_coord
", "
The value of attribute y_coord
", "
The value of attribute z_coord
Click here for example
Ex: If the input is:
86
79
22
69
49
51

then the output is:

First location coordinates:
86, 79, 22
Second location coordinates:
69, 49, 51

 

1

2

3

Check

Next level
1
2
3

```
class Coordinates3D:
    def __init__(self):
        self.x_coord = 0
        self.y_coord = 0
        self.z_coord = 0

    """ Your code goes here """

point1 = Coordinates3D()
point1.x_coord = int(input())
point1.y_coord = int(input())
point1.z_coord = int(input())

point2 = Coordinates3D()
point2.x_coord = int(input())
point2.y_coord = int(input())
point2.z_coord = int(input())

print(f"First location coordinates:")
point1.print_coordinates()
print(f"Second location coordinates:")
point2.print_coordinates()
```'''
def challenge_activity_9_3_2_1():
    setin("86", "79", "22", "69", "49", "51")
    class Coordinates3D:
        def __init__(self):
            self.x_coord = 0
            self.y_coord = 0
            self.z_coord = 0

        def print_coordinates(self):
            print(f"{self.x_coord}, {self.y_coord}, {self.z_coord}")
    point1 = Coordinates3D()
    point1.x_coord = int(input())
    point1.y_coord = int(input())
    point1.z_coord = int(input())
    point2 = Coordinates3D()
    point2.x_coord = int(input())
    point2.y_coord = int(input())
    point2.z_coord = int(input())
    print(f"First location coordinates:")
    point1.print_coordinates()  # Output: 86, 79, 22
    print(f"Second location coordinates:")
    point2.print_coordinates()  # Output: 69, 49, 51
challenge_activity_9_3_2_1()
'''challenge activity
9.3.2: Instance methods.
712910.5105864.qx3zqy7

Jump to level 1
pt1 and pt2 are instances of the Coordinates class. Attributes x_coord and y_coord of both pt1 and pt2 are read from input. Then, two strings are read from input. In the Coordinates class, define instance method print_coordinates() with self and one string as parameters to output the string parameter in one line, and the following in the next line:

The value of attribute x_coord
", "
The value of attribute y_coord
Click here for example
Ex: If the input is:
97
94
22
51
Map location of hiker: Pat
^^^ Map location of hiker: Uma ^^^

then the output is:

Map location of hiker: Pat
97, 94
^^^ Map location of hiker: Uma ^^^
22, 51


pt1 = Coordinates()
pt1.x_coord = int(input())
pt1.y_coord = int(input())

pt2 = Coordinates()
pt2.x_coord = int(input())



1

2

3

Check

Next level
1
2
3

Feedback?

```
class Coordinates:
    def __init__(self):
        self.x_coord = 0
        self.y_coord = 0

    """ Your code goes here """

pt1 = Coordinates()
pt1.x_coord = int(input())
pt1.y_coord = int(input())

pt2 = Coordinates()
pt2.x_coord = int(input())
pt2.y_coord = int(input())

pt1.print_coordinates(input())
pt2.print_coordinates(input())
```
'''
def challenge_activity_9_3_2_2():
    setin("97", "94", "22", "51", "Map location of hiker: Pat", "^^^ Map location of hiker: Uma ^^^")
    class Coordinates:
        def __init__(self):
            self.x_coord = 0
            self.y_coord = 0

        def print_coordinates(self, location):
            print(location)
            print(f"{self.x_coord}, {self.y_coord}")
            
    pt1 = Coordinates()
    pt1.x_coord = int(input())
    pt1.y_coord = int(input())
    pt2 = Coordinates()
    pt2.x_coord = int(input())
    pt2.y_coord = int(input())
    pt1.print_coordinates(input())  # Output: Map location of hiker: Pat \n 97, 94
    pt2.print_coordinates(input())  # Output: ^^^ Map location of hiker: Uma ^^^ \n 22, 51
challenge_activity_9_3_2_2()

'''challenge activity
9.3.2: Instance methods.
712910.5105864.qx3zqy7

Jump to level 1
funny_video1 and funny_video2 are instances of the Video class. Attribute like_clicks of both funny_video1 and funny_video2 is initialized with 0. In the Video class, define instance method like() with self as the parameter to increment attribute like_clicks and output "Thank you for liking this video."

Click here for example
Ex: If the input is:
3
1

then the output is:

Thank you for liking this video.
Thank you for liking this video.
Thank you for liking this video.
The first video is liked 3 time(s).
Thank you for liking this video.
The second video is liked 1 time(s).


1

2

3

Check

Next level
1
2
3

Feedback?

```
class Video:
    def __init__(self):
        self.like_clicks = 0

    """ Your code goes here """

funny_video1 = Video()
for i in range(int(input())):
    funny_video1.like()
print(f"The first video is liked {funny_video1.like_clicks} time(s).")

funny_video2 = Video()
for i in range(int(input())):
    funny_video2.like()
print(f"The second video is liked {funny_video2.like_clicks} time(s).")
```
'''
def challenge_activity_9_3_2_3():
    setin("3", "1")
    class Video:
        def __init__(self):
            self.like_clicks = 0

        def like(self):
            self.like_clicks += 1
            print("Thank you for liking this video.")
            
    funny_video1 = Video()
    for i in range(int(input())):
        funny_video1.like()
    print(f"The first video is liked {funny_video1.like_clicks} time(s).")

    funny_video2 = Video()
    for i in range(int(input())):
        funny_video2.like()
    print(f"The second video is liked {funny_video2.like_clicks} time(s).")
challenge_activity_9_3_2_3()
# Out:
# 'challenge activity\n9.3.2: Instance methods.\n712910.5105864.qx3zqy7\n\nJump to level 1\npoint1 and point2 are instances of the Coordinates3D class. Attributes x_coord, y_coord, and z_coord of both point1 and point2 are read from input. In the Coordinates3D class, define instance method print_coordinates() with self as the parameter to output the following in one line:\n\nThe value of attribute x_coord\n", "\nThe value of attribute y_coord\n", "\nThe value of attribute z_coord\nClick here for example\nEx: If the input is:\n86\n79\n22\n69\n49\n51\n\nthen the output is:\n\nFirst location coordinates:\n86, 79, 22\nSecond location coordinates:\n69, 49, 51\n\n\n\n1\n\n2\n\n3\n\nCheck\n\nNext level\n1\n2\n3\n\n```\nclass Coordinates3D:\n    def __init__(self):\n        self.x_coord = 0\n        self.y_coord = 0\n        self.z_coord = 0\n\n    """ Your code goes here """\n\npoint1 = Coordinates3D()\npoint1.x_coord = int(input())\npoint1.y_coord = int(input())\npoint1.z_coord = int(input()
# ...

# %% [markdown]
# ## 9.4 Class and instance object types
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/4

# %%
ohokay='''9.4 Class and instance object types
A program with user-defined classes contains two additional types of objects: class objects and instance objects. A class object acts as a factory that creates instance objects. When created by the class object, an instance object is initialized via the __init__ method. The following tool demonstrates how the __init__ method of the Time class object is used to initialize two new Time instance objects:

PythonTutor: Class Time's init method initializes two new Time instance objects.

```
class Time:
    def __init__(self):
        self.hours = 0
        self.minutes = 0

time1 = Time()
time1.hours = 5
time1.minutes = 30

time2 = Time()
time2.hours = 7
time2.minutes = 45
print(f"Time 1: {time1.hours}:{time1.minutes}")
print(f"Time 2: {time2.hours}:{time2.minutes}")```
Feedback?
Class and instance objects are namespaces used to group data and functions together.

A class attribute is shared among all instances of that class. Class attributes are defined within the scope of a class.
Figure 9.4.1: A class attribute is shared between all instances of that class.
class MarathonRunner:
    race_distance = 42.195  # Marathon distance in kilometers

    def __init__(self):
        # ...

    def get_speed(self):
        # ...

runner1 = MarathonRunner()
runner2 = MarathonRunner()

print(MarathonRunner.race_distance)  # Look in class namespace
print(runner1.race_distance)  # Look in instance namespace
print(runner2.race_distance)
42.195
42.195
42.195

Feedback?

An instance attribute can be unique to each instance.
Figure 9.4.2: An instance attribute can be different between instances of a class.
class MarathonRunner:
    race_distance = 42.195  # Marathon distance in kilometers

    def __init__(self):
        self.speed = 0
        # ...

    def get_speed(self):
        # ...

runner1 = MarathonRunner()
runner1.speed = 7.5

runner2 = MarathonRunner()
runner2.speed = 8.0

print(f"Runner 1 speed: {runner1.speed}")
print(f"Runner 2 speed: {runner2.speed}")
Runner 1 speed: 7.5
Runner 2 speed: 8.0

Feedback?
Instance attributes are created using dot notation, as in self.speed = 0 within a method, or runner1.speed = 7.5 from outside of the class's scope.

Instance and class namespaces are linked to each other. If a name is not found in an instance namespace, then the class namespace is searched.

participation activity
9.4.1: Class and instance namespaces.


1

2

3

Using dot notation initiates a search that first looks in the instance namespace, then the class namespace.
class MarathonRunner:
   race_distance = 42.195  # Same for all runners
  
   def __init__(self):
       self.speed = 0

runner1 = MarathonRunner()
runner2 = MarathonRunner()

print(runner1.race_distance)
print(runner2.race_distance)
MarathonRunnerrunner1runner2race_distance42.195__init__<func>speed0speed042.19542.195
Static figure: A code block, a monitor, and 3 boxes to represent MarathonRunner, runner1, and runner2. Begin Python code: class MarathonRunner: race_distance = 42.195 # Same for all runners def __init__(self): self.speed = 0 runner1 = MarathonRunner() runner2 = MarathonRunner() print(runner1.race_distance) print(runner2.race_distance) End Python code. The monitor shows the code's output: 42.195 42.195 MarathonRunner has: race_distance 42.195 __init__ <func> runner1 has: speed 0 runner2 has: speed 0 Step 1: Class namespace contains all class attributes. The class attributes of race_distance and __init__ and their values 42.195 and <func> are added to the MarathonRunner box. Step 2: Instance attributes are added to each instance's namespace only. The line runner1 = MarathonRunner() is scanned, and a box for runner1 appears. Class MarathonRunner's __init__ is scanned, which adds the instance attribute speed and its value of 0 to the runner1 box. runner1 is instantiated with an instance of MarathonRunner, and the instance attribute speed with a value of 0 is added to runner1's namespace. The same process is repeated for runner2, resulting in the instance attribute speed and its value of 0 added to runner2's namespace. Step 3: Using dot notation initiates a search that first looks in the instance namespace, then the class namespace. The first print statement which prints the race_distance attribute of runner1 is highlighted in the codeblock. The instance namespace of runner1 is searched to find the value for race_distance, but is not found. The class namespace of runner1 is then searched, where the attribute race_distance is found with a value of 42.195. The value of 42.195 is printed to the monitor. The same process is repeated for runner2, resulting in 42.195 printing a second time to the monitor.

Captions
Class namespace contains all class attributes
Instance attributes added to each instance's namespace only
Using dot notation initiates a search that first looks in the instance namespace, then the class namespace.
Playing step 3: Using dot notation initiates a search that first looks in the instance namespace, then the class namespace. Step finished playing

Feedback?
Besides methods, typical class attributes are variables required only by instances of the class. Placing such constants in the class scope helps to reduce possible collisions with other variables or functions in the global scope.

Figure 9.4.3: Changing the gmt_offset class attribute affects behavior of all instances.
class Time:
    gmt_offset = 0  # Class attribute. Changing alters print_time output
    
    def __init__(self):  # Methods are a class attribute too
        self.hours = 0  # Instance attribute
        self.minutes = 0  # Instance attribute

    def print_time(self):  # Methods are a class attribute too
        offset_hours = self.hours + self.gmt_offset  # Local variable
        
        print(f"Time -- {offset_hours}:{self.minutes}")

time1 = Time()
time1.hours = 10
time1.minutes = 15

time2 = Time()
time2.hours = 12
time2.minutes = 45

print ("Greenwich Mean Time (GMT):")
time1.print_time()
time2.print_time()

Time.gmt_offset = -8  # Change to PST time (-8 GMT)

print("\nPacific Standard Time (PST):")
time1.print_time()
time2.print_time()
Greenwich Mean Time (GMT):
Time -- 10:15
Time -- 12:45

Pacific Standard Time (PST):
Time -- 2:15
Time -- 4:45

Feedback?'''

# %%
class Time:
    def __init__(self):
        self.hours = 0
        self.minutes = 0

time1 = Time()
time1.hours = 5
time1.minutes = 30

time2 = Time()
time2.hours = 7
time2.minutes = 45
print(f"Time 1: {time1.hours}:{time1.minutes}")
print(f"Time 2: {time2.hours}:{time2.minutes}")

__
__
class Time:
    def __init__(self):
        self.hours = 0
        self.minutes = 0


time1 = Time()
(time1,time1.hours,time1.minutes)

time1.hours = 5
(time1,time1.hours,time1.minutes)

time1.minutes = 30
(time1,time1.hours,time1.minutes)


time2 = Time()
(time2,time2.hours,time2.minutes)

time2.hours = 7
time2.minutes = 45
(time2,time2.hours,time2.minutes)

print(f"Time 1: {time1.hours}:{time1.minutes}")
print(f"Time 2: {time2.hours}:{time2.minutes}")

__

# class object
"class object"
class Time:
    def __init__(self):
        self.hours = 0
        self.minutes = 0
Time
# instance objects
"instance objects"
time1 = Time()
time2 = Time()
time1,time2
# Out:
# Time 1: 5:30
# Time 2: 7:45
# '--------------------'
# '--------------------'
# (<__main__.Time at 0x70d07f7f7530>, 0, 0)
# (<__main__.Time at 0x70d07f7f7530>, 5, 0)
# (<__main__.Time at 0x70d07f7f7530>, 5, 30)
# (<__main__.Time at 0x70d09c514cb0>, 0, 0)
# (<__main__.Time at 0x70d09c514cb0>, 7, 45)
# Time 1: 5:30
# Time 2: 7:45
# '--------------------'
# 'class object'
# __main__.Time
# 'instance objects'
# (<__main__.Time at 0x70d07f7f7d40>, <__main__.Time at 0x70d07f7f7530>)

# %%
class MarathonRunner:
    race_distance = 42.195  # Marathon distance in kilometers

    def __init__(self):
        self.speed = 0

    def get_speed(self):
        return self.speed
    
runner1 = MarathonRunner()
runner2 = MarathonRunner()
print(MarathonRunner.race_distance)  # Look in class namespace
print(runner1.race_distance)  # Look in instance namespace
print(runner2.race_distance)

__

# class attribute
"class attribute:MarathonRunner.race_distance"
MarathonRunner.race_distance
# instance attributes
"instance attributes:runner1.speed, runner2.speed"
runner1.speed, runner2.speed
# Out:
# 42.195
# 42.195
# 42.195
# '--------------------'
# 'class attribute:MarathonRunner.race_distance'
# 42.195
# 'instance attributes:runner1.speed, runner2.speed'
# (0, 0)

# %%
class MarathonRunner:
    race_distance = 42.195  # Marathon distance in kilometers

    def __init__(self):
        self.speed = 0
        

    def get_speed(self):
        return self.speed

runner1 = MarathonRunner()
runner1.speed = 7.5

runner2 = MarathonRunner()
runner2.speed = 8.0

print(f"Runner 1 speed: {runner1.speed}")
print(f"Runner 2 speed: {runner2.speed}")

__

# class attribute
"class attribute:MarathonRunner.race_distance"
MarathonRunner.race_distance
# instance attributes
"instance attributes:runner1.speed, runner2.speed"
runner1.speed, runner2.speed
# Out:
# Runner 1 speed: 7.5
# Runner 2 speed: 8.0
# '--------------------'
# 'class attribute:MarathonRunner.race_distance'
# 42.195
# 'instance attributes:runner1.speed, runner2.speed'
# (7.5, 8.0)

# %%
class Time:
    gmt_offset = 0  # Class attribute. Changing alters print_time output
    
    def __init__(self):  # Methods are a class attribute too
        self.hours = 0  # Instance attribute
        self.minutes = 0  # Instance attribute

    def print_time(self):  # Methods are a class attribute too
        offset_hours = self.hours + self.gmt_offset  # Local variable
        
        print(f"Time -- {offset_hours}:{self.minutes}")

time1 = Time()
time1.hours = 10
time1.minutes = 15

time2 = Time()
time2.hours = 12
time2.minutes = 45

print ("Greenwich Mean Time (GMT):")
time1.print_time()
time2.print_time()

Time.gmt_offset = -8  # Change to PST time (-8 GMT)

print("\nPacific Standard Time (PST):")
time1.print_time()
time2.print_time()

__
#instance methods
"instance methods:Time.print_time"
Time.print_time
# Out:
# Greenwich Mean Time (GMT):
# Time -- 10:15
# Time -- 12:45
#
# Pacific Standard Time (PST):
# Time -- 2:15
# Time -- 4:45
# '--------------------'
# 'instance methods:Time.print_time'
# <function __main__.Time.print_time(self)>

# %%
'''participation activity
9.4.2: Class and instance objects.
How to use this tool
Mouse: Drag/drop
Keyboard: Grab/release Spacebar (or Enter). Move ↑↓←→. Cancel Esc

Class object
A factory for creating new class instances
Correct
Instance object
Represents a single instance of a class
Correct
Instance methods
Functions that are also class attributes
Correct
Instance attribute
A variable that exists in a single instance
Correct
Class attribute
A variable shared with all instances of a class
Correct

Reset

Feedback?'''
def participation_activity_9_4_2():
    print("Class object: A factory for creating new class instances")
    print("Instance object: Represents a single instance of a class")
    print("Instance methods: Functions that are also class attributes")
    print("Instance attribute: A variable that exists in a single instance")
    print("Class attribute: A variable shared with all instances of a class")
participation_activity_9_4_2()
# Out:
# 'participation activity\n9.4.2: Class and instance objects.\nHow to use this tool\nMouse: Drag/drop\nKeyboard: Grab/release Spacebar (or Enter). Move ↑↓←→. Cancel Esc\n\nClass object\nA factory for creating new class instances\nCorrect\nInstance object\nRepresents a single instance of a class\nCorrect\nInstance methods\nFunctions that are also class attributes\nCorrect\nInstance attribute\nA variable that exists in a single instance\nCorrect\nClass attribute\nA variable shared with all instances of a class\nCorrect\n\nReset\n\nFeedback?'
# Class object: A factory for creating new class instances
# Instance object: Represents a single instance of a class
# Instance methods: Functions that are also class attributes
# Instance attribute: A variable that exists in a single instance
# Class attribute: A variable shared with all instances of a class

# %%
ohokay='''Note that even though class and instance attributes have unique namespaces, a programmer can use the "self" parameter to reference either type. For example, self.hours finds the instance attribute hours, and self.gmt_offset finds the class attribute gmt_offset. Thus, if a class and instance both have an attribute with the same name, the instance attribute will always be referenced. Good practice is to avoid name collisions between class and instance attributes.'''

# %%
'''participation activity
9.4.3: Identifying class and instance attributes.
1)
What type of attribute is number?
class PhoneNumber:
    def __init__(self):
        self.number = "805-555-2231"
Correct
Instance variables are assigned using dot notation. __init__ initializes the number variable of every instance to a specific number in this case.
2)
What type of attribute is number?
class PhoneNumber:
    def __init__(self):
        self.number = None

garrett = PhoneNumber()
garrett.number = "805-555-2231"
Correct
An instance attribute can be also created/changed from outside the function scope.
3)
What type of attribute is area_code?
class PhoneNumber:
    area_code = "805"
    def __init__(self):
        self.number = "555-2231"
Correct
Assignments within the class definition are class attributes.

Feedback?'''
def participation_activity_9_4_3():
    print("1) Instance variable")
    print("2) Instance variable")
    print("3) Class attribute")
participation_activity_9_4_3()
# Out:
# 'participation activity\n9.4.3: Identifying class and instance attributes.\n1)\nWhat type of attribute is number?\nclass PhoneNumber:\n    def __init__(self):\n        self.number = "805-555-2231"\nCorrect\nInstance variables are assigned using dot notation. __init__ initializes the number variable of every instance to a specific number in this case.\n2)\nWhat type of attribute is number?\nclass PhoneNumber:\n    def __init__(self):\n        self.number = None\n\ngarrett = PhoneNumber()\ngarrett.number = "805-555-2231"\nCorrect\nAn instance attribute can be also created/changed from outside the function scope.\n3)\nWhat type of attribute is area_code?\nclass PhoneNumber:\n    area_code = "805"\n    def __init__(self):\n        self.number = "555-2231"\nCorrect\nAssignments within the class definition are class attributes.\n\nFeedback?'
# 1) Instance variable
# 2) Instance variable
# 3) Class attribute

# %%
'''challenge activity
9.4.1: Classes and instances.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Shape:
    def __init__(self):
       self.color = None

shape1 = Shape()
shape2 = Shape()
shape2.color = "yellow"

print(shape1.color)
print(shape2.color)
1
2
3
4
5
6
7
Check
Next
1
2
3
4
5
6
7

Feedback?'''
def challenge_activity_9_4_1_1():
    class Shape:
        def __init__(self):
           self.color = None

    shape1 = Shape()
    shape2 = Shape()
    shape2.color = "yellow"

    print(shape1.color)  # Output: None
    print(shape2.color)  # Output: yellow
challenge_activity_9_4_1_1()
'''challenge activity
9.4.1: Classes and instances.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

# "New" means new compared to previous level
class Shape:
    # New: Add class variable
    default_color = "red"

    def __init__(self):
        self.color = None

a_shape = Shape()
print(a_shape.color)

a_shape.color = Shape.default_color
print(a_shape.color)

a_shape.color = "maroon"
print(a_shape.color)
1
2
3
4
5
6
7
Check
Next
1
2
3
4
5
6
7

Feedback?'''
def challenge_activity_9_4_1_2():
    class Shape:
        default_color = "red"

        def __init__(self):
            self.color = None

    a_shape = Shape()
    print(a_shape.color)  # Output: None

    a_shape.color = Shape.default_color
    print(a_shape.color)  # Output: red

    a_shape.color = "maroon"
    print(a_shape.color)  # Output: maroon
challenge_activity_9_4_1_2()
'''challenge activity
9.4.1: Classes and instances.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Shape:
    default_color = "maroon"

    def __init__(self):
        self.color = None

a_shape = Shape()
a_shape.color = "gray"

print(a_shape.color)
print(a_shape.default_color)
print(Shape.default_color)
1
2
3
4
5
6
7
Check
Next
1
2
3
4
5
6
7

Feedback?'''
def challenge_activity_9_4_1_3():
    class Shape:
        default_color = "maroon"

        def __init__(self):
            self.color = None

    a_shape = Shape()
    a_shape.color = "gray"

    print(a_shape.color)  # Output: gray
    print(a_shape.default_color)  # Output: maroon
    print(Shape.default_color)  # Output: maroon
challenge_activity_9_4_1_3()
'''challenge activity
9.4.1: Classes and instances.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

# "New" means new compared to previous level
class Shape:
    default_color = "green"

    def __init__(self):
        # New: change from None
        self.color = self.default_color

a_shape = Shape()
print(a_shape.color)
a_shape.color = "teal"
print(a_shape.color)
1
2
3
4
5
6
7
Check
Next
1
2
3
4
5
6
7

Feedback?
'''
def challenge_activity_9_4_1_4():
    class Shape:
        default_color = "green"

        def __init__(self):
            self.color = self.default_color

    a_shape = Shape()
    print(a_shape.color)  # Output: green
    a_shape.color = "teal"
    print(a_shape.color)  # Output: teal
challenge_activity_9_4_1_4()
'''challenge activity
9.4.1: Classes and instances.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Shape:
    default_color = "gray"

    def __init__(self):
        self.color = self.default_color

shape1 = Shape()
Shape.default_color = "magenta"
shape2 = Shape()

print(Shape.default_color)
print(shape2.color)
print(shape1.color)
1
2
3
4
5
6
7
Check
Next
1
2
3
4
5
6
7

Feedback?'''
def challenge_activity_9_4_1_5():
    class Shape:
        default_color = "gray"

        def __init__(self):
            self.color = self.default_color

    shape1 = Shape()
    Shape.default_color = "magenta"
    shape2 = Shape()

    print(Shape.default_color)  # Output: magenta
    print(shape2.color)  # Output: magenta
    print(shape1.color)  # Output: gray
challenge_activity_9_4_1_5()
'''challenge activity
9.4.1: Classes and instances.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

# "New" means new compared to previous level
class Shape:
    default_color = "indigo"
    # New: Add class variable
    background_color = "beige"

    def __init__(self):
        self.color = self.default_color

    # New: Add instance method
    def print_description(self):
        print(f"{self.color} on {self.background_color}")

a_shape = Shape()
a_shape.print_description()

a_shape.color = "teal"
a_shape.print_description()

Shape.background_color = "ivory"
a_shape.print_description()
1
2
3
4
5
6
7
Check
Next
1
2
3
4
5
6
7

Feedback?'''
def challenge_activity_9_4_1_6():
    class Shape:
        default_color = "indigo"
        background_color = "beige"

        def __init__(self):
            self.color = self.default_color

        def print_description(self):
            print(f"{self.color} on {self.background_color}")

    a_shape = Shape()
    a_shape.print_description()  # Output: indigo on beige

    a_shape.color = "teal"
    a_shape.print_description()  # Output: teal on beige

    Shape.background_color = "ivory"
    a_shape.print_description()  # Output: teal on ivory
challenge_activity_9_4_1_6()

'''challenge activity
9.4.1: Classes and instances.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

# "New" means new compared to previous level
class Shape:
    default_color = "yellow"
    # New: Change from background_color
    count = 0

    def __init__(self):
        Shape.count += 1
        self.number = self.count
        self.color = self.default_color

    def print_description(self):
        print(f"{self.number} of {self.count} - {self.color}")

shape1 = Shape()
shape2 = Shape()
shape2.color = "teal"

print(Shape.count)
shape1.print_description()
shape2.print_description()
1
2
3
4
5
6
7
Check
Next
1
2
3
4
5
6
7

Feedback?'''
def challenge_activity_9_4_1_7():
    class Shape:
        default_color = "yellow"
        count = 0

        def __init__(self):
            Shape.count += 1
            self.number = self.count
            self.color = self.default_color

        def print_description(self):
            print(f"{self.number} of {self.count} - {self.color}")

    shape1 = Shape()
    shape2 = Shape()
    shape2.color = "teal"

    print(Shape.count)  # Output: 2
    shape1.print_description()  # Output: 1 of 2 - yellow
    shape2.print_description()  # Output: 2 of 2 - teal
challenge_activity_9_4_1_7()
# Out:
# 'challenge activity\n9.4.1: Classes and instances.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program\'s output\n\nclass Shape:\n    def __init__(self):\n       self.color = None\n\nshape1 = Shape()\nshape2 = Shape()\nshape2.color = "yellow"\n\nprint(shape1.color)\nprint(shape2.color)\n1\n2\n3\n4\n5\n6\n7\nCheck\nNext\n1\n2\n3\n4\n5\n6\n7\n\nFeedback?'
# None
# yellow
# 'challenge activity\n9.4.1: Classes and instances.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program\'s output\n\n# "New" means new compared to previous level\nclass Shape:\n    # New: Add class variable\n    default_color = "red"\n\n    def __init__(self):\n        self.color = None\n\na_shape = Shape()\nprint(a_shape.color)\n\na_shape.color = Shape.default_color\nprint(a_shape.color)\n\na_shape.color = "maroon"\nprint(a_shape.color)\n1\n2\n3\n4\n5\n6\n7\nCheck\nNext\n1\n2\n3\n4\n5\n6\n7\n\nFeedback?'
# None
# red
# maroon
# ...

# %%
class MyClass:
    class_attribute = "I am a class attribute"

    def __init__(self):
        self.instance_attribute = "I am an instance attribute"

    def i_am_modify_class_attribute(self):
        MyClass.class_attribute =MyClass.class_attribute + "|I have been modified|"

    def i_am_modify_instance_attribute(self):
        self.instance_attribute = self.instance_attribute + "|I have been modified|"

# %%
class MyClass:
    class_attribute = "I am a class attribute"

    def __init__(self):
        self.instance_attribute = "I am an instance attribute"

    def i_am_modify_class_attribute(self):
        MyClass.class_attribute =MyClass.class_attribute + "|I have been modified|"

    def i_am_modify_instance_attribute(self):
        self.instance_attribute = self.instance_attribute + "|I have been modified|"

my_instance = MyClass()
print(my_instance.class_attribute)  # Output: I am a class attribute
print(my_instance.instance_attribute)  # Output: I am an instance attribute

my_instance2 = MyClass()
print(my_instance2.class_attribute)  # Output: I am a class attribute
print(my_instance2.instance_attribute)  # Output: I am an instance attribute

my_instance.i_am_modify_class_attribute()
print(my_instance.class_attribute)  # Output: I am a class attribute|I have been modified|
print(my_instance2.class_attribute)  # Output: I am a class attribute|I have been modified|
my_instance.i_am_modify_instance_attribute()
print(my_instance.instance_attribute)  # Output: I am an instance attribute|I have been modified|
print(my_instance2.instance_attribute)  # Output: I am an instance attribute
# Out:
# I am a class attribute
# I am an instance attribute
# I am a class attribute
# I am an instance attribute
# I am a class attribute|I have been modified|
# I am a class attribute|I have been modified|
# I am an instance attribute|I have been modified|
# I am an instance attribute

# %%
class Test:
    class_attribute = "I am a class attribute"

    def __init__(self):
        self.instance_attribute = "I am an instance attribute"
test_instance = Test()

test_instance.class_attribute,test_instance.instance_attribute #('I am a class attribute', 'I am an instance attribute')




class Test:
    print(1)
    class_attribute = "I am a class attribute"
    print(2)
    def __init__(self):
        print(3,"!")
        self.instance_attribute = "I am an instance attribute"
        print(4,"!!")
    print(5)

test_instance = Test()
test_instance.class_attribute,test_instance.instance_attribute #('I am a class attribute', 'I am an instance attribute')
# Out:
# ('I am a class attribute', 'I am an instance attribute')
# 1
# 2
# 5
# 3 !
# 4 !!
# ('I am a class attribute', 'I am an instance attribute')

# %%
'''challenge activity
9.4.2: Class and instance object types.
712910.5105864.qx3zqy7

Jump to level 1
Define a class attribute named h_to_m in the Time class, and assign h_to_m with 60.

Ex: If the input is 6, then the output is:

6 hours = 360 minutes


1

2

3

Check

Next level
1
2
3

Feedback?

```
class Time:

    """ Your code goes here """

    def __init__(self):
        self.h = 0
        
    def print_value(self):
        m = self.h * self.h_to_m
        print(f"{self.h} hours = {m} minutes")

sleep_time = Time()
sleep_time.h = int(input())
sleep_time.print_value()
```
'''
def challenge_activity_9_4_2_1():
    setin("6")
    class Time:
        h_to_m = 60

        def __init__(self):
            self.h = 0
            
        def print_value(self):
            m = self.h * self.h_to_m
            print(f"{self.h} hours = {m} minutes")

    sleep_time = Time()
    sleep_time.h = int(input())
    sleep_time.print_value()  # Output: 6 hours = 360 minutes
challenge_activity_9_4_2_1()

'''challenge activity
9.4.2: Class and instance object types.
712910.5105864.qx3zqy7

Jump to level 1
In the print_value() method of the Weight class object:

If the class attribute show_2dp is True, then output "Weight (2dp): " followed by instance attribute value_raw with two digits after the decimal point.
Otherwise, output "Weight (raw): " followed by the value of instance attribute value_raw.
Click here for example
Ex: If the input is:
3
50

then the output is:

First weight measurement:
Weight (raw): 3.0
Second weight measurement:
Weight (2dp): 50.00

Note: print(f"{x:.2f}") outputs variable x with two digits after the decimal point.

 

1

2

3

Check

Next level
1
2
3

Feedback?
```
class Weight:
    show_2dp = False
      
    def __init__(self):
        self.value_raw = 0
  
    def print_value(self):

        """ Your code goes here """
  
box_weight1 = Weight()
box_weight1.value_raw = float(input())
print("First weight measurement:")
box_weight1.print_value()

Weight.show_2dp = True

box_weight2 = Weight()
box_weight2.value_raw = float(input())
print("Second weight measurement:")
box_weight2.print_value()
```
'''
def challenge_activity_9_4_2_2():
    setin("3", "50")
    class Weight:
        show_2dp = False
          
        def __init__(self):
            self.value_raw = 0
    
        def print_value(self):
            if self.show_2dp:
                print(f"Weight (2dp): {self.value_raw:.2f}")
            else:
                print(f"Weight (raw): {self.value_raw}")
    
    box_weight1 = Weight()
    box_weight1.value_raw = float(input())
    print("First weight measurement:")
    box_weight1.print_value()  # Output: Weight (raw): 3.0

    Weight.show_2dp = True

    box_weight2 = Weight()
    box_weight2.value_raw = float(input())
    print("Second weight measurement:")
    box_weight2.print_value()  # Output: Weight (2dp): 50.00
challenge_activity_9_4_2_2()

'''challenge activity
9.4.2: Class and instance object types.
712910.5105864.qx3zqy7

Jump to level 1
In method setup() of the Museum class, perform the following tasks:

Increment class attribute visitors_count.
Assign instance attribute ticket_number with the value of visitors_count.
Assign instance attribute visitor_name with parameter applicant_name.
Click here for example
Ex: If the input is Ike Bly Joe, then the output is:
Ike's ticket number is 1.
Bly's ticket number is 2.
Joe's ticket number is 3.
The museum has 3 visitors.

Note: Museum.visitors_count should be used when modifying class attribute visitors_count.

    def setup(self, applicant_name):

        """ Your code goes here """
    
    def print_value(self):
        print(f"{self.visitor_name}'s ticket number is {self.ticket_number}.")



 

1

2

3

Check

Next level
1
2
3

Feedback?

```
class Museum:
    visitors_count = 0
    
    def __init__(self):
        self.visitor_name = "empty"
        self.ticket_number = 0

    def setup(self, applicant_name):

        """ Your code goes here """
    
    def print_value(self):
        print(f"{self.visitor_name}'s ticket number is {self.ticket_number}.")

for applicant_name in input().split():
    new_visitor = Museum()
    new_visitor.setup(applicant_name)
    new_visitor.print_value()
print(f"The museum has {Museum.visitors_count} visitors.") 
```
'''
def challenge_activity_9_4_2_3():
    setin("Ike Bly Joe")
    class Museum:
        visitors_count = 0
        
        def __init__(self):
            self.visitor_name = "empty"
            self.ticket_number = 0

        def setup(self, applicant_name):
            Museum.visitors_count += 1
            self.ticket_number = Museum.visitors_count
            self.visitor_name = applicant_name
    
        def print_value(self):
            print(f"{self.visitor_name}'s ticket number is {self.ticket_number}.")

    for applicant_name in input().split():
        new_visitor = Museum()
        new_visitor.setup(applicant_name)
        new_visitor.print_value()
    print(f"The museum has {Museum.visitors_count} visitors.")
challenge_activity_9_4_2_3()
# Out:
# 'challenge activity\n9.4.2: Class and instance object types.\n712910.5105864.qx3zqy7\n\nJump to level 1\nDefine a class attribute named h_to_m in the Time class, and assign h_to_m with 60.\n\nEx: If the input is 6, then the output is:\n\n6 hours = 360 minutes\n\n\n1\n\n2\n\n3\n\nCheck\n\nNext level\n1\n2\n3\n\nFeedback?\n\n```\nclass Time:\n\n    """ Your code goes here """\n\n    def __init__(self):\n        self.h = 0\n\n    def print_value(self):\n        m = self.h * self.h_to_m\n        print(f"{self.h} hours = {m} minutes")\n\nsleep_time = Time()\nsleep_time.h = int(input())\nsleep_time.print_value()\n```\n'
# 6
# 6 hours = 360 minutes
# ...

# %% [markdown]
# ## 9.5 Class example: Seat reservation system
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/5

# %%
'''Try 9.5.1: Using classes to implement an airline seat reservation system.

Full screen
The following example implements an airline seat reservations system using classes with instance data members and methods. Ultimately, the use of classes should lead to programs that are easier to understand and maintain.

```
class Seat:
    def __init__(self):
        self.first_name = ""
        self.last_name = ""
        self.paid = 0.0

    def reserve(self, f_name, l_name, amt_paid):
        self.first_name = f_name
        self.last_name = l_name
        self.paid = amt_paid

    def make_empty(self):
        self.first_name = ""
        self.last_name = ""
        self.paid = 0.0

    def is_empty(self):
        return self.first_name == ""

    def print_seat(self):
        print(f"{self.first_name} {self.last_name}, Paid: {self.paid:.2f}")

def make_seats_empty(seats):
    for s in seats:
        s.make_empty()

def print_seats(seats):
    for i in range(len(seats)):
        print(f"{i}:", end=" ")
        seats[i].print_seat()

num_seats = 5

available_seats = []
for i in range(num_seats):
    available_seats.append(Seat())

command = input("Enter command (p/r/q):\n")
while command != "q":
    if command == "p":  # Print seats
        print_seats(available_seats)
    elif command == "r":  # Reserve a seat
        seat_num = int(input("Enter seat num:\n"))
        if not available_seats[seat_num].is_empty():
            print("Seat not empty")
        else:
            fname = input("Enter first name:\n")
            lname = input("Enter last name:\n")
            paid = float(input("Enter amount paid:\n"))
            available_seats[seat_num].reserve(fname, lname, paid)
    else:
        print("Invalid command.")

    command = input("Enter command (p/r/q):\n")
```'''
setin("p", "r", "0", "John", "Doe", "199.99", "p", "q")
def try_9_5_1():
    class Seat:
        def __init__(self):
            self.first_name = ""
            self.last_name = ""
            self.paid = 0.0

        def reserve(self, f_name, l_name, amt_paid):
            self.first_name = f_name
            self.last_name = l_name
            self.paid = amt_paid

        def make_empty(self):
            self.first_name = ""
            self.last_name = ""
            self.paid = 0.0

        def is_empty(self):
            return self.first_name == ""

        def print_seat(self):
            print(f"{self.first_name} {self.last_name}, Paid: {self.paid:.2f}")

    def make_seats_empty(seats):
        for s in seats:
            s.make_empty()

    def print_seats(seats):
        for i in range(len(seats)):
            print(f"{i}:", end=" ")
            seats[i].print_seat()

    num_seats = 5

    available_seats = []
    for i in range(num_seats):
        available_seats.append(Seat())

    command = input("Enter command (p/r/q):\n")
    while command != "q":
        if command == "p":  # Print seats
            print_seats(available_seats)
        elif command == "r":  # Reserve a seat
            seat_num = int(input("Enter seat num:\n"))
            if not available_seats[seat_num].is_empty():
                print("Seat not empty")
            else:
                fname = input("Enter first name:\n")
                lname = input("Enter last name:\n")
                paid = float(input("Enter amount paid:\n"))
                available_seats[seat_num].reserve(fname, lname, paid)
        else:
            print("Invalid command.")

        command = input("Enter command (p/r/q):\n")
try_9_5_1()
# Out:
# 'Try 9.5.1: Using classes to implement an airline seat reservation system.\n\nFull screen\nThe following example implements an airline seat reservations system using classes with instance data members and methods. Ultimately, the use of classes should lead to programs that are easier to understand and maintain.\n\n```\nclass Seat:\n    def __init__(self):\n        self.first_name = ""\n        self.last_name = ""\n        self.paid = 0.0\n\n    def reserve(self, f_name, l_name, amt_paid):\n        self.first_name = f_name\n        self.last_name = l_name\n        self.paid = amt_paid\n\n    def make_empty(self):\n        self.first_name = ""\n        self.last_name = ""\n        self.paid = 0.0\n\n    def is_empty(self):\n        return self.first_name == ""\n\n    def print_seat(self):\n        print(f"{self.first_name} {self.last_name}, Paid: {self.paid:.2f}")\n\ndef make_seats_empty(seats):\n    for s in seats:\n        s.make_empty()\n\ndef print_seats(seats):\n    for i in range
# ...

# %% [markdown]
# ## 9.6 Class constructors
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/6

# %%
ohokay='''9.6 Class constructors
A class instance is initialized to a specific state. The __init__ method constructor can be customized with additional parameters, as shown below:

Figure 9.6.1: Adding parameters to a constructor.
class RaceTime:
    def __init__(self, start_time, end_time, distance):
        """
         start_time: Race start time. String w/ format 'hours:minutes'.
         end_time: Race end time. String w/ format 'hours:minutes'.
         distance: Distance of race in miles.
        """
    # ...

# The race times of marathon contestants
time_jason = RaceTime("3:15", "7:45", 26.21875)
time_bobby = RaceTime("3:15", "6:30", 26.21875)

Feedback?
The above constructor has three additional parameters: start_time, end_time, and distance. When instantiating a new instance of RaceTime, arguments must be passed to the constructor, e.g., RaceTime("3:15", "7:45", 26.21875).

Consider the example below, which fully implements the RaceTime class, adding methods to print the time taken to complete the race and average pace.

Figure 9.6.2: Additional parameters can be added to a class constructor.
class RaceTime:

    def __init__(self, start_hrs, start_mins, end_hrs, end_mins, dist):
        self.start_hrs = start_hrs
        self.start_mins = start_mins
        self.end_hrs = end_hrs
        self.end_mins = end_mins
        self.distance = dist

    def print_time(self):
        if self.end_mins >= self.start_mins:
            minutes = self.end_mins - self.start_mins
            hours = self.end_hrs - self.start_hrs
        else:
            minutes = 60 - self.start_mins + self.end_mins
            hours = self.end_hrs - self.start_hrs - 1

        print(f"Time to complete race: {hours}:{minutes}")

    def print_pace(self):
        if self.end_mins >= self.start_mins:
            minutes = self.end_mins - self.start_mins
            hours = self.end_hrs - self.start_hrs
        else:
            minutes = 60 - self.start_mins + self.end_mins
            hours = self.end_hrs - self.start_hrs - 1

        total_minutes = hours*60 + minutes
        print(f"Avg pace (mins/mile): {total_minutes / self.distance:.2f}")

distance = 5.0

start_hrs = int(input("Enter starting time hours: "))
start_mins = int(input("Enter starting time minutes: "))
end_hrs = int(input("Enter ending time hours: "))
end_mins = int(input("Enter ending time minutes: "))

race_time = RaceTime(start_hrs, start_mins, end_hrs, end_mins, distance)

race_time.print_time()
race_time.print_pace()
Enter starting time hours: 5
Enter starting time minutes: 30
Enter ending time hours: 7
Enter ending time minutes: 00
Time to complete race: 1:30
Avg pace (mins/mile): 18.00

...

Enter starting time hours: 5
Enter starting time minutes: 30
Enter ending time hours: 6
Enter ending time minutes: 24
Time to complete race: 0:54
Avg pace (mins/mile): 10.80

Feedback?
The arguments passed into the constructor are saved as instance attributes using the automatically added "self" parameter and dot notation, as in self.distance = distance. Creation of such instance attributes allows methods to later access the values passed as arguments. Ex: print_time() uses self.start and self.end, and print_pace() uses self.distance.'''

# %%
setin("5", "30", "7", "00")
def figure_9_6_2():
    class RaceTime:

        def __init__(self, start_hrs, start_mins, end_hrs, end_mins, dist):
            self.start_hrs = start_hrs
            self.start_mins = start_mins
            self.end_hrs = end_hrs
            self.end_mins = end_mins
            self.distance = dist

        def print_time(self):
            if self.end_mins >= self.start_mins:
                minutes = self.end_mins - self.start_mins
                hours = self.end_hrs - self.start_hrs
            else:
                minutes = 60 - self.start_mins + self.end_mins
                hours = self.end_hrs - self.start_hrs - 1

            print(f"Time to complete race: {hours}:{minutes}")

        def print_pace(self):
            if self.end_mins >= self.start_mins:
                minutes = self.end_mins - self.start_mins
                hours = self.end_hrs - self.start_hrs
            else:
                minutes = 60 - self.start_mins + self.end_mins
                hours = self.end_hrs - self.start_hrs - 1

            total_minutes = hours*60 + minutes
            print(f"Avg pace (mins/mile): {total_minutes / self.distance:.2f}")

    distance = 5.0

    start_hrs = int(input("Enter starting time hours: "))
    start_mins = int(input("Enter starting time minutes: "))
    end_hrs = int(input("Enter ending time hours: "))
    end_mins = int(input("Enter ending time minutes: "))

    race_time = RaceTime(start_hrs, start_mins, end_hrs, end_mins, distance)

    race_time.print_time()
    race_time.print_pace()
figure_9_6_2()
# Out:
# Enter starting time hours: 5
# Enter starting time minutes: 30
# Enter ending time hours: 7
# Enter ending time minutes: 00
# Time to complete race: 1:30
# Avg pace (mins/mile): 18.00

# %%
class RaceTime:

        def __init__(self, start_hrs, start_mins, end_hrs, end_mins, dist):
            self.start_hrs = start_hrs
            self.start_mins = start_mins
            self.end_hrs = end_hrs
            self.end_mins = end_mins
            self.distance = dist

        def print_time(self):
            if self.end_mins >= self.start_mins:
                minutes = self.end_mins - self.start_mins
                hours = self.end_hrs - self.start_hrs
            else:
                minutes = 60 - self.start_mins + self.end_mins
                hours = self.end_hrs - self.start_hrs - 1

            print(f"Time to complete race: {hours}:{minutes}")

        def print_pace(self):
            if self.end_mins >= self.start_mins:
                minutes = self.end_mins - self.start_mins
                hours = self.end_hrs - self.start_hrs
            else:
                minutes = 60 - self.start_mins + self.end_mins
                hours = self.end_hrs - self.start_hrs - 1

            total_minutes = hours*60 + minutes
            print(f"Avg pace (mins/mile): {total_minutes / self.distance:.2f}")



#class instance
"Class instance: An object created from a class definition"
class_instance = RaceTime(5, 30, 7, 0, 5.0)
class_instance
#class constructor
"Class constructor: A special method named __init__ that initializes a new instance of a class"
class_constructor = RaceTime.__init__
class_constructor
# Out:
# 'Class instance: An object created from a class definition'
# 'Class constructor: A special method named __init__ that initializes a new instance of a class'
# <function __main__.RaceTime.__init__(self, start_hrs, start_mins, end_hrs, end_mins, dist)>

# %%
'''participation activity
9.6.1: Method parameters.
1)
Write the definition of an __init__ method that requires the parameters x and y.

Check

Show answer
2)
Complete the statement to create a new instance of Widget with p1=15 and p2=5.
class Widget:
    def __init__(self, p1, p2):
        # ...

widg = 


Check

Show answer'''
def participation_activity_9_6_1():
    print("1) def __init__(self, x, y)")
    print("2) Widget(p1=15, p2=5)")
participation_activity_9_6_1()
# Out:
# 'participation activity\n9.6.1: Method parameters.\n1)\nWrite the definition of an __init__ method that requires the parameters x and y.\n\nCheck\n\nShow answer\n2)\nComplete the statement to create a new instance of Widget with p1=15 and p2=5.\nclass Widget:\n    def __init__(self, p1, p2):\n        # ...\n\nwidg = \n\n\nCheck\n\nShow answer'
# 1) def __init__(self, x, y)
# 2) Widget(p1=15, p2=5)

# %%
ohokay='''Constructor parameters can have default values like any other function using the name=value syntax. Default parameter values may indicate the default state of an instance. A programmer might then use constructor arguments only to modify the default state if necessary. Ex: The Employee class constructor in the program below uses default values that represent a typical new employee's wage and scheduled hours per week.

Figure 9.6.3: Constructor default parameters.
class Employee:
    def __init__(self, name, wage=8.25, hours=20):
        """
        Default employee is part time (20 hours/week)
        and earns minimum wage
        """
        self.name = name
        self.wage = wage
        self.hours = hours

    # ...


todd = Employee("Todd")  # Typical part-time employee
jason = Employee("Jason")  # Typical part-time employee
tricia = Employee("Tricia", 12.50, 40)  # Manager employee

employees = [todd, jason, tricia]

for e in employees:
    print (f"{e.name} earns {e.wage*e.hours:.2f} per week")
Todd earns 165.00 per week
Jason earns 165.00 per week
Tricia earns 500.00 per week

Feedback?
Similar to calling functions, default parameter values can be mixed with positional and name-mapped arguments in an instantiation operation. Arguments without default values are required, must come first, and must be in order. The following arguments with default values are optional and can appear in any order.'''

setin("Todd", "Jason", "Tricia", "12.50", "40")
def figure_9_6_3():
    class Employee:
        def __init__(self, name, wage=8.25, hours=20):
            self.name = name
            self.wage = wage
            self.hours = hours

    todd = Employee("Todd")  # Typical part-time employee
    jason = Employee("Jason")  # Typical part-time employee
    tricia = Employee("Tricia", 12.50, 40)  # Manager employee

    employees = [todd, jason, tricia]

    for e in employees:
        print (f"{e.name} earns {e.wage*e.hours:.2f} per week")
figure_9_6_3()
# Out:
# Todd earns 165.00 per week
# Jason earns 165.00 per week
# Tricia earns 500.00 per week

# %%
class BeachBall:
    def __init__(self, color="white", size=1):
        self.color = color
        self.size = size
    def print_BeachBall(self):
        print(f"BeachBall color: {self.color}, size: {self.size}")

ball1 = BeachBall()
ball1

ball2 = BeachBall("red", 3)
ball2

ball1.print_BeachBall()
ball2.print_BeachBall()

ball1.color, ball1.size
ball2.color, ball2.size
# Out:
# BeachBall color: white, size: 1
# BeachBall color: red, size: 3
# ('white', 1)
# ('red', 3)

# %%
'''participation activity
9.6.2: Default constructor parameters.
Consider the class definition below. Match the instantiations of Student to the matching list of attributes.

class Student:
    def __init__(self, name, grade=9, honors=False, athletics=False):
        self.name = name
        self.grade = grade
        self.honors = honors
        self.athletics = athletics

    # ...
How to use this tool

Student("Tommy")
Student("Johnny", grade=11, honors=True)
Student("Johnny", grade=11, athletics=False)
Student("Tommy", grade=9, honors=True, athletics=True)

1.self.name: "Tommy", self.grade: 9, self.honors: False, self.athletics: False
2.self.name: "Tommy", self.grade: 9, self.honors: True, self.athletics: True
3.self.name: "Johnny", self.grade:11, self.honors: False, self.athletics: False
4.self.name: "Johnny", self.grade: 11, self.honors: True, self.athletics: False

Reset

Feedback?'''
def participation_activity_9_6_2():
    print("1. Student(\"Tommy\")","->", "self.name: \"Tommy\", self.grade: 9, self.honors: False, self.athletics: False")
    print("2. Student(\"Tommy\", grade=9, honors=True, athletics=True)","->", "self.name: \"Tommy\", self.grade: 9, self.honors: True, self.athletics: True")
    print("3. Student(\"Johnny\", grade=11, athletics=False)","->", "self.name: \"Johnny\", self.grade: 11, self.honors: False, self.athletics: False")
    print("4. Student(\"Johnny\", grade=11, honors=True)","->", "self.name: \"Johnny\", self.grade: 11, self.honors: True, self.athletics: False")
participation_activity_9_6_2()
# Out:
# 'participation activity\n9.6.2: Default constructor parameters.\nConsider the class definition below. Match the instantiations of Student to the matching list of attributes.\n\nclass Student:\n    def __init__(self, name, grade=9, honors=False, athletics=False):\n        self.name = name\n        self.grade = grade\n        self.honors = honors\n        self.athletics = athletics\n\n    # ...\nHow to use this tool\n\nStudent("Tommy")\nStudent("Johnny", grade=11, honors=True)\nStudent("Johnny", grade=11, athletics=False)\nStudent("Tommy", grade=9, honors=True, athletics=True)\n\n1.self.name: "Tommy", self.grade: 9, self.honors: False, self.athletics: False\n2.self.name: "Tommy", self.grade: 9, self.honors: True, self.athletics: True\n3.self.name: "Johnny", self.grade:11, self.honors: False, self.athletics: False\n4.self.name: "Johnny", self.grade: 11, self.honors: True, self.athletics: False\n\nReset\n\nFeedback?'
# ...

# %%
class Student:
    def __init__(self, name, grade=9, honors=False, athletics=False):
        self.name = name
        self.grade = grade
        self.honors = honors
        self.athletics = athletics
#student1 = Student("Tommy")
#student1.name, student1.grade, student1.honors, student1.athletics
#student2 = Student("Johnny", grade=11, honors=True)
#student2.name, student2.grade, student2.honors, student2.athletics
#student3 = Student("Johnny", grade=11, athletics=False)
#student3.name, student3.grade, student3.honors, student3.athletics
#student4 = Student("Tommy", grade=9, honors=True, athletics=True)
#student4.name, student4.grade, student4.honors, student4.athletics
def helper(instance):
    print(instance.name, instance.grade, instance.honors, instance.athletics)
student1 = Student("Tommy")
helper(student1)
student2 = Student("Johnny", grade=11, honors=True)
helper(student2)
student3 = Student("Johnny", grade=11, athletics=False)
helper(student3)
student4 = Student("Tommy", grade=9, honors=True, athletics=True)
helper(student4)

__

"askdjfhaskljfhasjklf, meow :3"
# Out:
# Tommy 9 False False
# Johnny 11 True False
# Johnny 11 False False
# Tommy 9 True True
# '--------------------'
# 'askdjfhaskljfhasjklf, meow :3'

# %%
'''challenge activity
9.6.1: Constructor customization.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

rectangle1 = Rectangle(1, 11)
rectangle2 = Rectangle(7, 14)

print(rectangle1.length)
print(rectangle2.length)
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_6_1_1():
    class Rectangle:
        def __init__(self, length, width):
            self.length = length
            self.width = width

    rectangle1 = Rectangle(1, 11)
    rectangle2 = Rectangle(7, 14)

    print(rectangle1.length)  # Output: 1
    print(rectangle2.length)  # Output: 7
challenge_activity_9_6_1_1()
'''challenge activity
9.6.1: Constructor customization.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Rectangle:
    def __init__(self, length=7, width=10):
        self.length = length
        self.width = width

rectangle1 = Rectangle(11, 1)
rectangle2 = Rectangle()
rectangle3 = Rectangle(12)

print(rectangle2.width)
print(rectangle1.width)
print(rectangle3.length)
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_6_1_2():
    class Rectangle:
        def __init__(self, length=7, width=10):
            self.length = length
            self.width = width

    rectangle1 = Rectangle(11, 1)
    rectangle2 = Rectangle()
    rectangle3 = Rectangle(12)

    print(rectangle2.width)  # Output: 10
    print(rectangle1.width)  # Output: 1
    print(rectangle3.length)  # Output: 12
challenge_activity_9_6_1_2()
'''challenge activity
9.6.1: Constructor customization.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Rectangle:
    def __init__(self, color, length=5, width=6):
        self.color = color
        self.length = length
        self.width = width

rectangle1 = Rectangle("purple", 10)
rectangle2 = Rectangle("white")
rectangle3 = Rectangle("yellow", 6, 7)

print(rectangle1.color)
print(rectangle1.width)
print(rectangle2.width)
print(rectangle3.width)
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_6_1_3():
    class Rectangle:
        def __init__(self, color, length=5, width=6):
            self.color = color
            self.length = length
            self.width = width

    rectangle1 = Rectangle("purple", 10)
    rectangle2 = Rectangle("white")
    rectangle3 = Rectangle("yellow", 6, 7)

    print(rectangle1.color)  # Output: purple
    print(rectangle1.width)  # Output: 6
    print(rectangle2.width)  # Output: 6
    print(rectangle3.width)  # Output: 7
challenge_activity_9_6_1_3()
'''challenge activity
9.6.1: Constructor customization.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Rectangle:
    def __init__(self, color, length=6, width=5):
        self.color = color
        self.length = length
        self.width = width

rectangle1 = Rectangle("green")
rectangle2 = Rectangle("black", length=4, width=12)
rectangle3 = Rectangle("brown", width=8, length=3)

print(rectangle1.length, rectangle1.width)
print(rectangle2.length, rectangle2.width)
print(rectangle3.length, rectangle3.width)
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_6_1_4():
    class Rectangle:
        def __init__(self, color, length=6, width=5):
            self.color = color
            self.length = length
            self.width = width

    rectangle1 = Rectangle("green")
    rectangle2 = Rectangle("black", length=4, width=12)
    rectangle3 = Rectangle("brown", width=8, length=3)

    print(rectangle1.length, rectangle1.width)  # Output: 6 5
    print(rectangle2.length, rectangle2.width)  # Output: 4 12
    print(rectangle3.length, rectangle3.width)  # Output: 3 8
challenge_activity_9_6_1_4()
# Out:
# "challenge activity\n9.6.1: Constructor customization.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program's output\n\nclass Rectangle:\n    def __init__(self, length, width):\n        self.length = length\n        self.width = width\n\nrectangle1 = Rectangle(1, 11)\nrectangle2 = Rectangle(7, 14)\n\nprint(rectangle1.length)\nprint(rectangle2.length)\n1\n2\n3\n4\nCheck\nNext\n1\n2\n3\n4\n\nFeedback?"
# 1
# 7
# "challenge activity\n9.6.1: Constructor customization.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program's output\n\nclass Rectangle:\n    def __init__(self, length=7, width=10):\n        self.length = length\n        self.width = width\n\nrectangle1 = Rectangle(11, 1)\nrectangle2 = Rectangle()\nrectangle3 = Rectangle(12)\n\nprint(rectangle2.width)\nprint(rectangle1.width)\nprint(rectangle3.length)\n1\n2\n3\n4\nCheck\nNext\n1\n2\n3\n4\n\nFeedback?"
# 10
# 1
# 12
# ...

# %%
'''challenge activity

## 

9.6.2: Defining a class constructor.

_fullscreen_

Full screen

712910.5105864.qx3zqy7

Organize the lines of code to define a constructor with parameters self, num\_mins, and num\_messages. num\_mins and num\_messages should have a default value of 0.

Ex: If the input is:

`200`  
`300`

then the output is:

`My plan... Mins: 200 Messages: 300`  
`Dad's plan... Mins: 0 Messages: 0`  
`Mom's plan... Mins: 500 Messages: 0`

Note: Not all lines of code on the left should be used in the final solution.

_keyboard\_arrow\_down_

How to use this tool

#### Unused

self.num\_mins = num\_mins

def \_\_init\_\_(self, num\_mins=0, num\_messages=0):

self.num\_mins = 0

def \_\_init\_\_(self, num\_mins, num\_messages):

self.num\_messages = num\_messages

self.num\_messages = 0

#### main.py

Load default template...

class PhonePlan: \# FIXME: Add constructor

def print\_plan(self): print(f"Mins: {self.num\_mins}", end=" ") print(f"Messages: {self.num\_messages}") my\_plan = PhonePlan(int(input()), int(input())) dads\_plan = PhonePlan() moms\_plan = PhonePlan(500) print("My plan...", end=" ") my\_plan.print\_plan() print("Dad's plan...", end=" ") dads\_plan.print\_plan() print("Mom's plan...", end= " ") moms\_plan.print\_plan()

Check

Feedback?

'''
setin("200", "300")
def challenge_activity_9_6_2_1():
    class PhonePlan:
        #FIXME: Add constructor

        def __init__(self, num_mins=0, num_messages=0): #<- 
            self.num_mins = num_mins #<-
            self.num_messages = num_messages #<-
        
        #
        def print_plan(self):
            print(f"Mins: {self.num_mins}", end=" ")
            print(f"Messages: {self.num_messages}")
        
    my_plan = PhonePlan(int(input()), int(input()))
    dads_plan = PhonePlan()
    moms_plan = PhonePlan(500)

    print("My plan...", end=" ")
    my_plan.print_plan()  # Output: Mins: 200 Messages: 300
    print("Dad's plan...", end=" ")
    dads_plan.print_plan()  # Output: Mins: 0 Messages: 0
    print("Mom's plan...", end= " ")
    moms_plan.print_plan()  # Output: Mins: 500 Messages: 0
challenge_activity_9_6_2_1()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipykernel_21732/3779628723.py:1: SyntaxWarning: invalid escape sequence '\_'
#   '''challenge activity
# ...

# %%
'''challenge activity
9.6.3: Class constructors.
712910.5105864.qx3zqy7

Jump to level 1
The Reservation class constructor has a self parameter and three additional parameters: name, num_in_party, and preordered. Input values name1, num_in_party1, and preordered1 are read representing the information of a reservation. Instantiate a new instance of Reservation by assigning reservation1 with an instance of Reservation with name1 as name, num_in_party1 as num_in_party, and preordered1 as preordered.

Click here for example
Ex: If the input is:
Svetlana
3
no preorder
then the output is:

reservation1 data: Svetlana, 3 guests, Food preordered: no preorder
name1 = input()
num_in_party1 = int(input())
preordered1 = input()

""" Your code goes here """

print(f"reservation1 data: {reservation1.name}, {reservation1.num_in_party} guests, Food preordered: {reservation1.preordered}")


 

1

2

3

4

Check

Next level
1
2
3
4

Feedback?
'''

def challenge_activity_9_6_3_1():
    setin("Svetlana", "3", "no preorder")
    class Reservation:
        def __init__(self, name, num_in_party, preordered):
            self.name = name
            self.num_in_party = num_in_party
            self.preordered = preordered

    name1 = input()
    num_in_party1 = int(input())
    preordered1 = input()

    reservation1 = Reservation(name1, num_in_party1, preordered1) #<-

    print(f"reservation1 data: {reservation1.name}, {reservation1.num_in_party} guests, Food preordered: {reservation1.preordered}")
challenge_activity_9_6_3_1()

'''challenge activity
9.6.3: Class constructors.
712910.5105864.qx3zqy7

Jump to level 1
The Profile class constructor has a self parameter and three additional parameters: username, status, and location. profile1 is created with "maroon-wasp", "active", and "Illinois" as the values of the three attributes in that order. profile2 is created with the values of the three attributes read from input. Complete the constructor so the instance attributes are assigned.

Click here for example
Ex: If the input is:
brown-tortoise
active
New Mexico
then the output is:

profile1 data: user maroon-wasp, active, located in Illinois
profile2 data: user brown-tortoise, active, located in New Mexico

1

2

3

4

Check

Next level
1
2
3
4

Feedback?

```
class Profile:
    def __init__(self, username, status, location):

        """ Your code goes here """

username2 = input()
status2 = input()
location2 = input()

profile1 = Profile("maroon-wasp", "active", "Illinois")
profile2 = Profile(username2, status2, location2)

print(f"profile1 data: user {profile1.username}, {profile1.status}, located in {profile1.location}")
print(f"profile2 data: user {profile2.username}, {profile2.status}, located in {profile2.location}")
```'''

def challenge_activity_9_6_3_2():
    setin("brown-tortoise", "active", "New Mexico")
    class Profile:
        def __init__(self, username, status, location):
            self.username = username
            self.status = status
            self.location = location
    username2 = input()
    status2 = input()
    location2 = input()
    profile1 = Profile("maroon-wasp", "active", "Illinois")
    profile2 = Profile(username2, status2, location2)

    print(f"profile1 data: user {profile1.username}, {profile1.status}, located in {profile1.location}")
    print(f"profile2 data: user {profile2.username}, {profile2.status}, located in {profile2.location}")
challenge_activity_9_6_3_2()

'''challenge activity
9.6.3: Class constructors.
712910.5105864.qx3zqy7

Jump to level 1
Write an __init__ method that requires three parameters in addition to the self parameter:

The first parameter has no default value.
The second parameter has 0 as the default value.
The third parameter has "No data" as the default value.
In the __init__ method, assign instance attributes:

username with the first parameter.
age with the second parameter.
location with the third parameter.
Click here for example
 

1

2

3

4

Check

Next level
1
2
3
4

Feedback?

```
class Profile:

    """ Your code goes here """

username2 = input()
age2 = int(input())
location2 = input()

default_profile = Profile("green-elk")
profile2 = Profile(username2, age2, location2)

print(f"Default profile data: user {default_profile.username}, {default_profile.age} years old, located in {default_profile.location}")
print(f"profile2 data: user {profile2.username}, {profile2.age} years old, located in {profile2.location}")
```
'''
def challenge_activity_9_6_3_3():
    setin("blue-fox", "25", "Florida")
    class Profile:
        def __init__(self, username, age=0, location="No data"):
            self.username = username
            self.age = age
            self.location = location

    username2 = input()
    age2 = int(input())
    location2 = input()

    default_profile = Profile("green-elk")
    profile2 = Profile(username2, age2, location2)

    print(f"Default profile data: user {default_profile.username}, {default_profile.age} years old, located in {default_profile.location}")
    print(f"profile2 data: user {profile2.username}, {profile2.age} years old, located in {profile2.location}")
challenge_activity_9_6_3_3()

'''challenge activity
9.6.3: Class constructors.
712910.5105864.qx3zqy7

Jump to level 1
Input values num_checked_bags1, plane_num1 and airport_code1 are read from input, representing the number of checked bags, plane number, and airport code of a passenger. Complete the following tasks:

Assign passenger1 with an instance of Passenger with num_checked_bags1, plane_num1 and airport_code1 as attributes in that order.
Call passenger1's print_data().
Call passenger1's lost_checked_bag().
Call passenger1's print_data() again.
Click here for example
Ex: If the input is:
4
4001
SFO
then the output is:

Passenger data: 4 checked bags, Flight #4001, flying to SFO
Passenger data: 3 checked bags, Flight #4001, flying to SFO
  

1

2

3

4

Check

Next level
1
2
3
4

Feedback?

```
class Passenger:
    def __init__(self, num_checked_bags, plane_num, airport_code): 
        self.num_checked_bags = num_checked_bags
        self.plane_num = plane_num
        self.airport_code = airport_code

    def lost_checked_bag(self):
        self.num_checked_bags -= 1

    def print_data(self):
        print(f"Passenger data: {self.num_checked_bags} checked bags, Flight #{self.plane_num}, flying to {self.airport_code}")

num_checked_bags1 = int(input())
plane_num1 = int(input())
airport_code1 = input()

""" Your code goes here """

```'''
def challenge_activity_9_6_3_4():
    setin("4", "4001", "SFO")
    class Passenger:
        def __init__(self, num_checked_bags, plane_num, airport_code): 
            self.num_checked_bags = num_checked_bags
            self.plane_num = plane_num
            self.airport_code = airport_code

        def lost_checked_bag(self):
            self.num_checked_bags -= 1

        def print_data(self):
            print(f"Passenger data: {self.num_checked_bags} checked bags, Flight #{self.plane_num}, flying to {self.airport_code}")

    num_checked_bags1 = int(input())
    plane_num1 = int(input())
    airport_code1 = input()

    passenger1 = Passenger(num_checked_bags1, plane_num1, airport_code1) #<-

    passenger1.print_data()  # Output: Passenger data: 4 checked bags, Flight #4001, flying to SFO
    passenger1.lost_checked_bag()
    passenger1.print_data()  # Output: Passenger data: 3 checked bags, Flight #4001, flying to SFO
challenge_activity_9_6_3_4()
# Out:
# 'challenge activity\n9.6.3: Class constructors.\n712910.5105864.qx3zqy7\n\nJump to level 1\nThe Reservation class constructor has a self parameter and three additional parameters: name, num_in_party, and preordered. Input values name1, num_in_party1, and preordered1 are read representing the information of a reservation. Instantiate a new instance of Reservation by assigning reservation1 with an instance of Reservation with name1 as name, num_in_party1 as num_in_party, and preordered1 as preordered.\n\nClick here for example\nEx: If the input is:\nSvetlana\n3\nno preorder\nthen the output is:\n\nreservation1 data: Svetlana, 3 guests, Food preordered: no preorder\nname1 = input()\nnum_in_party1 = int(input())\npreordered1 = input()\n\n""" Your code goes here """\n\nprint(f"reservation1 data: {reservation1.name}, {reservation1.num_in_party} guests, Food preordered: {reservation1.preordered}")\n\n\n\n\n1\n\n2\n\n3\n\n4\n\nCheck\n\nNext level\n1\n2\n3\n4\n\nFeedback?\n'
# Svetlana
# 3
# ...

# %%
#should i put set ins inside or outside?
#i think inside is better because it keeps the code more organized and easier to read.
#okay

# %% [markdown]
# ## 9.7 Class interfaces
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/7

# %%
ohokay='''9.7 Class interfaces
A class usually contains a set of methods that a programmer interacts with. For example, the class RaceTime might contain the instance methods print_time() and print_pace() that a programmer calls to print output. A class interface consists of the methods that a programmer calls to create, modify, or access a class instance. The figure below shows the class interface of the RaceTime class, which consists of the __init__ constructor and the print_time() and print_pace() methods.

Figure 9.7.1: A class interface consists of methods to interact with an instance.
class RaceTime:
    def __init__(self, start_time, end_time, distance):
        # ...

    def print_time(self):
        # ...

    def print_pace(self):
        # ...

Feedback?
A class may also contain methods used internally that a user of the class need not access. For example, consider if the RaceTime class contains a separate method _diff_time() used by print_time() and print_pace() to find the total number of minutes to complete the race. A programmer using the RaceTime class does not need to use the _diff_time() function directly; thus, _diff_time() does not need to be a part of the class interface. Good practice is to prepend an underscore to methods only used internally by a class. The underscore is a widely recognized convention but otherwise has no special syntactic meaning. A programmer could still call the method, e.g. time1._diff_time(), though such usage should be unnecessary if the class interface is well-designed.

Figure 9.7.2: Internal instance methods.
RaceTime class with internal instance method usage and definition highlighted.

class RaceTime:
    def __init__(self, start_hrs, start_mins, end_hrs, end_mins, dist):
        self.start_hrs = start_hrs
        self.start_mins = start_mins
        self.end_hrs = end_hrs
        self.end_mins = end_mins
        self.distance = dist

    def print_time(self):
        total_time = self._diff_time()
        print(f"Time to complete race: {total_time[0]}:{total_time[1]}")

    def print_pace(self):
        total_time = self._diff_time()
        total_minutes = total_time[0]*60 + total_time[1]
        print(f"Avg pace (mins/mile): {total_minutes / self.distance:.2f}")

    def _diff_time(self):
        """Calculate total race time. Returns a 2-tuple (hours, minutes)"""
        if self.end_mins >= self.start_mins:
            minutes = self.end_mins - self.start_mins
            hours = self.end_hrs - self.start_hrs
        else:
            minutes = 60 - self.start_mins + self.end_mins
            hours = self.end_hrs - self.start_hrs - 1

        return (hours, minutes)


distance = 5.0

start_hrs = int(input("Enter starting time hours: "))
start_mins = int(input("Enter starting time minutes: "))
end_hrs = int(input("Enter ending time hours: "))
end_mins = int(input("Enter ending time minutes: "))

race_time = RaceTime(start_hrs, start_mins, end_hrs, end_mins, distance)

race_time.print_time()
race_time.print_pace()
Enter starting time hours: 5
Enter starting time minutes: 30
Enter ending time hours: 7
Enter ending time minutes: 0
Time to complete race: 1:30
Average pace (mins/mile): 18.00
...
Enter starting time hours: 9
Enter starting time minutes: 30
Enter ending time hours: 10
Enter ending time minutes: 3
Time to complete race: 0:33
Avg pace (mins/mile): 6.60

Feedback?
A class can be used to implement the computing concept known as an abstract data type (ADT), whose creation and update are constrained to specific, well-defined operations (the class interface). A key aspect of an ADT is that the internal implementation of the data and operations are hidden from the user, a concept known as information hiding, which allows the ADT user to be more productive by focusing on higher-level concepts. Information hiding also allows the ADT developer to improve the internal implementation without requiring changes to programs using the ADT. In the previous example, a RaceTime ADT was defined that captured the number of hours and minutes to complete a race, and that presents a well-defined set of operations to create (via __init__) and view (via print_time and print_pace) the data.

Programmers commonly refer to separating an object's interface from its implementation (internal methods and variables); the user of an object needs to know only the object's interface.

Python lacks the ability to truly hide information from a user of the ADT, because all attributes of a class are always accessible from the outside. Many other computing languages require methods and variables to be marked as either public (part of a class interface) or private (internal), and attempting to access private methods and variables results in an error. Python, on the other hand, is a more "trusting" language. An ADT user can always inspect, and if desired, use private variables and methods in ways unexpected by the ADT developer.'''

# %%
'''participation activity

## 

9.7.1: Class interfaces.

1)

A class interface consists of the methods that a programmer should use to modify or access the class.

True

False

2)

Internal methods used by the class should start with an underscore in their name.

True

False

3)

Internal methods cannot be called. Ex: my\_instance.\_calc() results in an error.

True

False

4)

A well-designed class separates its _interface_ from its _implementation_.

True

False

Feedback?

'''
def participation_activity_9_7_1():
    print("1) True")
    print("2) True")
    print("3) False")
    print("4) True")
participation_activity_9_7_1()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipykernel_21732/1189810852.py:1: SyntaxWarning: invalid escape sequence '\_'
#   '''participation activity
# 'participation activity\n\n## \n\n9.7.1: Class interfaces.\n\n1)\n\nA class interface consists of the methods that a programmer should use to modify or access the class.\n\nTrue\n\nFalse\n\n2)\n\nInternal methods used by the class should start with an underscore in their name.\n\nTrue\n\nFalse\n\n3)\n\nInternal methods cannot be called. Ex: my\\_instance.\\_calc() results in an error.\n\nTrue\n\nFalse\n\n4)\n\nA well-designed class separates its _interface_ from its _implementation_.\n\nTrue\n\nFalse\n\nFeedback?\n\n'
# 1) True
# 2) True
# 3) False
# 4) True

# %%
def figure_9_7_2():
    setin("5", "30", "7", "00")
    class RaceTime:
        def __init__(self, start_hrs, start_mins, end_hrs, end_mins, dist):
            self.start_hrs = start_hrs
            self.start_mins = start_mins
            self.end_hrs = end_hrs
            self.end_mins = end_mins
            self.distance = dist

        def print_time(self):
            total_time = self._diff_time()
            print(f"Time to complete race: {total_time[0]}:{total_time[1]}")

        def print_pace(self):
            total_time = self._diff_time()
            total_minutes = total_time[0]*60 + total_time[1]
            print(f"Avg pace (mins/mile): {total_minutes / self.distance:.2f}")

        def _diff_time(self):
            """Calculate total race time. Returns a 2-tuple (hours, minutes)"""
            if self.end_mins >= self.start_mins:
                minutes = self.end_mins - self.start_mins
                hours = self.end_hrs - self.start_hrs
            else:
                minutes = 60 - self.start_mins + self.end_mins
                hours = self.end_hrs - self.start_hrs - 1

            return (hours, minutes)


    distance = 5.0

    start_hrs = int(input("Enter starting time hours: "))
    start_mins = int(input("Enter starting time minutes: "))
    end_hrs = int(input("Enter ending time hours: "))
    end_mins = int(input("Enter ending time minutes: "))

    race_time = RaceTime(start_hrs, start_mins, end_hrs, end_mins, distance)

    race_time.print_time()
    race_time.print_pace()
figure_9_7_2()
# Out:
# Enter starting time hours: 5
# Enter starting time minutes: 30
# Enter ending time hours: 7
# Enter ending time minutes: 00
# Time to complete race: 1:30
# Avg pace (mins/mile): 18.00

# %%
def figure_9_7_2_scratch():
    setin("5", "30", "7", "00")
    class RaceTime:
        def __init__(self, start_hrs, start_mins, end_hrs, end_mins, dist):
            self.start_hrs = start_hrs
            self.start_mins = start_mins
            self.end_hrs = end_hrs
            self.end_mins = end_mins
            self.distance = dist

        def print_time(self):
            total_time = self._diff_time()
            print(f"Time to complete race: {total_time[0]}:{total_time[1]}")

        def print_pace(self):
            total_time = self._diff_time()
            total_minutes = total_time[0]*60 + total_time[1]
            print(f"Avg pace (mins/mile): {total_minutes / self.distance:.2f}")

        def _diff_time(self):
            """Calculate total race time. Returns a 2-tuple (hours, minutes)"""
            if self.end_mins >= self.start_mins:
                minutes = self.end_mins - self.start_mins
                hours = self.end_hrs - self.start_hrs
            else:
                minutes = 60 - self.start_mins + self.end_mins
                hours = self.end_hrs - self.start_hrs - 1

            return (hours, minutes)


    distance = 5.0

    start_hrs = int(input("Enter starting time hours: "))
    start_mins = int(input("Enter starting time minutes: "))
    end_hrs = int(input("Enter ending time hours: "))
    end_mins = int(input("Enter ending time minutes: "))

    race_time = RaceTime(start_hrs, start_mins, end_hrs, end_mins, distance)

    race_time.print_time()
    race_time.print_pace()

    # Testing internal method
    print("Testing internal method _diff_time():")
    print(race_time._diff_time())  # Output should be (1, 30) for the given input

    # class interface
    print("Class interface:")
    print(f"Start time: {race_time.start_hrs}:{race_time.start_mins}")
    print(f"End time: {race_time.end_hrs}:{race_time.end_mins}")
    print(f"Distance: {race_time.distance} miles")

    # internal instance variables
    print("Internal instance variables:")
    print(f"Start hours: {race_time.start_hrs}")
    print(f"Start minutes: {race_time.start_mins}")
    print(f"End hours: {race_time.end_hrs}")
    print(f"End minutes: {race_time.end_mins}")

    

figure_9_7_2_scratch()
# Out:
# Enter starting time hours: 5
# Enter starting time minutes: 30
# Enter ending time hours: 7
# Enter ending time minutes: 00
# Time to complete race: 1:30
# Avg pace (mins/mile): 18.00
# Testing internal method _diff_time():
# (1, 30)
# Class interface:
# Start time: 5:30
# End time: 7:0
# Distance: 5.0 miles
# Internal instance variables:
# Start hours: 5
# Start minutes: 30
# End hours: 7
# End minutes: 0

# %%
class IamClass:
    def __init__(self, name):
        self.name = name
    def print_name(self):
        print(f"My name is {self.name}")
instance1 = IamClass("Alice")
instance1.print_name()  # Output: My name is Alice
# Out:
# My name is Alice

# %%
class IamClass:
    def __init__(self,param1, param2=0, param3="No data"):
        self.param1 = param1
        self.param2 = param2
        self.param3 = param3
    def public_method1(self):
        print(f"param1: {self.param1}, param2: {self.param2}, param3: {self.param3}")
    def _internal_method(self):
        print("This is an internal method")
        1+1
        2+2
        3+3
        pass
instance2 = IamClass("Value1", 10, "Value3")
instance2.public_method1()  # Output: param1: Value1, param2: 10, param3: Value3
instance2._internal_method()  # Output: This is an internal method
# Out:
# param1: Value1, param2: 10, param3: Value3
# This is an internal method

# %%
class IamClass:
    def __init__(self, name):
        self.name = name
    def _internal_method(self):
        print("This is an internal method")
    def __another_internal_method(self):
        print("This is another internal method")
instance3 = IamClass("Bob")
instance3._internal_method()  # Output: This is an internal method
# instance3.__another_internal_method()  # This will raise an AttributeError because of name mangling


#oh okay
# Out:
# This is an internal method

# %% [markdown]
# ## 9.8 Class customization
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/8

# %%
ohokay='''## 9.8 Class customization

Class customization is the process of defining how an instance of a class should behave for some common operations. Such operations might include printing, accessing attributes, or how instances of that class are compared to each other. To customize a class, a programmer implements instance methods with special method names that the Python interpreter recognizes. Ex: To change how a class instance object is printed, the special __str__() method can be defined, as illustrated below.

> **Implementing __str__() alters how the class is printed.**
> | class Toy:     def __init__(self, name, price, min_age):         self.name = name         self.price = price         self.min_age = min_age   truck = Toy("Monster Truck XX", 14.99, 5) print(truck) |
> | `<__main__.Toy instance at 0xb74cb98c>` |
> | class Toy:     def __init__(self, name, price, min_age):         self.name = name         self.price = price         self.min_age = min_age      def __str__(self):         return (f"{self.name} costs only ${self.price:.2f}. Not for children under {self.min_age}!")  truck = Toy("Monster Truck XX", 14.99, 5) print(truck) |
> | `Monster Truck XX costs only $14.99. Not for children under 5!` |

The left program prints a default string for the class instance. The right program implements __str__(), generating a custom message using some instance attributes.

Run the tool below, which visualizes the execution of the above example. When `print(truck)` is evaluated, the __str__() method is called.

**PythonTutor: Implementing __str__() alters how the class is printed.**

```python
class Toy:
    def __init__(self, name, price, min_age):
        self.name = name
        self.price = price
        self.min_age = min_age

    def __str__(self):
        return (f"{self.name} costs only ${self.price:.2f}. Not for children under {self.min_age}!")

truck = Toy("Monster Truck XX", 14.99, 5)
print(truck)
```

- An instance of the Toy class is created, with some values to initialize the instance attributes.
    - Printing the instance directly via print(truck) calls the overloaded __str__ method.

### LAB ACTIVITY: Customization of printing a class instance.

The following class represents a vehicle for sale in a used-car lot. Add a __str__() method so that printing an instance of Car displays a string in the following format:

```
1989 Chevrolet Blazer:
  Mileage: 115000
  Sticker price: $3250
```

```python
class Car:
    def __init__(self, make, model, year, miles, price):
        self.make = make
        self.model = model
        self.year = year
        self.miles = miles
        self.price = price

    def __str__(self):
        ret_str = f"{self.year} {self.make} {self.model}:\n"
        ret_str += f"  Mileage: {self.miles}\n"
        ret_str += f"  Sticker price: ${self.price}"
        return ret_str

cars = []
cars.append(Car("Ford", "Mustang", 2013, 25000, 37999))
cars.append(Car("Nissan", "Xterra", 2004, 89500, 7500))
cars.append(Car("Nissan", "Maxima", 2012, 25000, 15750))

for car in cars:
    print(car)
```

Class customization can redefine the functionality of built-in operators like =, +, -, and * when used with class instances, a technique known as operator overloading. 

The below code shows overloading of the less-than (<) operator of the Time class by defining a method with the __lt__ special method name.

> **Overloading the less than operator of the Time class allows for comparison of instances.**
> ```python
> class Time:
>     def __init__(self, hours, minutes):
>         self.hours = hours
>         self.minutes = minutes
> 
>     def __str__(self):
>         return f"{self.hours}:{self.minutes:02d}"
> 
>     def __lt__(self, other):
>         if self.hours < other.hours:
>             return True
>         elif self.hours == other.hours:
>             if self.minutes < other.minutes:
>                 return True
>         return False
> 
> num_times = 3
> times = []
> 
> # Obtain times from user input
> for i in range(num_times):
>     user_input = input("Enter time (Hrs:Mins): ")
>     tokens = user_input.split(":")
>     times.append(Time(int(tokens[0]), int(tokens[1])))
> 
> min_time = times[0]
> for t in times:
>     if t < min_time :
>         min_time = t
> 
> print(f"\nEarliest time is {min_time}")
> ```
> ```
> Enter time (Hrs:Mins): 10:40
> Enter time (Hrs:Mins): 12:15
> Enter time (Hrs:Mins): 9:15
> 
> Earliest time is 9:15
> ```

In the above program, the Time class contains a definition for the __lt__ method, which overloads the < operator. When the comparison `t < min_time` is evaluated, the __lt__ method is automatically called. The self parameter of __lt__ is bound to the left operand, t, and the other parameter is bound to the right operand, min_time. Returning True indicates that t is indeed less than min_time, and returning False indicates that t equal to or greater than min_time.

Methods like `__lt__` above are known as rich comparison methods. The following table describes rich comparison methods and the corresponding relational operator that is overloaded.

> **Rich comparison methods.**
> | Rich comparison method | Overloaded operator |
> | --- | --- |
> | __lt__(self, other) | less than (<) |
> | __le__(self, other) | less than or equal to (<=) |
> | __gt__(self, other) | greater than (>) |
> | __ge__(self, other) | greater than or equal to (>=) |
> | __eq__(self, other) | equal to (==) |
> | __ne__(self, other) | not equal to (!=) |

### LAB ACTIVITY: Rich comparisons for a quarterback class.

Complete the __gt__ method. A quarterback is considered greater than another only if that quarterback has more wins and a higher quarterback passer rating.

Once __gt__ is complete, compare Tom Brady's 2007 stats as well (4,806 yards; 50 touchdowns; 398 completions; 578 attempts; 8 interceptions; 16 wins).

More advanced usage of class customization is possible, such as customizing how a class accesses or sets its attributes. Such advanced topics are out of scope for this material; however, students are encouraged to explore the links at the end of the section for a complete list of class customizations and special method names.

```
class Quarterback:
    def __init__(self, yrds, tds, cmps, atts, ints, wins):
        self.wins = wins

        # Calculate quarterback passer rating (NCAA)
        self.rating = ((8.4 * yrds) + (330 * tds) + (100 * cmps) -
                       (200 * ints)) / atts

    def __lt__(self, other):
        if (self.rating < other.rating) or (self.wins < other.wins):
            return True
        return False

    def __gt__(self, other):
        if (self.rating > other.rating) and (self.wins > other.wins):
            return True
        return False

peyton = Quarterback(yrds=4700, atts=679, cmps=450, tds=33, ints=17, wins=10)
eli = Quarterback(yrds=4002, atts=539, cmps=339, tds=31, ints=25, wins=9)

if peyton > eli:
    print("Peyton is the better QB")
elif peyton < eli:
    print("Eli is the better QB")
else:
    print("It is not clear who the better QB is...")```'''

# %%
def figure_9_8_1_1():
    class Toy:
        def __init__(self, name, price, min_age):
            self.name = name
            self.price = price
            self.min_age = min_age

    truck = Toy("Monster Truck XX", 14.99, 5)
    print(truck)
figure_9_8_1_1()

def figure_9_8_1_2():
    class Toy:
        def __init__(self, name, price, min_age):
            self.name = name
            self.price = price
            self.min_age = min_age

        def __str__(self):
            return (f"{self.name} costs only ${self.price:.2f}. Not for children under {self.min_age}!")

    truck = Toy("Monster Truck XX", 14.99, 5)
    print(truck)
figure_9_8_1_2()

def python_tutor_implementing_str():
    class Toy:
        def __init__(self, name, price, min_age):
            self.name = name
            self.price = price
            self.min_age = min_age

        def __str__(self):
            return (f"{self.name} costs only ${self.price:.2f}. Not for children under {self.min_age}!")

    truck = Toy("Monster Truck XX", 14.99, 5)
    print(truck)
python_tutor_implementing_str()

def try_9_8_1_lab():
    class Car:
        def __init__(self, make, model, year, miles, price):
            self.make = make
            self.model = model
            self.year = year
            self.miles = miles
            self.price = price
        # FIXME: Add a __str__() method here.
        def __str__(self):
            ret_str = f"{self.year} {self.make} {self.model}:\n"
            ret_str += f"  Mileage: {self.miles}\n"
            ret_str += f"  Sticker price: ${self.price}"
            return ret_str
        #
    cars = []
    cars.append(Car("Ford", "Mustang", 2013, 25000, 37999))
    cars.append(Car("Nissan", "Xterra", 2004, 89500, 7500))
    cars.append(Car("Nissan", "Maxima", 2012, 25000, 15750))

    for car in cars:
        print(car)
try_9_8_1_lab()
def figure_9_6_2_1():
    setin("200", "300")
    class PhonePlan:
        def __init__(self, num_mins=0, num_messages=0):
            self.num_mins = num_mins
            self.num_messages = num_messages
        
        def print_plan(self):
            print(f"Mins: {self.num_mins}", end=" ")
            print(f"Messages: {self.num_messages}")
        
    my_plan = PhonePlan(int(input()), int(input()))
    dads_plan = PhonePlan()
    moms_plan = PhonePlan(500)

    print("My plan...", end=" ")
    my_plan.print_plan()  # Output: Mins: 200 Messages: 300
    print("Dad's plan...", end=" ")
    dads_plan.print_plan()  # Output: Mins: 0 Messages: 0
    print("Mom's plan...", end= " ")
    moms_plan.print_plan()  # Output: Mins: 500 Messages: 0
figure_9_6_2_1()
# Out:
# <__main__.figure_9_8_1_1.<locals>.Toy object at 0x70d07ee46b70>
# Monster Truck XX costs only $14.99. Not for children under 5!
# Monster Truck XX costs only $14.99. Not for children under 5!
# 2013 Ford Mustang:
#   Mileage: 25000
#   Sticker price: $37999
# 2004 Nissan Xterra:
#   Mileage: 89500
#   Sticker price: $7500
# 2012 Nissan Maxima:
#   Mileage: 25000
#   Sticker price: $15750
# 200
# 300
# My plan... Mins: 200 Messages: 300
# Dad's plan... Mins: 0 Messages: 0
# Mom's plan... Mins: 500 Messages: 0

# %%
class Toy:
    def __init__(self, name, price, min_age):
        self.name = name
        self.price = price
        self.min_age = min_age

    def __str__(self):
        return (f"{self.name} costs only ${self.price:.2f}. Not for children under {self.min_age}!")

truck = Toy("Monster Truck XX", 14.99, 5)
print(truck)
# Out:
# Monster Truck XX costs only $14.99. Not for children under 5!

# %%
class IamClass:
    def __init__(self, *params):
        self.params = params
    def public_method(self):
        print(f"params: {self.params}")
    def _internal_method(self):
        print("This is an internal method")
instance = IamClass("Value1", "Value2", "Value3")
instance.public_method()  # Output: params: ('Value1', 'Value2', 'Value3')
instance._internal_method()  # Output: This is an internal method
# Out:
# params: ('Value1', 'Value2', 'Value3')
# This is an internal method

# %%
class IamClass:
    def __init__(self, *params):
        self.params = params
    def public_method(self):
        print(f"params: {self.params}")
    def _internal_method(self):
        print("This is an internal method")
    def __str__(self):
        #print(1,2,3)
        return f"I am a class with parameters: {self.params}"
instance = IamClass("Value1", "Value2", "Value3")
print(instance)  # Output: I am a class with parameters: ('Value1', 'Value2', 'Value3')
# Out:
# I am a class with parameters: ('Value1', 'Value2', 'Value3')

# %%
class IamMath:
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2
    def __add__(self, other):
        return self.num1 + self.num2 + other.num1 + other.num2
    def __str__(self):
        return f"I am a math class with num1: {self.num1} and num2: {self.num2}"
    def __lt__(self, other):
        return (self.num1 + self.num2) < (other.num1 + other.num2)
    def __le__(self, other):
        return (self.num1 + self.num2) <= (other.num1 + other.num2)
    def __gt__(self, other):
        return (self.num1 + self.num2) > (other.num1 + other.num2)
    def __ge__(self, other):
        return (self.num1 + self.num2) >= (other.num1 + other.num2)
    def __eq__(self, other):
        return (self.num1 + self.num2) == (other.num1 + other.num2)
    def __ne__(self, other):
        return (self.num1 + self.num2) != (other.num1 + other.num2)
    
instance1 = IamMath(1, 2)
instance2 = IamMath(3, 4)
print(instance1 + instance2)  # Output: 10 (1+2+3+4)
print(instance1 < instance2)   # Output: True (3 < 7)
print(instance1 > instance2)   # Output: False (3 > 7)
print(instance1 == instance2)   # Output: False (3 == 7)
print(instance1 != instance2)   # Output: True (3 != 7)
#print(instance1 - instance2) # This will raise an error because __sub__ is not defined
# Out:
# 10
# True
# False
# False
# True

# %%
class IamString:
    def __init__(self, text):
        self.text = text
    def __str__(self):
        return f"I am a string class with text: {self.text}"
    def __add__(self, other):
        return self.text + other.text
    def __lt__(self, other):
        return self.text < other.text
    def __le__(self, other):
        return self.text <= other.text
    def __gt__(self, other):
        return self.text > other.text
    def __ge__(self, other):
        return self.text >= other.text
    def __eq__(self, other):
        return self.text == other.text
    def __ne__(self, other):
        return self.text != other.text
instance1 = IamString("Hello")
instance2 = IamString("World")
print(instance1 + instance2)  # Output: HelloWorld
print(instance1 < instance2)   # Output: True (Hello < World)
print(instance1 > instance2)   # Output: False (Hello > World)
print(instance1 == instance2)   # Output: False (Hello == World)
print(instance1 != instance2)   # Output: True (Hello != World)
# Out:
# HelloWorld
# True
# False
# False
# True

# %%
class IamList:
    def __init__(self, *items):
        self.items = items
    def __str__(self):
        return f"I am a list class with items: {self.items}"
    def __add__(self, other):
        return self.items + other.items
    def __lt__(self, other):
        return self.items < other.items
    def __le__(self, other):
        return self.items <= other.items
    def __gt__(self, other):
        return self.items > other.items
    def __ge__(self, other):
        return self.items >= other.items
    def __eq__(self, other):
        return self.items == other.items
    def __ne__(self, other):
        return self.items != other.items
instance1 = IamList(1, 2, 3)
instance2 = IamList(4, 5, 6)

instance1.__str__()  # Output: I am a list class with items: (1, 2, 3)
print(instance1)  # Output: I am a list class with items: (1, 2, 3)

instance1,instance2

print(instance1)
print(instance2)

print(instance1 + instance2)  # Output: (1, 2, 3, 4, 5, 6)
print(instance1 < instance2)   # Output: True (1, 2, 3 < 4, 5, 6)
print(instance1 > instance2)   # Output: False (1, 2, 3 > 4, 5, 6)
print(instance1 == instance2)   # Output: False (1, 2, 3 == 4, 5, 6)
print(instance1 != instance2)   # Output: True (1, 2, 3 != 4, 5, 6)
# Out:
# 'I am a list class with items: (1, 2, 3)'
# I am a list class with items: (1, 2, 3)
# (<__main__.IamList at 0x70d07eece2a0>, <__main__.IamList at 0x70d07ee5af30>)
# I am a list class with items: (1, 2, 3)
# I am a list class with items: (4, 5, 6)
# (1, 2, 3, 4, 5, 6)
# True
# False
# False
# True

# %%
'''participation activity
9.8.1: Rich comparison methods.
Consider the following class:

class UsedCar:
    def __init__(self, price, condition):
        self.price = price
        self.condition = condition  # integer between 0-5; 0=poor condition, 5=new condition
Fill in the missing code as described in each question to complete the rich comparison methods.

1)
A car is less than another if the price is lower.
def __lt__(self, other):
    if 
:
        return True
    return False
 

Check

Show answer
2)
A car is less than or equal to another if the price is at most the same.
def __le__(self, other):
    if 
:
        return True
    return False
 

Check

Show answer
3)
A car is greater than another if the condition is better.
def __gt__(self, other):
    if 
:
        return True
    return False
 

Check

Show answer
4)
Two cars are not equivalent if either the prices or conditions don't match.
def __ne__(self, other):
    if 
:
        return True
    return False
 

Check

Show answer

Feedback?'''
def participation_activity_9_8_1():
    class UsedCar:
        def __init__(self, price, condition):
            self.price = price
            self.condition = condition  # integer between 0-5; 0=poor condition, 5=new condition

        def __lt__(self, other):
            if self.price < other.price:
                return True
            return False

        def __le__(self, other):
            if self.price <= other.price:
                return True
            return False

        def __gt__(self, other):
            if self.condition > other.condition:
                return True
            return False

        def __ne__(self, other):
            if (self.price != other.price) or (self.condition != other.condition):
                return True
            return False
participation_activity_9_8_1()
# Out:
# "participation activity\n9.8.1: Rich comparison methods.\nConsider the following class:\n\nclass UsedCar:\n    def __init__(self, price, condition):\n        self.price = price\n        self.condition = condition  # integer between 0-5; 0=poor condition, 5=new condition\nFill in the missing code as described in each question to complete the rich comparison methods.\n\n1)\nA car is less than another if the price is lower.\ndef __lt__(self, other):\n    if \n:\n        return True\n    return False\n\n\nCheck\n\nShow answer\n2)\nA car is less than or equal to another if the price is at most the same.\ndef __le__(self, other):\n    if \n:\n        return True\n    return False\n\n\nCheck\n\nShow answer\n3)\nA car is greater than another if the condition is better.\ndef __gt__(self, other):\n    if \n:\n        return True\n    return False\n\n\nCheck\n\nShow answer\n4)\nTwo cars are not equivalent if either the prices or conditions don't match.\ndef __ne__(self, other):\n    if \n:\n   
# ...

# %%
'''challenge activity
9.8.1: Enter the output of the program that has a class with special methods.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __str__(self):
        return f"{self.hours} hrs {self.minutes:02d} mins"

one_hour = Duration(1, 0)
print(one_hour)
1
2
3
Check
Next
1
2
3

Feedback?'''
def challenge_activity_9_8_1_1():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __str__(self):
            return f"{self.hours} hrs {self.minutes:02d} mins"

    one_hour = Duration(1, 0)
    print(one_hour)  # Output: 1 hrs 00 mins
challenge_activity_9_8_1_1()
'''challenge activity
9.8.1: Enter the output of the program that has a class with special methods.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __eq__(self, other):
        return (self.hours == other.hours) and (self.minutes == other.minutes)

workday = Duration(6, 0)
tuesday_time = Duration(10, 45)
monday_time = Duration(6, 0)

print(monday_time == workday)
print(tuesday_time == workday)
1
2
3
Check
Next
1
2
3

Feedback?'''
def challenge_activity_9_8_1_2():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __eq__(self, other):
            return (self.hours == other.hours) and (self.minutes == other.minutes)

    workday = Duration(6, 0)
    tuesday_time = Duration(10, 45)
    monday_time = Duration(6, 0)

    print(monday_time == workday)  # Output: True
    print(tuesday_time == workday)  # Output: False
challenge_activity_9_8_1_2()
'''challenge activity
9.8.1: Enter the output of the program that has a class with special methods.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __lt__(self, other):
        if self.hours < other.hours:
            return True
        elif self.hours == other.hours:
            if self.minutes < other.minutes:
                return True
        return False

workday = Duration(10, 30)
monday_time = Duration(10, 0)
tuesday_time = Duration(8, 30)
wednesday_time = Duration(11, 30)

print(monday_time < workday)
print(tuesday_time < workday)
print(wednesday_time < workday)
print(wednesday_time < tuesday_time)
1
2
3
Check
Next
1
2
3

Feedback?'''
def challenge_activity_9_8_1_3():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __lt__(self, other):
            if self.hours < other.hours:
                return True
            elif self.hours == other.hours:
                if self.minutes < other.minutes:
                    return True
            return False

    workday = Duration(10, 30)
    monday_time = Duration(10, 0)
    tuesday_time = Duration(8, 30)
    wednesday_time = Duration(11, 30)

    print(monday_time < workday)  # Output: False
    print(tuesday_time < workday)  # Output: True
    print(wednesday_time < workday)  # Output: False
    print(wednesday_time < tuesday_time)  # Output: False
challenge_activity_9_8_1_3()
# Out:
# 'challenge activity\n9.8.1: Enter the output of the program that has a class with special methods.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program\'s output\n\nclass Duration:\n    def __init__(self, hours, minutes):\n        self.hours = hours\n        self.minutes = minutes\n\n    def __str__(self):\n        return f"{self.hours} hrs {self.minutes:02d} mins"\n\none_hour = Duration(1, 0)\nprint(one_hour)\n1\n2\n3\nCheck\nNext\n1\n2\n3\n\nFeedback?'
# 1 hrs 00 mins
# ...

# %%
'''challenge activity
9.8.2: Defining __str__.
Write the special method __str__() for CarRecord.

Sample output with input: 2009 "ABC321"
Year: 2009, VIN: ABC321


Learn how our autograder works

712910.5105864.qx3zqy7
1 test passed
All tests passed

Run
Running tests...

Feedback?

```
class CarRecord:
    def __init__(self):
        self.year_made = 0
        self.car_vin = ""

    # FIXME add __str__()

    """ Your solution goes here """

my_car = CarRecord()
my_car.year_made = int(input())
my_car.car_vin = input()

print(my_car)
```
'''
def challenge_activity_9_8_2():
    setin("2009", "ABC321")
    class CarRecord:
        def __init__(self):
            self.year_made = 0
            self.car_vin = ""

        def __str__(self):
            return f"Year: {self.year_made}, VIN: {self.car_vin}"

    my_car = CarRecord()
    my_car.year_made = int(input())
    my_car.car_vin = input()

    print(my_car)
challenge_activity_9_8_2()
# Out:
# 'challenge activity\n9.8.2: Defining __str__.\nWrite the special method __str__() for CarRecord.\n\nSample output with input: 2009 "ABC321"\nYear: 2009, VIN: ABC321\n\n\nLearn how our autograder works\n\n712910.5105864.qx3zqy7\n1 test passed\nAll tests passed\n\nRun\nRunning tests...\n\nFeedback?\n\n```\nclass CarRecord:\n    def __init__(self):\n        self.year_made = 0\n        self.car_vin = ""\n\n    # FIXME add __str__()\n\n    """ Your solution goes here """\n\nmy_car = CarRecord()\nmy_car.year_made = int(input())\nmy_car.car_vin = input()\n\nprint(my_car)\n```\n'
# 2009
# ABC321
# Year: 2009, VIN: ABC321

# %% [markdown]
# ## 9.9 More operator overloading: Classes as numeric types
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/9

# %%
ohokay='''## 9.9 More operator overloading: Classes as numeric types

Numeric operators such as +, -, *, and / can be overloaded using class customization techniques. Thus, a user-defined class can be treated as a numeric object in which instances of that class can be added , multiplied, etc. Consider the example below, which represents a 24-hour clock time. The algorithm determines the absolute shortest distance between two given times. The two times may appear within the same day (Ex: Time between 5:00 and 3:30 in the same day is short) or span two days (Ex: 22:30 to 2:40 over two days is shorter than 2:40 to 22:30 within one day).

> **Extending the time class with overloaded subtraction operator.**
> ```python
> class Time24:
>     def __init__(self, hours, minutes):
>         self.hours = hours
>         self.minutes = minutes
> 
>     def __str__(self):
>         return f"{self.hours:02d}:{self.minutes:02d}"
> 
>     def __gt__(self, other): 
>         if self.hours > other.hours: 
>             return True 
>         else: 
>             if self.hours == other.hours: 
>                 if self.minutes > other.minutes: 
>                     return True 
>         return False
> 
>     def __sub__(self, other):
>         """ Calculate absolute distance between two times """
>         if self > other:
>             larger = self
>             smaller = other
>         else:
>             larger = other
>             smaller = self
> 
>         hrs = larger.hours - smaller.hours
>         mins = larger.minutes - smaller.minutes
>         if mins < 0:
>             mins += 60
>             hrs -=1
>         
>         # Check if times wrap to new day
>         if hrs > 12:
>             hrs = 24 - (hrs + 1)
>             mins = 60 - mins
>             if mins >= 60:
>                 mins -= 60
>                 hrs += 1
>         
>         # Return new Time24 instance 
>         return Time24(hrs, mins)
> 
> t1 = input("Enter time1 (hours:minutes): ")
> tokens = t1.split(":")
> time1 = Time24(int(tokens[0]), int(tokens[1]))
> 
> t2 = input("Enter time2 (hours:minutes): ")
> tokens = t2.split(":")
> time2 = Time24(int(tokens[0]), int(tokens[1]))
> 
> print(f"Time difference: {time1 - time2}")
> ```
> ```
> Enter time1 (hours:minutes): 5:00
> Enter time2 (hours:minutes): 3:30
> Time difference: 01:30
> ...
> Enter time1 (hours:minutes): 22:30
> Enter time2 (hours:minutes): 2:40
> Time difference: 04:10
> ```

The above program adds a definition of the  __sub__method to the Time24 class that is called when an expression like `time1 - time2` is evaluated. The method calculates the absolute difference between the two times, and returns a new instance of Time24 containing the result. 

 The overloaded method will be called whenever the left operand is an instance Time24. Thus, an expression like `time1 - 1` will also cause the overloaded method to be called. Such an expression would cause an error because the __sub__ method would attempt to access the attribute other.minutes, but the integer 1 does not contain a minutes attribute. The error occurs because the behavior is undefined &mdash; does `time1 - 1` mean to subtract one hour or one minute? 

 To handle subtraction of arbitrary object types, the built-in isinstance() function can be used. The isinstance() function returns a True or False Boolean depending on whether a given variable matches a given type. The __sub__ function is modified below to first check the type of the right operand, and subtract an hour if the right operand is an integer, or find the time difference if the right operand is another Time24 instance.

> **The isinstance() built-in function.**
> | def __sub__(self, other):     if isinstance(other, int): # right op is integer         return Time24(self.hours - other, self.minutes)      if isinstance(other, Time24):  # right op is Time24         if self > other:             larger = self             smaller = other         else:             larger = other             smaller = self          hrs = larger.hours - smaller.hours         mins = larger.minutes - smaller.minutes         if mins < 0:             mins += 60             hrs -=1          # Check if times wrap to new day         if hrs > 12:             hrs = 24 - (hrs + 1)             mins = 60 - mins          # Return new Time24 instance         return Time24(hrs, mins)      print(f"{type(other)} unsupported")     raise NotImplementedError | Operation | Result |
> | --- | --- | --- |
> | t1 - t2 | Difference between t1, t2 |  |
> | t1 - 5 | t1 minus 5 hours. |  |
> | t1 - 5.75 | "float unsupported" |  |
> | t1 - <other_type> | "<other_type> unsupported" |  |

Every operator in Python can be overloaded. The table below lists some of the most common methods. A full list is available at the bottom of the section.

> **Methods for emulating numeric types.**
> | Method | Description |
> | --- | --- |
> | __add__(self, other) | Add (+) |
> | __sub__(self, other) | Subtract (-) |
> | __mul__(self, other) | Multiply (*) |
> | __truediv__(self, other) | Divide (/) |
> | __floordiv__(self, other) | Floored division (//) |
> | __mod__(self, other) | Modulus (%) |
> | __pow__(self, other) | Exponentiation (**) |
> | __and__(self, other) | "and" logical operator |
> | __or__(self, other) | "or" logical operator |
> | __abs__(self) | Absolute value (abs()) |
> | __int__(self) | Convert to integer (int()) |
> | __float__(self) | Convert to floating point (float()) |

The table above lists common operators such as addition, subtraction, multiplication, and division. Sometimes a class also needs to pass as an argument to built-in functions like abs(), int(), float(), etc.  Defining the methods like __abs__(), __int__(), and __float__() will automatically cause those methods to be called when an instance of that class is passed to the corresponding function. The methods should return an appropriate object for each method, i.e., an integer value for __int__() and a floating-point value for __float__(). Note that not all such methods need to be implemented for a class; their usage is generally optional, but can provide for cleaner and more elegant code. Not defining a method will simply cause an error if that method is needed but not found, which indicates to the programmer that additional functionality must be implemented.

### PARTICIPATION ACTIVITY: Emulating numeric types with operator overloading.

**1.** def __add__(self, other):

      new_value = Adding two LooseChange instances, `lc1 + lc2`, returns a new LooseChange instance with the summed value of lc1 and lc2. return LooseChange(new_value)

```

```
Answer: self.value + other.value or other.value + self.value
*Hint: Add the value attributes of the self and other instances.*
*self is bound to the left operand of the add operation, and other is bound to the right operand. The value attribute of each is summed, and a new instance with the new value is returned.*

**2.**
```
lc1  = LooseChange(135)
print(float(lc1))
```
Answer: float(self.value) / 100 or float(self.value) / 100.0 or self.value / 100 or self.value / 100.
*Hint: Divide by 100 to move the decimal point left 2 places.*
*self is bound to the single operand of the float conversion. The value attribute is converted to a floating point number, then divided by 100, and returned.*

### CHALLENGE ACTIVITY: Enter the output of classes as numeric types.

**Level 1:**

What is the output?

```python
class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __add__(self, other):
        total_hours = self.hours + other.hours
        total_minutes = self.minutes + other.minutes
        if total_minutes >= 60:
            total_hours += 1
            total_minutes -= 60
        return Duration(total_hours, total_minutes)

first_trip = Duration(1, 30)
second_trip = Duration(0, [minutes2])

first_time = first_trip + second_trip
second_time = second_trip + second_trip

print(first_time.hours, first_time.minutes)
print(second_time.hours, second_time.minutes)
```

*When two values are added, Python looks for a definition of __add__() in the class of the first value. Thus, `first_time = first_trip + second_trip` calls the __add__() method of the Duration class with the arguments first_trip and second_trip. __add__() returns a new Duration object representing the sum of first_trip and second_trip. If the sum of the minutes of the two objects is greater than or equal to 60, the method adds 1 to total_hours and subtracts 60 from total_minutes.*

**Level 2:**

What is the output?

```python
class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __add__(self, other):
        if not isinstance(other, Duration):
            return "oops"
        total_hours = self.hours + other.hours
        total_minutes = self.minutes + other.minutes
        if total_minutes >= 60:
            total_hours += 1
            total_minutes -= 60
        return Duration(total_hours, total_minutes)
  
one_way_time = Duration(1, 30)
round_trip_time = one_way_time + one_way_time

${print_statements[0]}
${print_statements[1]}
```

*__add__() begins by calling isinstance() to verify that the argument is an instance of the Duration class. isinstance(other, Duration) returns True if other is an instance of Duration and False otherwise. If other is not an instance of Duration, __add__() outputs "oops". Otherwise, __add__() returns the result of adding other to self.*

**Level 3:**

What is the output?

```python
class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __int__(self):
        return self.hours * 60 + self.minutes

flight_time = Duration(1, [minutes])
print(int(flight_time))
```

*int(flight_time) calls the __int__() method with flight_time as the argument. __int__() returns an integer value representing the total number of minutes of flight_time.*

**Level 4:**

What is the output?

```python
class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __add__(self, other):
        if not isinstance(other, Duration):
            return None # Outputs "None"
        total_hours = self.hours + other.hours
        total_minutes = self.minutes + other.minutes
        if total_minutes >= 60:
            total_hours += 1
            total_minutes -= 60
        return Duration(total_hours, total_minutes)

    def __int__(self):
        return self.hours * 60 + self.minutes

flight_time = Duration(1, [minutes1])
drive_time = Duration([hours2], [minutes2])

${print_statements[0]}
${print_statements[1]}
```

*`int(flight_time) + int(drive_time)` converts the Duration objects into integer values and then adds the integer values. `int(flight_time + drive_time)` uses __add__() to add the Duration objects and then converts the new Duration into an integer value. Both yield the same result.*

Exploring further:

 -  List of numeric special method names'''

ohokay='''
9.9 More operator overloading: Classes as numeric types
Numeric operators such as +, -, *, and / can be overloaded using class customization techniques. Thus, a user-defined class can be treated as a numeric object in which instances of that class can be added , multiplied, etc. Consider the example below, which represents a 24-hour clock time. The algorithm determines the absolute shortest distance between two given times. The two times may appear within the same day (Ex: Time between 5:00 and 3:30 in the same day is short) or span two days (Ex: 22:30 to 2:40 over two days is shorter than 2:40 to 22:30 within one day).

Figure 9.9.1: Extending the time class with overloaded subtraction operator.
class Time24:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __str__(self):
        return f"{self.hours:02d}:{self.minutes:02d}"

    def __gt__(self, other): 
        if self.hours > other.hours: 
            return True 
        else: 
            if self.hours == other.hours: 
                if self.minutes > other.minutes: 
                    return True 
        return False

    def __sub__(self, other):
        """ Calculate absolute distance between two times """
        if self > other:
            larger = self
            smaller = other
        else:
            larger = other
            smaller = self

        hrs = larger.hours - smaller.hours
        mins = larger.minutes - smaller.minutes
        if mins < 0:
            mins += 60
            hrs -=1
        
        # Check if times wrap to new day
        if hrs > 12:
            hrs = 24 - (hrs + 1)
            mins = 60 - mins
            if mins >= 60:
                mins -= 60
                hrs += 1
        
        # Return new Time24 instance 
        return Time24(hrs, mins)

t1 = input("Enter time1 (hours:minutes): ")
tokens = t1.split(":")
time1 = Time24(int(tokens[0]), int(tokens[1]))

t2 = input("Enter time2 (hours:minutes): ")
tokens = t2.split(":")
time2 = Time24(int(tokens[0]), int(tokens[1]))

print(f"Time difference: {time1 - time2}")
Enter time1 (hours:minutes): 5:00
Enter time2 (hours:minutes): 3:30
Time difference: 01:30
...
Enter time1 (hours:minutes): 22:30
Enter time2 (hours:minutes): 2:40
Time difference: 04:10

Feedback?
The above program adds a definition of the __sub__method to the Time24 class that is called when an expression like time1 - time2 is evaluated. The method calculates the absolute difference between the two times, and returns a new instance of Time24 containing the result.

The overloaded method will be called whenever the left operand is an instance Time24. Thus, an expression like time1 - 1 will also cause the overloaded method to be called. Such an expression would cause an error because the __sub__ method would attempt to access the attribute other.minutes, but the integer 1 does not contain a minutes attribute. The error occurs because the behavior is undefined — does time1 - 1 mean to subtract one hour or one minute?

To handle subtraction of arbitrary object types, the built-in isinstance() function can be used. The isinstance() function returns a True or False Boolean depending on whether a given variable matches a given type. The __sub__ function is modified below to first check the type of the right operand, and subtract an hour if the right operand is an integer, or find the time difference if the right operand is another Time24 instance.

Figure 9.9.2: The isinstance() built-in function.
def __sub__(self, other):
    if isinstance(other, int): # right op is integer
        return Time24(self.hours - other, self.minutes)

    if isinstance(other, Time24):  # right op is Time24
        if self > other:
            larger = self
            smaller = other
        else:
            larger = other
            smaller = self

        hrs = larger.hours - smaller.hours
        mins = larger.minutes - smaller.minutes
        if mins < 0:
            mins += 60
            hrs -=1

        # Check if times wrap to new day
        if hrs > 12:
            hrs = 24 - (hrs + 1)
            mins = 60 - mins

        # Return new Time24 instance
        return Time24(hrs, mins)

    print(f"{type(other)} unsupported")
    raise NotImplementedError
Operation	Result
t1 - t2	Difference between t1, t2
t1 - 5	t1 minus 5 hours.
t1 - 5.75	"float unsupported"
t1 - <other_type>	"<other_type> unsupported"

Feedback?
Every operator in Python can be overloaded. The table below lists some of the most common methods. A full list is available at the bottom of the section.

Table 9.9.1: Methods for emulating numeric types.
Method	Description
__add__(self, other)	Add (+)
__sub__(self, other)	Subtract (-)
__mul__(self, other)	Multiply (*)
__truediv__(self, other)	Divide (/)
__floordiv__(self, other)	Floored division (//)
__mod__(self, other)	Modulus (%)
__pow__(self, other)	Exponentiation (**)
__and__(self, other)	"and" logical operator
__or__(self, other)	"or" logical operator
__abs__(self)	Absolute value (abs())
__int__(self)	Convert to integer (int())
__float__(self)	Convert to floating point (float())

Feedback?
The table above lists common operators such as addition, subtraction, multiplication, and division. Sometimes a class also needs to pass as an argument to built-in functions like abs(), int(), float(), etc. Defining the methods like __abs__(), __int__(), and __float__() will automatically cause those methods to be called when an instance of that class is passed to the corresponding function. The methods should return an appropriate object for each method, i.e., an integer value for __int__() and a floating-point value for __float__(). Note that not all such methods need to be implemented for a class; their usage is generally optional, but can provide for cleaner and more elegant code. Not defining a method will simply cause an error if that method is needed but not found, which indicates to the programmer that additional functionality must be implemented.
'''

# %%
def figure_9_9_1():
    setin("5:00", "3:30", "22:30", "2:40")
    class Time24:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __str__(self):
            return f"{self.hours:02d}:{self.minutes:02d}"

        def __gt__(self, other): 
            if self.hours > other.hours: 
                return True 
            else: 
                if self.hours == other.hours: 
                    if self.minutes > other.minutes: 
                        return True 
            return False

        def __sub__(self, other):
            """ Calculate absolute distance between two times """
            if self > other:
                larger = self
                smaller = other
            else:
                larger = other
                smaller = self

            hrs = larger.hours - smaller.hours
            mins = larger.minutes - smaller.minutes
            if mins < 0:
                mins += 60
                hrs -=1
            
            # Check if times wrap to new day
            if hrs > 12:
                hrs = 24 - (hrs + 1)
                mins = 60 - mins
                if mins >= 60:
                    mins -= 60
                    hrs += 1
            
            # Return new Time24 instance 
            return Time24(hrs, mins)

    t1 = input("Enter time1 (hours:minutes): ")
    tokens = t1.split(":")
    time1 = Time24(int(tokens[0]), int(tokens[1]))

    t2 = input("Enter time2 (hours:minutes): ")
    tokens = t2.split(":")
    time2 = Time24(int(tokens[0]), int(tokens[1]))

    print(f"Time difference: {time1 - time2}")
figure_9_9_1()

def figure_9_9_2():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __add__(self, other):
            total_hours = self.hours + other.hours
            total_minutes = self.minutes + other.minutes
            if total_minutes >= 60:
                total_hours += 1
                total_minutes -= 60
            return Duration(total_hours, total_minutes)

    first_trip = Duration(1, 30)
    second_trip = Duration(0, 45)

    first_time = first_trip + second_trip
    second_time = second_trip + second_trip

    print(first_time.hours, first_time.minutes)  # Output: 2 15
    print(second_time.hours, second_time.minutes)  # Output: 1 30
figure_9_9_2()
# Out:
# Enter time1 (hours:minutes): 5:00
# Enter time2 (hours:minutes): 3:30
# Time difference: 01:30
# 2 15
# 1 30

# %%
class IamNinePointNine:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __add__(self, other):
        if not isinstance(other, IamNinePointNine):
            return "oops"
        total_hours = self.hours + other.hours
        total_minutes = self.minutes + other.minutes
        if total_minutes >= 60:
            total_hours += 1
            total_minutes -= 60
        return IamNinePointNine(total_hours, total_minutes)
    
one_way_time = IamNinePointNine(1, 30)
round_trip_time = one_way_time + one_way_time
print(round_trip_time.hours, round_trip_time.minutes)  # Output: 3 0

isinstance(one_way_time, IamNinePointNine)  # Output: True
isinstance(one_way_time, int)  # Output: False
# Out:
# 3 0
# True
# False

# %%
class MyClass:
    def __init__(self, value):
        self.value = value

    def __int__(self):
        return self.value * 2
my_instance = MyClass(5)

print(my_instance)  # Output: <__main__.MyClass object at 0x...>

print(int(my_instance))  # Output: 10

isinstance(my_instance, MyClass)  # Output: True

class MyClassTwo:
    def __init__(self, value):
        self.value = value

    def __int__(self):
        return self.value * 2
my_instance_two = MyClassTwo(5)

print(int(my_instance_two))  # Output: 10

isinstance(my_instance_two, MyClassTwo)  # Output: True
isinstance(my_instance_two, MyClass)  # Output: False

MyClassTwo.__int__(my_instance_two)  # Output: 10
# Out:
# ...
# 10
# True
# 10
# True
# False
# 10

# %%
'''participation activity
9.9.1: Emulating numeric types with operator overloading.
Assume that the following class is defined. Fill in the missing statements in the most direct possible way to complete the described method.

class LooseChange:
    def __init__(self, value):
        self.value = value  # integer representing total number of cents.

    # ...
1)
Adding two LooseChange instances, lc1 + lc2, returns a new LooseChange instance with the summed value of lc1 and lc2.

def __add__(self, other):

      new_value =   


      return LooseChange(new_value)
                                     

Check

Show answer
2)
Executing the code:

lc1  = LooseChange(135)
print(float(lc1))


yields the output

1.35

def __float__(self):

      fp_value =   


      return fp_value

Check

Show answer'''
def participation_activity_9_9_1():
    class LooseChange:
        def __init__(self, value):
            self.value = value  # integer representing total number of cents.

        def __add__(self, other):
            new_value = self.value + other.value
            return LooseChange(new_value)

        def __float__(self):
            fp_value = self.value / 100
            return fp_value

    lc1  = LooseChange(135)
    print(float(lc1))  # Output: 1.35
participation_activity_9_9_1()
# Out:
# 'participation activity\n9.9.1: Emulating numeric types with operator overloading.\nAssume that the following class is defined. Fill in the missing statements in the most direct possible way to complete the described method.\n\nclass LooseChange:\n    def __init__(self, value):\n        self.value = value  # integer representing total number of cents.\n\n    # ...\n1)\nAdding two LooseChange instances, lc1 + lc2, returns a new LooseChange instance with the summed value of lc1 and lc2.\n\ndef __add__(self, other):\n\n      new_value =   \n\n\n      return LooseChange(new_value)\n\n\nCheck\n\nShow answer\n2)\nExecuting the code:\n\nlc1  = LooseChange(135)\nprint(float(lc1))\n\n\nyields the output\n\n1.35\n\ndef __float__(self):\n\n      fp_value =   \n\n\n      return fp_value\n\nCheck\n\nShow answer'
# 1.35

# %%
'''challenge activity
9.9.1: Enter the output of classes as numeric types.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __add__(self, other):
        total_hours = self.hours + other.hours
        total_minutes = self.minutes + other.minutes
        if total_minutes >= 60:
            total_hours += 1
            total_minutes -= 60
        return Duration(total_hours, total_minutes)

first_trip = Duration(2, 41)
second_trip = Duration(0, 40)

first_time = first_trip + second_trip
second_time = second_trip + second_trip

print(first_time.hours, first_time.minutes)
print(second_time.hours, second_time.minutes)
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_9_1_1():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __add__(self, other):
            total_hours = self.hours + other.hours
            total_minutes = self.minutes + other.minutes
            if total_minutes >= 60:
                total_hours += 1
                total_minutes -= 60
            return Duration(total_hours, total_minutes)

    first_trip = Duration(2, 41)
    second_trip = Duration(0, 40)

    first_time = first_trip + second_trip
    second_time = second_trip + second_trip

    print(first_time.hours, first_time.minutes)  # Output: 3 21
    print(second_time.hours, second_time.minutes)  # Output: 1 20
challenge_activity_9_9_1_1()
'''challenge activity
9.9.1: Enter the output of classes as numeric types.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __add__(self, other):
        if not isinstance(other, Duration):
            return "oops"
        total_hours = self.hours + other.hours
        total_minutes = self.minutes + other.minutes
        if total_minutes >= 60:
            total_hours += 1
            total_minutes -= 60
        return Duration(total_hours, total_minutes)
  
one_way_time = Duration(5, 36)
round_trip_time = one_way_time + one_way_time

print(one_way_time + 41)
print(round_trip_time.hours, round_trip_time.minutes)
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''

def challenge_activity_9_9_1_2():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __add__(self, other):
            if not isinstance(other, Duration):
                return "oops"
            total_hours = self.hours + other.hours
            total_minutes = self.minutes + other.minutes
            if total_minutes >= 60:
                total_hours += 1
                total_minutes -= 60
            return Duration(total_hours, total_minutes)
  
    one_way_time = Duration(5, 36)
    round_trip_time = one_way_time + one_way_time

    print(one_way_time + 41)  # Output: "oops"
    print(round_trip_time.hours, round_trip_time.minutes)  # Output: 11 12
challenge_activity_9_9_1_2()
'''challenge activity
9.9.1: Enter the output of classes as numeric types.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __int__(self):
        return self.hours * 60 + self.minutes

flight_time = Duration(4, 37)
print(int(flight_time))
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_9_1_3():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __int__(self):
            return self.hours * 60 + self.minutes

    flight_time = Duration(4, 37)
    print(int(flight_time))  # Output: 277
challenge_activity_9_9_1_3()
'''challenge activity
9.9.1: Enter the output of classes as numeric types.
712910.5105864.qx3zqy7
Jump to level 1
Type the program's output

class Duration:
    def __init__(self, hours, minutes):
        self.hours = hours
        self.minutes = minutes

    def __add__(self, other):
        if not isinstance(other, Duration):
            return None # Outputs "None"
        total_hours = self.hours + other.hours
        total_minutes = self.minutes + other.minutes
        if total_minutes >= 60:
            total_hours += 1
            total_minutes -= 60
        return Duration(total_hours, total_minutes)

    def __int__(self):
        return self.hours * 60 + self.minutes

flight_time = Duration(5, 51)
drive_time = Duration(1, 10)

print(int(flight_time + drive_time))
print(int(flight_time) + int(drive_time))
1
2
3
4
Check
Next
1
2
3
4

Feedback?'''
def challenge_activity_9_9_1_4():
    class Duration:
        def __init__(self, hours, minutes):
            self.hours = hours
            self.minutes = minutes

        def __add__(self, other):
            if not isinstance(other, Duration):
                return None # Outputs "None"
            total_hours = self.hours + other.hours
            total_minutes = self.minutes + other.minutes
            if total_minutes >= 60:
                total_hours += 1
                total_minutes -= 60
            return Duration(total_hours, total_minutes)

        def __int__(self):
            return self.hours * 60 + self.minutes

    flight_time = Duration(5, 51)
    drive_time = Duration(1, 10)

    print(int(flight_time + drive_time))  # Output: 421
    print(int(flight_time) + int(drive_time))  # Output: 421
challenge_activity_9_9_1_4()
# Out:
# "challenge activity\n9.9.1: Enter the output of classes as numeric types.\n712910.5105864.qx3zqy7\nJump to level 1\nType the program's output\n\nclass Duration:\n    def __init__(self, hours, minutes):\n        self.hours = hours\n        self.minutes = minutes\n\n    def __add__(self, other):\n        total_hours = self.hours + other.hours\n        total_minutes = self.minutes + other.minutes\n        if total_minutes >= 60:\n            total_hours += 1\n            total_minutes -= 60\n        return Duration(total_hours, total_minutes)\n\nfirst_trip = Duration(2, 41)\nsecond_trip = Duration(0, 40)\n\nfirst_time = first_trip + second_trip\nsecond_time = second_trip + second_trip\n\nprint(first_time.hours, first_time.minutes)\nprint(second_time.hours, second_time.minutes)\n1\n2\n3\n4\nCheck\nNext\n1\n2\n3\n4\n\nFeedback?"
# 3 21
# 1 20
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

class A:
    pass
a=A()
isinstance(a, A)
class A:
    def __init__(self, value):
        self.value = value
a = A(5)
isinstance(a, A)


class A:
    def __init__(self, value):
        self.value = value

    def __int__(self):
        return self.value * 2
class B:
    def __init__(self, value):
        self.value = value

    def __int__(self):
        return self.value * 2
a = A(5)
b = B(5)
a #output: <__main__.A object at 0x...>
b #output: <__main__.B object at 0x...>
int(a) #output: 10
int(b) #output: 10
isinstance(a, A) #output: True
isinstance(b, B) #output: True
isinstance(a, B) #output: False
A.__int__(a) #output: 10
B.__int__(b) #output: 10
A,B #output: (__main__.A, __main__.B)


class A:
    def __init__(self, value1,value2):
        self.value1 = value1
        self.value2 = value2
    def __add__(self, other):
        return A(self.value1 + other.value1, self.value2 + other.value2)
    def __str__(self):
        return f"Value1: {self.value1}, Value2: {self.value2}"
a1 = A(1, 2)

a1

a2 = A(3, 4)

a2

a3 = a1 + a2

a3

a3.value1 #output: 4
a3.value2 #output: 6

a1 + a2 #output: Value1: 4, Value2: 6
print(a1 + a2) #output: Value1: 4, Value2: 6
# Out:
# True
# True
# 10
# 10
# True
# True
# False
# 10
# 10
# (__main__.A, __main__.B)
# 4
# 6
# Value1: 4, Value2: 6

# %% [markdown]
# ## 9.10 Memory allocation and garbage collection
#
# https://learn.zybooks.com/zybook/CPPCS2520NguyenSpring2026/chapter/9/section/10

# %%
ohokay='''
9.10 Memory allocation and garbage collection
Memory allocation
The process of an application requesting and being granted memory is known as memory allocation. Memory used by a Python application must be granted to the application by the operating system. When an application requests a specific amount of memory from the operating system, the operating system can then choose to grant or deny the request.

While some languages require the programmer to write memory allocating code, the Python runtime handles memory allocation for the programmer. Ex: Creating a list in Python and then appending 100 items means that memory for the 100 items must be allocated. The Python runtime allocates memory for lists and other objects as necessary.

participation activity
9.10.1: Memory allocation in Python.


1

2

3

4

Memory allocation is usually invisible to the programmer, since the allocation is done by the Python runtime.
Memory
lst = []
for i in range (0, 100):
  lst.append(i)
...
Application 1lst and application 1's other
variables reside in memory
allocated for application 1
...Application 2
x = 10
y = 20
z = x * y
...
x, y, z, and the rest of application 2's
variables reside in memory allocated
for application 2
Python allocates memory on programmer's behalf
Step 1: System memory is partitioned into segments and managed by the operating system. System memory is shown as a box with 11 memory locations, represented as adjacent rectangles stacked vertically. Step 2: A Python application creates an list with 100 items. The Python runtime has allocated space for this list. Code is displayed for Application 1. Begin Python code: lst = [] for i in range (0, 100): lst.append(i) ... End Python code. The third memory location is highlighted, and a line is drawn from the third memory location to the Application 1 code. The following text appears: lst and application 1's other variables reside in memory allocated for application 1. Step 3: Other applications may use other areas of allocated memory. Code is displayed for Application 2. Begin Python code: x = 10 y = 20 z = x * y ... End Python code. The eighth memory location is highlighted, and a line is drawn from the eighth memory location to the Application 2 code. The following text appears: x, y, z, and the rest of application 2's variables reside in memory allocated for application 2. Step 4: Memory allocation is usually invisible to the programmer, since the allocation is done by the Python runtime. The following text appears: Python allocates memory on programmer's behalf.

Captions
System memory is partitioned into segments and managed by the operating system.
A Python application creates a list with 100 items. The Python runtime has allocated space for this list.
Other applications may use other areas of allocated memory.
Memory allocation is usually invisible to the programmer, since the allocation is done by the Python runtime.
Playing step 4: Memory allocation is usually invisible to the programmer, since the allocation is done by the Python runtime. Step finished playing

Feedback?
'''

# %%
'''participation activity
9.10.2: Memory allocation in Python.
1)
The Python runtime requests memory from the operating system.
2)
Certain objects in a Python application may reside in memory that has not been allocated.
3)
All programming languages perform all memory allocation on behalf of the programmer.

Feedback?'''
def participation_activity_9_10_2():
    # 1) The Python runtime requests memory from the operating system.
    print("True","This process of requesting and being granted memory is known as memory allocation.")
    # 2) Certain objects in a Python application may reside in memory that has not been allocated.
    print("False","All variables/objects in a Python application reside in allocated memory. An application cannot use memory that has not been allocated.")
    # 3) All programming languages perform all memory allocation on behalf of the programmer.
    print("False","In some languages such as C++, the programmer is responsible for memory allocation. In Python, memory allocation is the responsibility of the Python runtime, making the programmer's life easier.")
    pass
participation_activity_9_10_2()
# Out:
# 'participation activity\n9.10.2: Memory allocation in Python.\n1)\nThe Python runtime requests memory from the operating system.\n2)\nCertain objects in a Python application may reside in memory that has not been allocated.\n3)\nAll programming languages perform all memory allocation on behalf of the programmer.\n\nFeedback?'
# True This process of requesting and being granted memory is known as memory allocation.
# False All variables/objects in a Python application reside in allocated memory. An application cannot use memory that has not been allocated.
# False In some languages such as C++, the programmer is responsible for memory allocation. In Python, memory allocation is the responsibility of the Python runtime, making the programmer's life easier.

# %%
# how do we view all variables in memory?
# we can use the built-in function globals() to view all global variables in memory, andlocals() to view all local variables in memory. Both functions return a dictionary of variable names and their values. The built-in function id() can be used to view the memory address of a variable. The memory address is an integer that represents the location of the variable in memory. The id() function can be used to compare the memory addresses of two variables to determine if they refer to the same object in memory.
x = 10
y = 20
z = x * y
#print(globals())  # Output: {'__name__': '__main__', '__doc__': None, '__package__': None, '__loader__': <_frozen_importlib

# %%
#its taking awhile the above cell,i avent gotten an output yet
#lets try a smaller example
a = 5
b = 10
#print(globals())  # Output: {'__name__': '__main__', '__doc__': None, '__package__': None, '__loader__': <_frozen_importlib

# %%
ohokay='''
Garbage collection
Memory deallocation is the act of freeing the memory that stores variables or objects in a program. Python is a managed language, meaning objects are deallocated automatically by the Python runtime, and not by the programmer's code. When an object is no longer referenced by any variables, the object becomes a candidate for deallocation.

A reference count is an integer counter that represents how many variables reference an object. When an object's reference count is 0, that object is no longer referenced. Python's garbage collector will deallocate objects with a reference count of 0. However, the time between an object's reference count becoming 0 and that object being deallocated may differ across different Python runtime implementations.
'''

# %%
'''participation activity
9.10.3: Python's garbage collection.


1

2

3

4

5

6

The Python garbage collector will eventually deallocate objects that are no longer referenced.
string1 = "Python"
string2 = "Computer science"
string3 = string2
string1 = "zyBooks"
string2 = string1
string1string2string3Objects that cannot be deallocatedObjects that can be deallocated Python
garbage
collector
Deallocated objectsPythonComputer sciencezyBooksRC = 0RC = 1RC = 1RC = 2RC = 2
Static Figure: Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. A diagram is displayed with an arrow going from the text string1 to a box with the text zyBooks inside the box. Another arrow is displayed going from the text string2 to the same zyBooks box that string1 is pointing to. The text RC = 2 is displayed next to the zyBooks box. Another arrow is displayed going from the text string3 to a box with the text Computer Science inside the box. The text RC = 1 is displayed next to the Computer Science box. The zyBooks box and the Computer Science box are inside a larger transparent box labelled Objects that cannot be deallocated. An empty box with the label Objects that can be deallocated is displayed. A larger box with the label Deallocated objects is displayed. A smaller box containing the text Python, is displayed within the Deallocated Objects box. A box labelled Python Garbage Collector is displayed, with a symbol similar to a clamp going from the Python Garbage Collector box to the Deallocated Objects box. Step 1: The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object. Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. The line of code string1 = "Python" is highlighted. A diagram is displayed with an arrow going from the text string1 to a box with the word Python inside the box. The line of code string2 = "Computer science" is highlighted. A diagram is displayed with an arrow going from the text string2 to a box with the word Computer Science inside the box. The line of code string3 = string2 is highlighted. An arrow is displayed going from the text string3 to the same box containing "Computer Science" that string2 is also pointing to. Step 2: The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object's RC is 2. The text RC = 1 is displayed next to the box with the text Python in the box. The text RC = 2 is displayed next to the box with the text Computer Science in the box. Step 3: Reference counts > 0 imply that neither object can be deallocated. A larger transparent box is displayed around the boxes with Python and Computer Science inside those boxes. Text appears beside this larger box: Objects that cannot be deallocated. Step 4: When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated. The line of code string1 = "zyBooks" is highlighted. The diagram is modified so that an arrow is displayed going from the text string1 to a box containing the text zyBooks. RC = 1 is displayed next to the zyBooks box. string1 and the arrow and the zyBooks box remain inside the larger transparent box with the label Objects that cannot be deallocated. The box containing the text Python is moved to a new transparent box labeled Objects that can be deallocated. The Python box has the text RC = 0 next to it. Step 5: After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated. The line of code string2 = string1 is highlighted. The diagram of the Objects that cannot be deallocated box is modified slightly. string2 now has an arrow that points to the zyBooks box, and string2 no longer points to the Computer Science box. The zyBooks box now has the text RC = 2 next to it. The Computer Science box now has the text RC = 1 next to it. Step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. A box appears with the label Python Garbage Collector. A symbol similar to a clamp appears, grabbing the Python box and moving it from the Objects that can be deallocated box to a new box with the label Deallocated objects.

Captions
The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.
The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object's RC is 2.
Reference counts > 0 imply that neither object can be deallocated.
When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.
After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.
The Python garbage collector will eventually deallocate objects that are no longer referenced.
Playing step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. Step finished playing

Feedback?'''
def participation_activity_9_10_3():
    string1 = "Python"
    string2 = "Computer science"
    string3 = string2
    string1 = "zyBooks"
    string2 = string1

    # The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.
    print("True","string1 references 'Python', while string2 and string3 both reference 'Computer science'.")
    # The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object's RC is 2.
    print("True","The 'Python' object is referenced by only string1, so its RC is 1. The 'Computer science' object is referenced by both string2 and string3, so its RC is 2.")
    # Reference counts > 0 imply that neither object can be deallocated.
    print("True","Both objects have RC > 0, so neither can be deallocated.")
    # When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.
    print("True","When string1 references 'zyBooks', the 'Python' object has no variables referencing it, so it can be deallocated.")
    # After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.
    print("True","After assigning string2 with 'zyBooks', the 'Computer science' object is still referenced by string3, so it cannot be deallocated.")
    # The Python garbage collector will eventually deallocate objects that are no longer referenced.
    print("True","The Python garbage collector will eventually deallocate objects that are no longer referenced, such as the 'Python' object in this example.")
participation_activity_9_10_3()
# Out:
# 'participation activity\n9.10.3: Python\'s garbage collection.\n\n\n1\n\n2\n\n3\n\n4\n\n5\n\n6\n\nThe Python garbage collector will eventually deallocate objects that are no longer referenced.\nstring1 = "Python"\nstring2 = "Computer science"\nstring3 = string2\nstring1 = "zyBooks"\nstring2 = string1\nstring1string2string3Objects that cannot be deallocatedObjects that can be deallocated Python\ngarbage\ncollector\nDeallocated objectsPythonComputer sciencezyBooksRC = 0RC = 1RC = 1RC = 2RC = 2\nStatic Figure: Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. A diagram is displayed with an arrow going from the text string1 to a box with the text zyBooks inside the box. Another arrow is displayed going from the text string2 to the same zyBooks box that string1 is pointing to. The text RC = 2 is displayed next to the zyBooks box. Another arrow is displayed going from the text string3 to a box with th
# ...

# %%
#globals()
#it finally came through
temp='''{'__name__': '__main__',
 '__doc__': 'participation activity\n9.10.3: Python\'s garbage collection.\n\n\n1\n\n2\n\n3\n\n4\n\n5\n\n6\n\nThe Python garbage collector will eventually deallocate objects that are no longer referenced.\nstring1 = "Python"\nstring2 = "Computer science"\nstring3 = string2\nstring1 = "zyBooks"\nstring2 = string1\nstring1string2string3Objects that cannot be deallocatedObjects that can be deallocated Python\ngarbage\ncollector\nDeallocated objectsPythonComputer sciencezyBooksRC = 0RC = 1RC = 1RC = 2RC = 2\nStatic Figure: Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. A diagram is displayed with an arrow going from the text string1 to a box with the text zyBooks inside the box. Another arrow is displayed going from the text string2 to the same zyBooks box that string1 is pointing to. The text RC = 2 is displayed next to the zyBooks box. Another arrow is displayed going from the text string3 to a box with the text Computer Science inside the box. The text RC = 1 is displayed next to the Computer Science box. The zyBooks box and the Computer Science box are inside a larger transparent box labelled Objects that cannot be deallocated. An empty box with the label Objects that can be deallocated is displayed. A larger box with the label Deallocated objects is displayed. A smaller box containing the text Python, is displayed within the Deallocated Objects box. A box labelled Python Garbage Collector is displayed, with a symbol similar to a clamp going from the Python Garbage Collector box to the Deallocated Objects box. Step 1: The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object. Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. The line of code string1 = "Python" is highlighted. A diagram is displayed with an arrow going from the text string1 to a box with the word Python inside the box. The line of code string2 = "Computer science" is highlighted. A diagram is displayed with an arrow going from the text string2 to a box with the word Computer Science inside the box. The line of code string3 = string2 is highlighted. An arrow is displayed going from the text string3 to the same box containing "Computer Science" that string2 is also pointing to. Step 2: The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2. The text RC = 1 is displayed next to the box with the text Python in the box. The text RC = 2 is displayed next to the box with the text Computer Science in the box. Step 3: Reference counts > 0 imply that neither object can be deallocated. A larger transparent box is displayed around the boxes with Python and Computer Science inside those boxes. Text appears beside this larger box: Objects that cannot be deallocated. Step 4: When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated. The line of code string1 = "zyBooks" is highlighted. The diagram is modified so that an arrow is displayed going from the text string1 to a box containing the text zyBooks. RC = 1 is displayed next to the zyBooks box. string1 and the arrow and the zyBooks box remain inside the larger transparent box with the label Objects that cannot be deallocated. The box containing the text Python is moved to a new transparent box labeled Objects that can be deallocated. The Python box has the text RC = 0 next to it. Step 5: After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated. The line of code string2 = string1 is highlighted. The diagram of the Objects that cannot be deallocated box is modified slightly. string2 now has an arrow that points to the zyBooks box, and string2 no longer points to the Computer Science box. The zyBooks box now has the text RC = 2 next to it. The Computer Science box now has the text RC = 1 next to it. Step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. A box appears with the label Python Garbage Collector. A symbol similar to a clamp appears, grabbing the Python box and moving it from the Objects that can be deallocated box to a new box with the label Deallocated objects.\n\nCaptions\nThe variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.\nThe "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2.\nReference counts > 0 imply that neither object can be deallocated.\nWhen string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.\nAfter assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.\nThe Python garbage collector will eventually deallocate objects that are no longer referenced.\nPlaying step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. Step finished playing\n\nFeedback?',
 '__package__': None,
 '__loader__': None,
 '__spec__': None,
 '__builtin__': <module 'builtins' (built-in)>,
 '__builtins__': <module 'builtins' (built-in)>,
 '_ih': ['',
  '\'\'\'participation activity\n9.10.3: Python\'s garbage collection.\n\n\n1\n\n2\n\n3\n\n4\n\n5\n\n6\n\nThe Python garbage collector will eventually deallocate objects that are no longer referenced.\nstring1 = "Python"\nstring2 = "Computer science"\nstring3 = string2\nstring1 = "zyBooks"\nstring2 = string1\nstring1string2string3Objects that cannot be deallocatedObjects that can be deallocated Python\ngarbage\ncollector\nDeallocated objectsPythonComputer sciencezyBooksRC = 0RC = 1RC = 1RC = 2RC = 2\nStatic Figure: Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. A diagram is displayed with an arrow going from the text string1 to a box with the text zyBooks inside the box. Another arrow is displayed going from the text string2 to the same zyBooks box that string1 is pointing to. The text RC = 2 is displayed next to the zyBooks box. Another arrow is displayed going from the text string3 to a box with the text Computer Science inside the box. The text RC = 1 is displayed next to the Computer Science box. The zyBooks box and the Computer Science box are inside a larger transparent box labelled Objects that cannot be deallocated. An empty box with the label Objects that can be deallocated is displayed. A larger box with the label Deallocated objects is displayed. A smaller box containing the text Python, is displayed within the Deallocated Objects box. A box labelled Python Garbage Collector is displayed, with a symbol similar to a clamp going from the Python Garbage Collector box to the Deallocated Objects box. Step 1: The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object. Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. The line of code string1 = "Python" is highlighted. A diagram is displayed with an arrow going from the text string1 to a box with the word Python inside the box. The line of code string2 = "Computer science" is highlighted. A diagram is displayed with an arrow going from the text string2 to a box with the word Computer Science inside the box. The line of code string3 = string2 is highlighted. An arrow is displayed going from the text string3 to the same box containing "Computer Science" that string2 is also pointing to. Step 2: The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2. The text RC = 1 is displayed next to the box with the text Python in the box. The text RC = 2 is displayed next to the box with the text Computer Science in the box. Step 3: Reference counts > 0 imply that neither object can be deallocated. A larger transparent box is displayed around the boxes with Python and Computer Science inside those boxes. Text appears beside this larger box: Objects that cannot be deallocated. Step 4: When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated. The line of code string1 = "zyBooks" is highlighted. The diagram is modified so that an arrow is displayed going from the text string1 to a box containing the text zyBooks. RC = 1 is displayed next to the zyBooks box. string1 and the arrow and the zyBooks box remain inside the larger transparent box with the label Objects that cannot be deallocated. The box containing the text Python is moved to a new transparent box labeled Objects that can be deallocated. The Python box has the text RC = 0 next to it. Step 5: After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated. The line of code string2 = string1 is highlighted. The diagram of the Objects that cannot be deallocated box is modified slightly. string2 now has an arrow that points to the zyBooks box, and string2 no longer points to the Computer Science box. The zyBooks box now has the text RC = 2 next to it. The Computer Science box now has the text RC = 1 next to it. Step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. A box appears with the label Python Garbage Collector. A symbol similar to a clamp appears, grabbing the Python box and moving it from the Objects that can be deallocated box to a new box with the label Deallocated objects.\n\nCaptions\nThe variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.\nThe "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2.\nReference counts > 0 imply that neither object can be deallocated.\nWhen string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.\nAfter assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.\nThe Python garbage collector will eventually deallocate objects that are no longer referenced.\nPlaying step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. Step finished playing\n\nFeedback?\'\'\'\ndef participation_activity_9_10_3():\n    string1 = "Python"\n    string2 = "Computer science"\n    string3 = string2\n    string1 = "zyBooks"\n    string2 = string1\n\n    # The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.\n    print("True","string1 references \'Python\', while string2 and string3 both reference \'Computer science\'.")\n    # The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2.\n    print("True","The \'Python\' object is referenced by only string1, so its RC is 1. The \'Computer science\' object is referenced by both string2 and string3, so its RC is 2.")\n    # Reference counts > 0 imply that neither object can be deallocated.\n    print("True","Both objects have RC > 0, so neither can be deallocated.")\n    # When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.\n    print("True","When string1 references \'zyBooks\', the \'Python\' object has no variables referencing it, so it can be deallocated.")\n    # After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.\n    print("True","After assigning string2 with \'zyBooks\', the \'Computer science\' object is still referenced by string3, so it cannot be deallocated.")\n    # The Python garbage collector will eventually deallocate objects that are no longer referenced.\n    print("True","The Python garbage collector will eventually deallocate objects that are no longer referenced, such as the \'Python\' object in this example.")\nparticipation_activity_9_10_3()',
  'from IPython.core.interactiveshell import InteractiveShell\nInteractiveShell.ast_node_interactivity = "all"',
  'import builtins\n\n# Store the original input function once, globally, to avoid re-capturing a mocked input\nif not hasattr(builtins, \'_original_input_backup\'):\n    builtins._original_input_backup = builtins.input\n\ndef set_test_inputs(inputs_list):\n    """\n    Sets up a mock input function that draws from a list of inputs.\n    If inputs_list is None or empty, restores the original input function.\n    """\n    if inputs_list:\n        input_iter = iter(inputs_list)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup\n\n# Define test_inputs, this is where you can change your desired inputs\ntest_inputs = [1]  # <--- Change this list to provide your test inputs\n\n# Apply the test inputs automatically when this cell is run\nset_test_inputs(test_inputs)\n\n# Example of how to revert to normal input:\n# set_test_inputs(None)\n# Or to set new inputs dynamically:\n# set_test_inputs(["new_input_1", "new_input_2"])\n\n#===\n\ndef setin(*inputs):\n    """\n    A helper function to set test inputs for the input() function.\n    Usage:\n    setin("input1", "input2", "input3")\n    This will set up the input() function to return "input1" on the first call,\n    "input2" on the second call, and so on.\n    To reset to normal input behavior, call setin() with no arguments or None:\n    setin()\n    """\n    if inputs:\n        input_iter = iter(inputs)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup',
  'setin("1","2","3")  # Example usage, you can change the input value as needed\ninput()\ninput()\ninput()',
  'from IPython.core.interactiveshell import InteractiveShell\nInteractiveShell.ast_node_interactivity = "all"',
  'import builtins\n\n# Store the original input function once, globally, to avoid re-capturing a mocked input\nif not hasattr(builtins, \'_original_input_backup\'):\n    builtins._original_input_backup = builtins.input\n\ndef set_test_inputs(inputs_list):\n    """\n    Sets up a mock input function that draws from a list of inputs.\n    If inputs_list is None or empty, restores the original input function.\n    """\n    if inputs_list:\n        input_iter = iter(inputs_list)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup\n\n# Define test_inputs, this is where you can change your desired inputs\ntest_inputs = [1]  # <--- Change this list to provide your test inputs\n\n# Apply the test inputs automatically when this cell is run\nset_test_inputs(test_inputs)\n\n# Example of how to revert to normal input:\n# set_test_inputs(None)\n# Or to set new inputs dynamically:\n# set_test_inputs(["new_input_1", "new_input_2"])\n\n#===\n\ndef setin(*inputs):\n    """\n    A helper function to set test inputs for the input() function.\n    Usage:\n    setin("input1", "input2", "input3")\n    This will set up the input() function to return "input1" on the first call,\n    "input2" on the second call, and so on.\n    To reset to normal input behavior, call setin() with no arguments or None:\n    setin()\n    """\n    if inputs:\n        input_iter = iter(inputs)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup',
  'setin("1","2","3")  # Example usage, you can change the input value as needed\ninput()\ninput()\ninput()',
  'globals()'],
 '_oh': {4: '3', 7: '3'},
 '_dh': [PosixPath('/workspaces/cs2520-study/zybooks notebooks')],
 'In': ['',
  '\'\'\'participation activity\n9.10.3: Python\'s garbage collection.\n\n\n1\n\n2\n\n3\n\n4\n\n5\n\n6\n\nThe Python garbage collector will eventually deallocate objects that are no longer referenced.\nstring1 = "Python"\nstring2 = "Computer science"\nstring3 = string2\nstring1 = "zyBooks"\nstring2 = string1\nstring1string2string3Objects that cannot be deallocatedObjects that can be deallocated Python\ngarbage\ncollector\nDeallocated objectsPythonComputer sciencezyBooksRC = 0RC = 1RC = 1RC = 2RC = 2\nStatic Figure: Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. A diagram is displayed with an arrow going from the text string1 to a box with the text zyBooks inside the box. Another arrow is displayed going from the text string2 to the same zyBooks box that string1 is pointing to. The text RC = 2 is displayed next to the zyBooks box. Another arrow is displayed going from the text string3 to a box with the text Computer Science inside the box. The text RC = 1 is displayed next to the Computer Science box. The zyBooks box and the Computer Science box are inside a larger transparent box labelled Objects that cannot be deallocated. An empty box with the label Objects that can be deallocated is displayed. A larger box with the label Deallocated objects is displayed. A smaller box containing the text Python, is displayed within the Deallocated Objects box. A box labelled Python Garbage Collector is displayed, with a symbol similar to a clamp going from the Python Garbage Collector box to the Deallocated Objects box. Step 1: The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object. Begin Python code: string1 = "Python" string2 = "Computer science" string3 = string2 string1 = "zyBooks" string2 = string1 End Python code. The line of code string1 = "Python" is highlighted. A diagram is displayed with an arrow going from the text string1 to a box with the word Python inside the box. The line of code string2 = "Computer science" is highlighted. A diagram is displayed with an arrow going from the text string2 to a box with the word Computer Science inside the box. The line of code string3 = string2 is highlighted. An arrow is displayed going from the text string3 to the same box containing "Computer Science" that string2 is also pointing to. Step 2: The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2. The text RC = 1 is displayed next to the box with the text Python in the box. The text RC = 2 is displayed next to the box with the text Computer Science in the box. Step 3: Reference counts > 0 imply that neither object can be deallocated. A larger transparent box is displayed around the boxes with Python and Computer Science inside those boxes. Text appears beside this larger box: Objects that cannot be deallocated. Step 4: When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated. The line of code string1 = "zyBooks" is highlighted. The diagram is modified so that an arrow is displayed going from the text string1 to a box containing the text zyBooks. RC = 1 is displayed next to the zyBooks box. string1 and the arrow and the zyBooks box remain inside the larger transparent box with the label Objects that cannot be deallocated. The box containing the text Python is moved to a new transparent box labeled Objects that can be deallocated. The Python box has the text RC = 0 next to it. Step 5: After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated. The line of code string2 = string1 is highlighted. The diagram of the Objects that cannot be deallocated box is modified slightly. string2 now has an arrow that points to the zyBooks box, and string2 no longer points to the Computer Science box. The zyBooks box now has the text RC = 2 next to it. The Computer Science box now has the text RC = 1 next to it. Step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. A box appears with the label Python Garbage Collector. A symbol similar to a clamp appears, grabbing the Python box and moving it from the Objects that can be deallocated box to a new box with the label Deallocated objects.\n\nCaptions\nThe variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.\nThe "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2.\nReference counts > 0 imply that neither object can be deallocated.\nWhen string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.\nAfter assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.\nThe Python garbage collector will eventually deallocate objects that are no longer referenced.\nPlaying step 6: The Python garbage collector will eventually deallocate objects that are no longer referenced. Step finished playing\n\nFeedback?\'\'\'\ndef participation_activity_9_10_3():\n    string1 = "Python"\n    string2 = "Computer science"\n    string3 = string2\n    string1 = "zyBooks"\n    string2 = string1\n\n    # The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.\n    print("True","string1 references \'Python\', while string2 and string3 both reference \'Computer science\'.")\n    # The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object\'s RC is 2.\n    print("True","The \'Python\' object is referenced by only string1, so its RC is 1. The \'Computer science\' object is referenced by both string2 and string3, so its RC is 2.")\n    # Reference counts > 0 imply that neither object can be deallocated.\n    print("True","Both objects have RC > 0, so neither can be deallocated.")\n    # When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.\n    print("True","When string1 references \'zyBooks\', the \'Python\' object has no variables referencing it, so it can be deallocated.")\n    # After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.\n    print("True","After assigning string2 with \'zyBooks\', the \'Computer science\' object is still referenced by string3, so it cannot be deallocated.")\n    # The Python garbage collector will eventually deallocate objects that are no longer referenced.\n    print("True","The Python garbage collector will eventually deallocate objects that are no longer referenced, such as the \'Python\' object in this example.")\nparticipation_activity_9_10_3()',
  'from IPython.core.interactiveshell import InteractiveShell\nInteractiveShell.ast_node_interactivity = "all"',
  'import builtins\n\n# Store the original input function once, globally, to avoid re-capturing a mocked input\nif not hasattr(builtins, \'_original_input_backup\'):\n    builtins._original_input_backup = builtins.input\n\ndef set_test_inputs(inputs_list):\n    """\n    Sets up a mock input function that draws from a list of inputs.\n    If inputs_list is None or empty, restores the original input function.\n    """\n    if inputs_list:\n        input_iter = iter(inputs_list)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup\n\n# Define test_inputs, this is where you can change your desired inputs\ntest_inputs = [1]  # <--- Change this list to provide your test inputs\n\n# Apply the test inputs automatically when this cell is run\nset_test_inputs(test_inputs)\n\n# Example of how to revert to normal input:\n# set_test_inputs(None)\n# Or to set new inputs dynamically:\n# set_test_inputs(["new_input_1", "new_input_2"])\n\n#===\n\ndef setin(*inputs):\n    """\n    A helper function to set test inputs for the input() function.\n    Usage:\n    setin("input1", "input2", "input3")\n    This will set up the input() function to return "input1" on the first call,\n    "input2" on the second call, and so on.\n    To reset to normal input behavior, call setin() with no arguments or None:\n    setin()\n    """\n    if inputs:\n        input_iter = iter(inputs)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup',
  'setin("1","2","3")  # Example usage, you can change the input value as needed\ninput()\ninput()\ninput()',
  'from IPython.core.interactiveshell import InteractiveShell\nInteractiveShell.ast_node_interactivity = "all"',
  'import builtins\n\n# Store the original input function once, globally, to avoid re-capturing a mocked input\nif not hasattr(builtins, \'_original_input_backup\'):\n    builtins._original_input_backup = builtins.input\n\ndef set_test_inputs(inputs_list):\n    """\n    Sets up a mock input function that draws from a list of inputs.\n    If inputs_list is None or empty, restores the original input function.\n    """\n    if inputs_list:\n        input_iter = iter(inputs_list)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup\n\n# Define test_inputs, this is where you can change your desired inputs\ntest_inputs = [1]  # <--- Change this list to provide your test inputs\n\n# Apply the test inputs automatically when this cell is run\nset_test_inputs(test_inputs)\n\n# Example of how to revert to normal input:\n# set_test_inputs(None)\n# Or to set new inputs dynamically:\n# set_test_inputs(["new_input_1", "new_input_2"])\n\n#===\n\ndef setin(*inputs):\n    """\n    A helper function to set test inputs for the input() function.\n    Usage:\n    setin("input1", "input2", "input3")\n    This will set up the input() function to return "input1" on the first call,\n    "input2" on the second call, and so on.\n    To reset to normal input behavior, call setin() with no arguments or None:\n    setin()\n    """\n    if inputs:\n        input_iter = iter(inputs)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup',
...
 '_i5': 'from IPython.core.interactiveshell import InteractiveShell\nInteractiveShell.ast_node_interactivity = "all"',
 '_i6': 'import builtins\n\n# Store the original input function once, globally, to avoid re-capturing a mocked input\nif not hasattr(builtins, \'_original_input_backup\'):\n    builtins._original_input_backup = builtins.input\n\ndef set_test_inputs(inputs_list):\n    """\n    Sets up a mock input function that draws from a list of inputs.\n    If inputs_list is None or empty, restores the original input function.\n    """\n    if inputs_list:\n        input_iter = iter(inputs_list)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup\n\n# Define test_inputs, this is where you can change your desired inputs\ntest_inputs = [1]  # <--- Change this list to provide your test inputs\n\n# Apply the test inputs automatically when this cell is run\nset_test_inputs(test_inputs)\n\n# Example of how to revert to normal input:\n# set_test_inputs(None)\n# Or to set new inputs dynamically:\n# set_test_inputs(["new_input_1", "new_input_2"])\n\n#===\n\ndef setin(*inputs):\n    """\n    A helper function to set test inputs for the input() function.\n    Usage:\n    setin("input1", "input2", "input3")\n    This will set up the input() function to return "input1" on the first call,\n    "input2" on the second call, and so on.\n    To reset to normal input behavior, call setin() with no arguments or None:\n    setin()\n    """\n    if inputs:\n        input_iter = iter(inputs)\n        def mock_input(prompt=""):\n            try:\n                value = next(input_iter)\n                print(f"{prompt}{value}")\n                return value\n            except StopIteration:\n                raise EOFError("No more inputs for testing")\n        builtins.input = mock_input\n    else:\n        builtins.input = builtins._original_input_backup',
 '_i7': 'setin("1","2","3")  # Example usage, you can change the input value as needed\ninput()\ninput()\ninput()',
 '_7': '3',
 '_i8': 'globals()'}
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...'''

# The variable string1 is a reference to the "Python" string object. string2 and string3 both reference the "Computer Science" string object.
# The "Python" string object is referenced by 1 variable and therefore has a reference count (RC) of 1. The "Computer science" string object's RC is 2.
# Reference counts > 0 imply that neither object can be deallocated.
# When string1 is reassigned to reference the "zyBooks" string, the "Python" string object is no longer referenced and can be deallocated.
# After assigning string2 with "zyBooks", "Computer Science" is still referenced by string3 and cannot be deallocated.
# The Python garbage collector will eventually deallocate objects that are no longer referenced.


#thanks!

del temp

# %%
'''participation activity

## 

9.10.4: Reference counts and garbage collection.

1)

An object with a reference count of 0 can be deallocated by the garbage collector.

True

False

2)

Immediately after an object's reference count is decremented from 1 to 0, the garbage collector deallocates the object.

True

False

3)

Swapping variables string1 and string2 with the code below is potentially problematic, because a moment exists when the "zyBooks" string has a reference count of 0.

string1 \= "zyBooks"
string2 \= "Computer science"

temp \= string1
string1 \= string2
string2 \= temp

True

False

Feedback?

'''
def participation_activity_9_10_4():
    # 1) An object with a reference count of 0 can be deallocated by the garbage collector.
    print("True","An object with a reference count of 0 can be deallocated by the garbage collector.")
    # 2) Immediately after an object's reference count is decremented from 1 to 0, the garbage collector deallocates the object.
    print("False","The garbage collector does not necessarily deallocate an object immediately after its reference count is decremented from 1 to 0.")
    # 3) Swapping variables string1 and string2 with the code below is potentially problematic, because a moment exists when the "zyBooks" string has a reference count of 0.
    print("False","Swapping variables string1 and string2 with the code below is not potentially problematic, because Python's garbage collector will not deallocate the \'zyBooks\' string until after it is no longer referenced by either variable (after both lines of code have executed).")
participation_activity_9_10_4()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\='
# <>:1: SyntaxWarning: invalid escape sequence '\='
# /tmp/ipykernel_21732/636245583.py:1: SyntaxWarning: invalid escape sequence '\='
#   '''participation activity
# 'participation activity\n\n## \n\n9.10.4: Reference counts and garbage collection.\n\n1)\n\nAn object with a reference count of 0 can be deallocated by the garbage collector.\n\nTrue\n\nFalse\n\n2)\n\nImmediately after an object\'s reference count is decremented from 1 to 0, the garbage collector deallocates the object.\n\nTrue\n\nFalse\n\n3)\n\nSwapping variables string1 and string2 with the code below is potentially problematic, because a moment exists when the "zyBooks" string has a reference count of 0.\n\nstring1 \\= "zyBooks"\nstring2 \\= "Computer science"\n\ntemp \\= string1\nstring1 \\= string2\nstring2 \\= temp\n\nTrue\n\nFalse\n\nFeedback?\n\n'
# True An object with a reference count of 0 can be deallocated by the garbage collector.
# ...

# %%
string1 = "zyBooks"
string2 = "Computer science"

temp = string1
string1 = string2
string2 = temp

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

s1="Python"
s2="Computer science"
s3=s2
s1="zyBooks"
s2=s1

s1="Python"
s1
s2="Computer science"
s1,s2
s3=s2
s1,s2,s3
s1="zyBooks"
s1,s2,s3
s2=s1
s1,s2,s3
# Out:
# 'Python'
# ('Python', 'Computer science')
# ('Python', 'Computer science', 'Computer science')
# ('zyBooks', 'Computer science', 'Computer science')
# ('zyBooks', 'zyBooks', 'Computer science')

# %%
# how find refrence count of an object in python?
# You can use the `sys.getrefcount()` function from the `sys` module to find the reference count of an object in Python. Here's how you can do it:
import sys
my_object_unique = "Hello, World!"
reference_count = sys.getrefcount(my_object_unique)
print(f"The reference count of my_object_unique is: {reference_count}") #The reference count of my_object_unique is: 3
# Out:
# The reference count of my_object_unique is: 3

# %%
import sys
a="google"
reference_count = sys.getrefcount(a)
print(f"The reference count of a is: {reference_count}") #The reference count of a is: 4294967295

#what?
# The reference count of a is: 4294967295
# Out:
# The reference count of a is: 4294967295

# %%
import sys
superduperlongwordywordvariablenameismeanttoexceedthetypicallengthofvariablenamesandtestthegarbagecollectionmechanismofpythonbyhavingaverylongvariablenameasareferenceforastringobject = "This is a test string to check the reference count of a long variable name."

reference_count = sys.getrefcount(superduperlongwordywordvariablenameismeanttoexceedthetypicallengthofvariablenamesandtestthegarbagecollectionmechanismofpythonbyhavingaverylongvariablenameasareferenceforastringobject)
print(f"The reference count of the long variable name is: {reference_count}") #The reference count of the long variable name is: 3
# Out:
# The reference count of the long variable name is: 3

# %%
#how can i find when python deallocates an object?
# You can find out when Python deallocates an object by using the `__del__` method in a class. This method is called when an object is about to be destroyed, which can give you insight into when the garbage collector deallocates the object. Here's an example:
import sys
class MyClass:
    def __init__(self, name):
        self.name = name
        print(f"{self.name} created. Reference count: {sys.getrefcount(self)}")
    
    def __del__(self):
        print(f"{self.name} is being deallocated. Reference count: {sys.getrefcount(self)}")
obj = MyClass("Test Object")
del obj
# Out:
# Test Object created. Reference count: 3
# Test Object is being deallocated. Reference count: 3

# %% [markdown]
# ## 9.11 LAB: Car value (classes)
#
# ### LAB ACTIVITY: LAB: Car value (classes)
#
# Complete the `Car` class by creating an attribute purchase_price (type int) and the method print_info() that outputs the car's information.
# Ex: If the input is:
#
# ```
# 2011
# 18000
# 2018
# ```
# where 2011 is the car's model year, 18000 is the purchase price, and 2018 is the current year, then print_info() outputs:
#
# ```
# Car's information:
#   Model year: 2011
#   Purchase price: $18000
#   Current value: $5770
# ```
# Note: print_info() should use two spaces for indentation.
#
# **Test Cases:**
# | # | Input | Expected Output | Points |
# |---|-------|-----------------|--------|
# | 1 | `2011\n18000\n2018` | `Car's information:\n  Model year: 2011\n  Purchase price: $18000\n  Current value: $5770` | 2 |
# | 2 | `1995\n32000\n2020` | `Car's information:\n  Model year: 1995\n  Purchase price: $32000\n  Current value: $550` | 2 |
# | 3 | `(none)` | `` | 4 |
# | 4 | `(none)` | `` | 2 |
# *Total: 10 points*

# %%
'''## 9.11 LAB: Car value (classes)

### LAB ACTIVITY: LAB: Car value (classes)

Complete the `Car` class by creating an attribute purchase_price (type int) and the method print_info() that outputs the car's information.
Ex: If the input is:

```
2011
18000
2018
```
where 2011 is the car's model year, 18000 is the purchase price, and 2018 is the current year, then print_info() outputs:

```
Car's information:
  Model year: 2011
  Purchase price: $18000
  Current value: $5770
```
Note: print_info() should use two spaces for indentation.

**Test Cases:**
| # | Input | Expected Output | Points |
|---|-------|-----------------|--------|
| 1 | `2011\n18000\n2018` | `Car's information:\n  Model year: 2011\n  Purchase price: $18000\n  Current value: $5770` | 2 |
| 2 | `1995\n32000\n2020` | `Car's information:\n  Model year: 1995\n  Purchase price: $32000\n  Current value: $550` | 2 |
| 3 | `(none)` | `` | 4 |
| 4 | `(none)` | `` | 2 |
*Total: 10 points*

```python
class Car:

    def __init__(self):
        self.model_year = 0
        # TODO: Declare purchase_price attribute

        self.current_value = 0

    def calc_current_value(self, current_year):
        depreciation_rate = 0.15
        # Car depreciation formula
        car_age = current_year - self.model_year
        self.current_value = round(self.purchase_price *
                                   (1 - depreciation_rate)**car_age)

    # TODO: Define print_info() method to output model_year, purchase_price, and current_value


if __name__ == "__main__":
    year = int(input())
    price = int(input())
    current_year = int(input())

    my_car = Car()
    my_car.model_year = year
    my_car.purchase_price = price
    my_car.calc_current_value(current_year)
    my_car.print_info()

```
'''
# Out:
# '## 9.11 LAB: Car value (classes)\n\n### LAB ACTIVITY: LAB: Car value (classes)\n\nComplete the `Car` class by creating an attribute purchase_price (type int) and the method print_info() that outputs the car\'s information.\nEx: If the input is:\n\n```\n2011\n18000\n2018\n```\nwhere 2011 is the car\'s model year, 18000 is the purchase price, and 2018 is the current year, then print_info() outputs:\n\n```\nCar\'s information:\n  Model year: 2011\n  Purchase price: $18000\n\xa0 Current value: $5770\n```\nNote: print_info() should use two spaces for indentation.\n\n**Test Cases:**\n| # | Input | Expected Output | Points |\n|---|-------|-----------------|--------|\n| 1 | `2011\n18000\n2018` | `Car\'s information:\n  Model year: 2011\n  Purchase price: $18000\n  Current value: $5770` | 2 |\n| 2 | `1995\n32000\n2020` | `Car\'s information:\n  Model year: 1995\n  Purchase price: $32000\n  Current value: $550` | 2 |\n| 3 | `(none)` | `` | 4 |\n| 4 | `(none)` | `` | 2 |\n*Total: 10 points*\n\
# ...

# %%
def lab_9_11():
    setin("2011","18000","2018")  # Example usage, you can change the input value as needed
    class Car:

        def __init__(self):
            self.model_year = 0
            # TODO: Declare purchase_price attribute
            self.purchase_price = 0

            self.current_value = 0

        def calc_current_value(self, current_year):
            depreciation_rate = 0.15
            # Car depreciation formula
            car_age = current_year - self.model_year
            self.current_value = round(self.purchase_price *
                                    (1 - depreciation_rate)**car_age)

        # TODO: Define print_info() method to output model_year, purchase_price, and current_value
        def print_info(self):
            print("Car's information:")
            print("  Model year: {}".format(self.model_year))
            print("  Purchase price: ${}".format(self.purchase_price))
            print("  Current value: ${}".format(self.current_value))


    if __name__ == "__main__":
        year = int(input())
        price = int(input())
        current_year = int(input())

        my_car = Car()
        my_car.model_year = year
        my_car.purchase_price = price
        my_car.calc_current_value(current_year)
        my_car.print_info()
lab_9_11()
# Out:
# 2011
# 18000
# 2018
# Car's information:
#   Model year: 2011
#   Purchase price: $18000
#   Current value: $5770

# %%
setin("2011","18000","2018")

class Car:

    def __init__(self):
        self.model_year = 0
        self.purchase_price = 0
        self.current_value = 0
    def calc_current_value(self, current_year):
        depreciation_rate = 0.15
        car_age = current_year - self.model_year
        self.current_value = round(self.purchase_price *
                                   (1 - depreciation_rate)**car_age)
    def print_info(self):
        print("Car's information:")
        print("  Model year: {}".format(self.model_year))
        print("  Purchase price: ${}".format(self.purchase_price))
        print("  Current value: ${}".format(self.current_value))
    
if __name__ == "__main__":
    year = int(input())
    price = int(input())
    current_year = int(input())

    my_car = Car()
    my_car.model_year = year
    my_car.purchase_price = price
    my_car.calc_current_value(current_year)
    my_car.print_info()
# Out:
# 2011
# 18000
# 2018
# Car's information:
#   Model year: 2011
#   Purchase price: $18000
#   Current value: $5770

# %% [markdown]
# ## 9.12 LAB: Nutritional information (classes/constructors)
#
# ### LAB ACTIVITY: LAB: Nutritional information (classes/constructors)
#
# Complete the `FoodItem` class by adding a constructor to initialize a food item. The constructor should initialize the name (a string) to "Water" and all other instance attributes to 0.0 by default. If the constructor is called with a food name, grams of fat, grams of carbohydrates, and grams of protein, the constructor should assign each instance attribute with the appropriate parameter value.
# The given program accepts as input a food item name, amount of fat, carbs, and protein, and the number of servings. The program creates a food item using the constructor parameters' default values and a food item using the input values. The program outputs the nutritional information and calories per serving for a food item.
# Ex: If the input is:
#
# ```
# Water
# ```
# the output is:
#
# ```
# Nutritional information per serving of Water:
#   Fat: 0.00 g
#   Carbohydrates: 0.00 g
#   Protein: 0.00 g
# Number of calories for 1.00 serving(s): 0.00
# ```
# Ex: If the input is:
#
# ```
# M&M's
# 10.0
# 34.0
# 2.0
# 3.0
# ```
# where M&M's is the food name, 10.0 is the grams of fat, 34.0 is the grams of carbohydrates, 2.0 is the grams of protein, and 3.0 is the number of servings, the output is:
#
# ```
# Nutritional information per serving of M&M's:
#   Fat: 10.00 g
#   Carbohydrates: 34.00 g
#   Protein: 2.00 g
# Number of calories for 1.00 serving(s): 234.00
# Number of calories for 3.00 serving(s): 702.00
# ```
# Note: The program outputs the number of calories for one serving of a food and for the input number of servings as well. The program only outputs the calories for one serving of water.
#
# **Test Cases:**
# | # | Input | Expected Output | Points |
# |---|-------|-----------------|--------|
# | 1 | `Water` | `Nutritional information per serving of Water:\n  Fat: 0.00 g\n  Carbohydrates: 0.00 g\n  Protein: 0.00 g\nNumber of calories for 1.00 serving(s): 0.00` | 1 |
# | 2 | `M&M's\n10.0\n34.0\n2.0\n3.0` | `Nutritional information per serving of M&M's:\n  Fat: 10.00 g\n  Carbohydrates: 34.00 g\n  Protein: 2.00 g\nNumber of calories for 1.00 serving(s): 234.00\nNumber of calories for 3.00 serving(s): 702.00` | 2 |
# | 3 | `Cabbage\n0.1\n6.0\n1.5\n5.5` | `Nutritional information per serving of Cabbage:\n  Fat: 0.10 g\n  Carbohydrates: 6.00 g\n  Protein: 1.50 g\nNumber of calories for 1.00 serving(s): 30.90\nNumber of calories for 5.50 serving(s): 169.95` | 2 |
# | 4 | `(none)` | `` | 2 |
# | 5 | `(none)` | `` | 2 |
# | 6 | `(none)` | `` | 1 |
# *Total: 10 points*

# %%
'''## 9.12 LAB: Nutritional information (classes/constructors)

### LAB ACTIVITY: LAB: Nutritional information (classes/constructors)

Complete the `FoodItem` class by adding a constructor to initialize a food item. The constructor should initialize the name (a string) to "Water" and all other instance attributes to 0.0 by default. If the constructor is called with a food name, grams of fat, grams of carbohydrates, and grams of protein, the constructor should assign each instance attribute with the appropriate parameter value.
The given program accepts as input a food item name, amount of fat, carbs, and protein, and the number of servings. The program creates a food item using the constructor parameters' default values and a food item using the input values. The program outputs the nutritional information and calories per serving for a food item.
Ex: If the input is:

```
Water
```
the output is:

```
Nutritional information per serving of Water:
  Fat: 0.00 g
  Carbohydrates: 0.00 g
  Protein: 0.00 g
Number of calories for 1.00 serving(s): 0.00
```
Ex: If the input is:

```
M&M's
10.0
34.0
2.0
3.0
```
where M&M's is the food name, 10.0 is the grams of fat, 34.0 is the grams of carbohydrates, 2.0 is the grams of protein, and 3.0 is the number of servings, the output is:

```
Nutritional information per serving of M&M's:
  Fat: 10.00 g
  Carbohydrates: 34.00 g
  Protein: 2.00 g
Number of calories for 1.00 serving(s): 234.00
Number of calories for 3.00 serving(s): 702.00
```
Note: The program outputs the number of calories for one serving of a food and for the input number of servings as well. The program only outputs the calories for one serving of water.

**Test Cases:**
| # | Input | Expected Output | Points |
|---|-------|-----------------|--------|
| 1 | `Water` | `Nutritional information per serving of Water:\n  Fat: 0.00 g\n  Carbohydrates: 0.00 g\n  Protein: 0.00 g\nNumber of calories for 1.00 serving(s): 0.00` | 1 |
| 2 | `M&M's\n10.0\n34.0\n2.0\n3.0` | `Nutritional information per serving of M&M's:\n  Fat: 10.00 g\n  Carbohydrates: 34.00 g\n  Protein: 2.00 g\nNumber of calories for 1.00 serving(s): 234.00\nNumber of calories for 3.00 serving(s): 702.00` | 2 |
| 3 | `Cabbage\n0.1\n6.0\n1.5\n5.5` | `Nutritional information per serving of Cabbage:\n  Fat: 0.10 g\n  Carbohydrates: 6.00 g\n  Protein: 1.50 g\nNumber of calories for 1.00 serving(s): 30.90\nNumber of calories for 5.50 serving(s): 169.95` | 2 |
| 4 | `(none)` | `` | 2 |
| 5 | `(none)` | `` | 2 |
| 6 | `(none)` | `` | 1 |
*Total: 10 points*
```python
class FoodItem:
    # TODO: Define constructor with parameters to initialize instance
    #       attributes (name, fat, carbs, protein)

    def get_calories(self, num_servings):
        # Calorie formula
        calories = ((self.fat * 9) + (self.carbs * 4) +
                    (self.protein * 4)) * num_servings
        return calories

    def print_info(self):
        print(f"Nutritional information per serving of {self.name}:")
        print(f"  Fat: {self.fat:.2f} g")
        print(f"  Carbohydrates: {self.carbs:.2f} g")
        print(f"  Protein: {self.protein:.2f} g")


if __name__ == "__main__":

    item_name = input()
    if item_name == "Water" or item_name == "water":
        food_item = FoodItem()
        food_item.print_info()
        print(
            f"Number of calories for {1.0:.2f} serving(s): {food_item.get_calories(1.0):.2f}"
        )

    else:
        amount_fat = float(input())
        amount_carbs = float(input())
        amount_protein = float(input())
        num_servings = float(input())

        food_item = FoodItem(item_name, amount_fat, amount_carbs,
                             amount_protein)
        food_item.print_info()
        print(
            f"Number of calories for {1.0:.2f} serving(s): {food_item.get_calories(1.0):.2f}"
        )
        print(
            f"Number of calories for {num_servings:.2f} serving(s): {food_item.get_calories(num_servings):.2f}"
        )

```
'''

def lab_9_12():
    setin("M&M's","10.0","34.0","2.0","3.0")  # Example usage, you can change the input value as needed
    class FoodItem:
        # TODO: Define constructor with parameters to initialize instance
        #       attributes (name, fat, carbs, protein)

        def __init__(self, name="Water", fat=0.0, carbs=0.0, protein=0.0):
            self.name = name
            self.fat = fat
            self.carbs = carbs
            self.protein = protein

        def get_calories(self, num_servings):
            # Calorie formula
            calories = ((self.fat * 9) + (self.carbs * 4) +
                        (self.protein * 4)) * num_servings
            return calories

        def print_info(self):
            print(f"Nutritional information per serving of {self.name}:")
            print(f"  Fat: {self.fat:.2f} g")
            print(f"  Carbohydrates: {self.carbs:.2f} g")
            print(f"  Protein: {self.protein:.2f} g")


    if __name__ == "__main__":

        item_name = input()
        if item_name == "Water" or item_name == "water":
            food_item = FoodItem()
            food_item.print_info()
            print(
                f"Number of calories for {1.0:.2f} serving(s): {food_item.get_calories(1.0):.2f}"
            )

        else:
            amount_fat = float(input())
            amount_carbs = float(input())
            amount_protein = float(input())
            num_servings = float(input())

            food_item = FoodItem(item_name, amount_fat, amount_carbs,
                                amount_protein)
            food_item.print_info()
            print(
                f"Number of calories for {1.0:.2f} serving(s): {food_item.get_calories(1.0):.2f}"
            )
            print(
                f"Number of calories for {num_servings:.2f} serving(s): {food_item.get_calories(num_servings):.2f}"
            )
lab_9_12()
# Out:
# '## 9.12 LAB: Nutritional information (classes/constructors)\n\n### LAB ACTIVITY: LAB: Nutritional information (classes/constructors)\n\nComplete the `FoodItem` class by adding a constructor to initialize a food item. The constructor should initialize the name (a string) to "Water" and all other instance attributes to 0.0 by default. If the constructor is called with a food name, grams of fat, grams of carbohydrates, and grams of protein, the constructor should assign each instance attribute with the appropriate parameter value.\nThe given program accepts as input a food item name, amount of fat, carbs, and protein, and the number of servings. The program creates a food item using the constructor parameters\' default values and a food item using the input values. The program outputs the nutritional information and calories per serving for a food item.\nEx: If the input is:\n\n```\nWater\n```\nthe output is:\n\n```\nNutritional information per serving of Water:\n  Fat: 0.00 g\n  Carbo
# ...

# %% [markdown]
# ## 9.13 LAB: Artwork label (classes/constructors)
#
# ### LAB ACTIVITY: LAB: Artwork label (classes/constructors)
#
# Define the `Artist` class with a constructor to initialize an artist's information and a print_info() method. The constructor should by default initialize the artist's name to "unknown" and the years of birth and death to -1. print_info() displays "Artist:", then a space, then the artist's name, then another space, then the birth and death dates in one of three formats:
# - `(XXXX to YYYY)` if both the birth and death years are nonnegative- `(XXXX to present)` if the birth year is nonnegative and the death year is negative- `(unknown)` otherwiseDefine the `Artwork` class with a constructor to initialize an artwork's information and a print_info() method. The constructor should by default initialize the title to "unknown", the year created to -1, and the artist to use the `Artist` default constructor parameter values.
# Ex: If the input is:
#
# ```
# Pablo Picasso
# 1881
# 1973
# Three Musicians
# 1921
# ```
# the output is:
#
# ```
# Artist: Pablo Picasso (1881 to 1973)
# Title: Three Musicians, 1921
# ```
# Ex: If the input is:
#
# ```
# Brice Marden
# 1938
# -1
# Distant Muses
# 2000
# ```
# the output is:
#
# ```
# Artist: Brice Marden (1938 to present)
# Title: Distant Muses, 2000
# ```
# Ex: If the input is:
#
# ```
# Banksy
# -1
# -1
# Balloon Girl
# 2002
# ```
# the output is:
#
# ```
# Artist: Banksy (unknown)
# Title: Balloon Girl, 2002
# ```
#
# **Test Cases:**
# | # | Input | Expected Output | Points |
# |---|-------|-----------------|--------|
# | 1 | `Pablo Picasso\n1881\n1973\nThree Musicians\n1921` | `Artist: Pablo Picasso (1881 to 1973)\nTitle: Three Musicians, 1921` | 1 |
# | 2 | `Brice Marden\n1938\n-1\nDistant Muses\n2000\n` | `Artist: Brice Marden (1938 to present)\nTitle: Distant Muses, 2000` | 1 |
# | 3 | `Banksy\n-1\n-1\nBalloon Girl\n2002` | `Artist: Banksy (unknown)\nTitle: Balloon Girl, 2002` | 1 |
# | 4 | `(none)` | `` | 2 |
# | 5 | `(none)` | `` | 2 |
# | 6 | `(none)` | `` | 2 |
# | 7 | `(none)` | `` | 1 |
# *Total: 10 points*

# %%
'''## 9.13 LAB: Artwork label (classes/constructors)

### LAB ACTIVITY: LAB: Artwork label (classes/constructors)

Define the `Artist` class with a constructor to initialize an artist's information and a print_info() method. The constructor should by default initialize the artist's name to "unknown" and the years of birth and death to -1. print_info() displays "Artist:", then a space, then the artist's name, then another space, then the birth and death dates in one of three formats:
- `(XXXX to YYYY)` if both the birth and death years are nonnegative- `(XXXX to present)` if the birth year is nonnegative and the death year is negative- `(unknown)` otherwiseDefine the `Artwork` class with a constructor to initialize an artwork's information and a print_info() method. The constructor should by default initialize the title to "unknown", the year created to -1, and the artist to use the `Artist` default constructor parameter values.
Ex: If the input is:

```
Pablo Picasso
1881
1973
Three Musicians
1921
```
the output is:

```
Artist: Pablo Picasso (1881 to 1973)
Title: Three Musicians, 1921
```
Ex: If the input is:

```
Brice Marden
1938
-1
Distant Muses
2000
```
the output is:

```
Artist: Brice Marden (1938 to present)
Title: Distant Muses, 2000
```
Ex: If the input is:

```
Banksy
-1
-1
Balloon Girl
2002
```
the output is:

```
Artist: Banksy (unknown)
Title: Balloon Girl, 2002
```

**Test Cases:**
| # | Input | Expected Output | Points |
|---|-------|-----------------|--------|
| 1 | `Pablo Picasso\n1881\n1973\nThree Musicians\n1921` | `Artist: Pablo Picasso (1881 to 1973)\nTitle: Three Musicians, 1921` | 1 |
| 2 | `Brice Marden\n1938\n-1\nDistant Muses\n2000\n` | `Artist: Brice Marden (1938 to present)\nTitle: Distant Muses, 2000` | 1 |
| 3 | `Banksy\n-1\n-1\nBalloon Girl\n2002` | `Artist: Banksy (unknown)\nTitle: Balloon Girl, 2002` | 1 |
| 4 | `(none)` | `` | 2 |
| 5 | `(none)` | `` | 2 |
| 6 | `(none)` | `` | 2 |
| 7 | `(none)` | `` | 1 |
*Total: 10 points*'''
def lab_9_13():
    setin("Pablo Picasso","1881","1973","Three Musicians","1921")  # Example usage, you can change the input value as needed
    class Artist:
        def __init__(self, name="unknown", birth_year=-1, death_year=-1):
            self.name = name
            self.birth_year = birth_year
            self.death_year = death_year

        def print_info(self):
            if self.birth_year >= 0 and self.death_year >= 0:
                print(f"Artist: {self.name} ({self.birth_year} to {self.death_year})")
            elif self.birth_year >= 0 and self.death_year < 0:
                print(f"Artist: {self.name} ({self.birth_year} to present)")
            else:
                print(f"Artist: {self.name} (unknown)")

    class Artwork:
        def __init__(self, title="unknown", year_created=-1, artist=Artist()):
            self.title = title
            self.year_created = year_created
            self.artist = artist

        def print_info(self):
            self.artist.print_info()
            print(f"Title: {self.title}, {self.year_created}")


    if __name__ == "__main__":
        artist_name = input()
        birth_year = int(input())
        death_year = int(input())
        artwork_title = input()
        artwork_year = int(input())

        artist = Artist(artist_name, birth_year, death_year)
        artwork = Artwork(artwork_title, artwork_year, artist)
        artwork.print_info()
lab_9_13()
# Out:
# '## 9.13 LAB: Artwork label (classes/constructors)\n\n### LAB ACTIVITY: LAB: Artwork label (classes/constructors)\n\nDefine the `Artist` class with a constructor to initialize an artist\'s information and a print_info() method. The constructor should by default initialize the artist\'s name to "unknown" and the years of birth and death to -1. print_info() displays "Artist:", then a space, then the artist\'s name, then another space, then the birth and death dates in one of three formats:\n- `(XXXX to YYYY)` if both the birth and death years are nonnegative- `(XXXX to present)` if the birth year is nonnegative and the death year is negative- `(unknown)` otherwiseDefine the `Artwork` class with a constructor to initialize an artwork\'s information and a print_info() method. The constructor should by default initialize the title to "unknown", the year created to -1, and the artist to use the `Artist` default constructor parameter values.\nEx: If the input is:\n\n```\nPablo Picasso\n1881
# ...

# %% [markdown]
# ## 9.14 LAB: Triangle area comparison (classes)
#
# ### LAB ACTIVITY: LAB: Triangle area comparison (classes)
#
# Given class `Triangle`, complete the program to read and set the base and height of triangle1 and triangle2, determine which triangle's area is smaller, and output the smaller triangle's info, making use of `Triangle`'s relevant methods.
# Ex: If the input is:
#
# ```
# 3.0
# 4.0
# 4.0
# 5.0
# ```
# where 3.0 is triangle1's base, 4.0 is triangle1's height, 4.0 is triangle2's base, and 5.0 is triangle2's height, the output is:
#
# ```
# Triangle with smaller area:
# Base: 3.00
# Height: 4.00
# Area: 6.00
# ```
#
# **Test Cases:**
# | # | Input | Expected Output | Points |
# |---|-------|-----------------|--------|
# | 1 | `3.0\n4.0\n4.0\n5.0` | `Triangle with smaller area:\nBase: 3.00\nHeight: 4.00\nArea: 6.00` | 2 |
# | 2 | `12.0\n16.0\n10.0\n18.0` | `Triangle with smaller area:\nBase: 10.00\nHeight: 18.00\nArea: 90.00` | 2 |
# | 3 | `6.5\n2.0\n3.0\n4.5` | `Triangle with smaller area:\nBase: 6.50\nHeight: 2.00\nArea: 6.50` | 2 |
# | 4 | `15.5\n2.3\n16.1\n2.0` | `Triangle with smaller area:\nBase: 16.10\nHeight: 2.00\nArea: 16.10` | 2 |
# | 5 | `23.4\n12.3\n4.5\n43.2` | `Triangle with smaller area:\nBase: 4.50\nHeight: 43.20\nArea: 97.20` | 2 |
# *Total: 10 points*

# %%
'''## 9.14 LAB: Triangle area comparison (classes)

### LAB ACTIVITY: LAB: Triangle area comparison (classes)

Given class `Triangle`, complete the program to read and set the base and height of triangle1 and triangle2, determine which triangle's area is smaller, and output the smaller triangle's info, making use of `Triangle`'s relevant methods.
Ex: If the input is:

```
3.0
4.0
4.0
5.0
```
where 3.0 is triangle1's base, 4.0 is triangle1's height, 4.0 is triangle2's base, and 5.0 is triangle2's height, the output is:

```
Triangle with smaller area:
Base: 3.00
Height: 4.00
Area: 6.00
```

**Test Cases:**
| # | Input | Expected Output | Points |
|---|-------|-----------------|--------|
| 1 | `3.0\n4.0\n4.0\n5.0` | `Triangle with smaller area:\nBase: 3.00\nHeight: 4.00\nArea: 6.00` | 2 |
| 2 | `12.0\n16.0\n10.0\n18.0` | `Triangle with smaller area:\nBase: 10.00\nHeight: 18.00\nArea: 90.00` | 2 |
| 3 | `6.5\n2.0\n3.0\n4.5` | `Triangle with smaller area:\nBase: 6.50\nHeight: 2.00\nArea: 6.50` | 2 |
| 4 | `15.5\n2.3\n16.1\n2.0` | `Triangle with smaller area:\nBase: 16.10\nHeight: 2.00\nArea: 16.10` | 2 |
| 5 | `23.4\n12.3\n4.5\n43.2` | `Triangle with smaller area:\nBase: 4.50\nHeight: 43.20\nArea: 97.20` | 2 |
*Total: 10 points*

```python
class Triangle:

    def __init__(self):
        self.base = 0
        self.height = 0

    def set_base(self, user_base):
        self.base = user_base

    def set_height(self, user_height):
        self.height = user_height

    def get_area(self):
        area = 0.5 * self.base * self.height
        return area

    def print_info(self):
        print(f"Base: {self.base:.2f}")
        print(f"Height: {self.height:.2f}")
        print(f"Area: {self.get_area():.2f}")


if __name__ == "__main__":
    triangle1 = Triangle()
    triangle2 = Triangle()

    # TODO: Read and set base and height for triangle1 (use set_base() and set_height())

    # TODO: Read and set base and height for triangle2 (use set_base() and set_height())

    print("Triangle with smaller area:")

    # TODO: Determine smaller triangle (use get_area())
    #       and output smaller triangle's info (use print_info())

```
'''
def lab_9_14():
    setin("3.0","4.0","4.0","5.0")  # Example usage, you can change the input value as needed
    class Triangle:

        def __init__(self):
            self.base = 0
            self.height = 0

        def set_base(self, user_base):
            self.base = user_base

        def set_height(self, user_height):
            self.height = user_height

        def get_area(self):
            area = 0.5 * self.base * self.height
            return area

        def print_info(self):
            print(f"Base: {self.base:.2f}")
            print(f"Height: {self.height:.2f}")
            print(f"Area: {self.get_area():.2f}")
    if __name__ == "__main__":
        triangle1 = Triangle()
        triangle2 = Triangle()

        # Read and set base and height for triangle1
        triangle1.set_base(float(input()))
        triangle1.set_height(float(input()))

        # Read and set base and height for triangle2
        triangle2.set_base(float(input()))
        triangle2.set_height(float(input()))

        print("Triangle with smaller area:")

        # Determine smaller triangle and output its info
        if triangle1.get_area() < triangle2.get_area():
            triangle1.print_info()
        else:
            triangle2.print_info()
lab_9_14()
# Out:
# '## 9.14 LAB: Triangle area comparison (classes)\n\n### LAB ACTIVITY: LAB: Triangle area comparison (classes)\n\nGiven class `Triangle`, complete the program to read and set the base and height of triangle1 and triangle2, determine which triangle\'s area is smaller, and output the smaller triangle\'s info, making use of `Triangle`\'s relevant methods.\nEx: If the input is:\n\n```\n3.0\n4.0\n4.0\n5.0\n```\nwhere 3.0 is triangle1\'s base, 4.0 is triangle1\'s height, 4.0 is triangle2\'s base, and 5.0 is triangle2\'s height, the output is:\n\n```\nTriangle with smaller area:\nBase: 3.00\nHeight: 4.00\nArea: 6.00\n```\n\n**Test Cases:**\n| # | Input | Expected Output | Points |\n|---|-------|-----------------|--------|\n| 1 | `3.0\n4.0\n4.0\n5.0` | `Triangle with smaller area:\nBase: 3.00\nHeight: 4.00\nArea: 6.00` | 2 |\n| 2 | `12.0\n16.0\n10.0\n18.0` | `Triangle with smaller area:\nBase: 10.00\nHeight: 18.00\nArea: 90.00` | 2 |\n| 3 | `6.5\n2.0\n3.0\n4.5` | `Triangle with smaller area:\
# ...

# %% [markdown]
# ## 9.15 LAB: Winning team (classes)
#
# ### LAB ACTIVITY: LAB: Winning team (classes)
#
# Complete the Team class implementation. For the instance method get_win_percentage(), the formula is:
# `wins / (wins + losses)`. *Note: Use floating-point division.*
# For instance method print_standing(), output the win percentage of the team with two digits after the decimal point and whether the team has a winning or losing average. A team has a winning average if the win percentage is 0.5 or greater.
# Ex: If the input is:
#
# ```
# Ravens
# 13
# 3
# ```
# where Ravens is the team's name, 13 is the number of team wins, and 3 is the number of team losses, the output is:
#
# ```
# Win percentage: 0.81
# Congratulations, Team Ravens has a winning average!
# ```
# Ex: If the input is:
#
# ```
# Angels
# 80
# 82
# ```
# the output is:
#
# ```
# Win percentage: 0.49
# Team Angels has a losing average.
# ```
#
# **Test Cases:**
# | # | Input | Expected Output | Points |
# |---|-------|-----------------|--------|
# | 1 | `Ravens\n13\n3\n` | `Win percentage: 0.81\nCongratulations, Team Ravens has a winning average!` | 2 |
# | 2 | `Angels\n80\n120\n` | `Win percentage: 0.40\nTeam Angels has a losing average.` | 2 |
# | 3 | `(none)` | `` | 2 |
# | 4 | `(none)` | `` | 2 |
# | 5 | `(none)` | `` | 2 |
# *Total: 10 points*

# %%
'''## 9.15 LAB: Winning team (classes)

### LAB ACTIVITY: LAB: Winning team (classes)

Complete the Team class implementation. For the instance method get_win_percentage(), the formula is:
`wins / (wins + losses)`. *Note: Use floating-point division.*
For instance method print_standing(), output the win percentage of the team with two digits after the decimal point and whether the team has a winning or losing average. A team has a winning average if the win percentage is 0.5 or greater.
Ex: If the input is:

```
Ravens
13
3
```
where Ravens is the team's name, 13 is the number of team wins, and 3 is the number of team losses, the output is:

```
Win percentage: 0.81
Congratulations, Team Ravens has a winning average!
```
Ex: If the input is:

```
Angels
80
82
```
the output is:

```
Win percentage: 0.49
Team Angels has a losing average.
```

**Test Cases:**
| # | Input | Expected Output | Points |
|---|-------|-----------------|--------|
| 1 | `Ravens\n13\n3\n` | `Win percentage: 0.81\nCongratulations, Team Ravens has a winning average!` | 2 |
| 2 | `Angels\n80\n120\n` | `Win percentage: 0.40\nTeam Angels has a losing average.` | 2 |
| 3 | `(none)` | `` | 2 |
| 4 | `(none)` | `` | 2 |
| 5 | `(none)` | `` | 2 |
*Total: 10 points*
```python
class Team:

    def __init__(self):
        self.name = "none"
        self.wins = 0
        self.losses = 0

    # TODO: Define get_win_percentage()

    # TODO: Define print_standing()


if __name__ == "__main__":
    team = Team()

    user_name = input()
    user_wins = int(input())
    user_losses = int(input())

    team.name = user_name
    team.wins = user_wins
    team.losses = user_losses

    team.print_standing()

```
'''
def lab_9_15():
    setin("Ravens","13","3")  # Example usage, you can change the input value as needed
    class Team:

        def __init__(self):
            self.name = "none"
            self.wins = 0
            self.losses = 0

        # Define get_win_percentage()
        def get_win_percentage(self):
            return self.wins / (self.wins + self.losses)

        # Define print_standing()
        def print_standing(self):
            win_percentage = self.get_win_percentage()
            print(f"Win percentage: {win_percentage:.2f}")
            if win_percentage >= 0.5:
                print(f"Congratulations, Team {self.name} has a winning average!")
            else:
                print(f"Team {self.name} has a losing average.")


    if __name__ == "__main__":
        team = Team()

        user_name = input()
        user_wins = int(input())
        user_losses = int(input())

        team.name = user_name
        team.wins = user_wins
        team.losses = user_losses

        team.print_standing()
lab_9_15()
# Out:
# '## 9.15 LAB: Winning team (classes)\n\n### LAB ACTIVITY: LAB: Winning team (classes)\n\nComplete the Team class implementation. For the instance method get_win_percentage(), the formula is:\n`wins / (wins + losses)`. *Note: Use floating-point division.*\nFor instance method print_standing(), output the win percentage of the team with two digits after the decimal point and whether the team has a winning or losing average. A team has a winning average if the win percentage is 0.5 or greater.\nEx: If the input is:\n\n```\nRavens\n13\n3\n```\nwhere Ravens is the team\'s name, 13 is the number of team wins, and 3 is the number of team losses, the output is:\n\n```\nWin percentage: 0.81\nCongratulations, Team Ravens has a winning average!\n```\nEx: If the input is:\n\n```\nAngels\n80\n82\n```\nthe output is:\n\n```\nWin percentage: 0.49\nTeam Angels has a losing average.\n```\n\n**Test Cases:**\n| # | Input | Expected Output | Points |\n|---|-------|-----------------|--------|\n| 1 | `Rav
# ...

# %%
'''setin("Ravens","13","3")  # Example usage, you can change the input value as needed
class Team:

    def __init__(self):
        self.name = "none"
        self.wins = 0
        self.losses = 0

    # TODO: Define get_win_percentage()
    def get_win_percentage(self):
        if self.wins + self.losses > 0:
            return self.wins / (self.wins + self.losses)
        else:
            return 0.0

    # TODO: Define print_standing()
    def print_standing(self):
        win_percentage = self.get_win_percentage()
        print(f"Win percentage: {win_percentage:.2f}")
        if win_percentage >= 0.5:
            print(f"Congratulations, Team {self.name} has a winning average!")
        else:
            print(f"Team {self.name} has a losing average.")


if __name__ == "__main__":
    team = Team()

    user_name = input()
    user_wins = int(input())
    user_losses = int(input())

    team.name = user_name
    team.wins = user_wins
    team.losses = user_losses

    team.print_standing()
'''
# Out:
# 'setin("Ravens","13","3")  # Example usage, you can change the input value as needed\nclass Team:\n\n    def __init__(self):\n        self.name = "none"\n        self.wins = 0\n        self.losses = 0\n\n    # TODO: Define get_win_percentage()\n    def get_win_percentage(self):\n        if self.wins + self.losses > 0:\n            return self.wins / (self.wins + self.losses)\n        else:\n            return 0.0\n\n    # TODO: Define print_standing()\n    def print_standing(self):\n        win_percentage = self.get_win_percentage()\n        print(f"Win percentage: {win_percentage:.2f}")\n        if win_percentage >= 0.5:\n            print(f"Congratulations, Team {self.name} has a winning average!")\n        else:\n            print(f"Team {self.name} has a losing average.")\n\n\nif __name__ == "__main__":\n    team = Team()\n\n    user_name = input()\n    user_wins = int(input())\n    user_losses = int(input())\n\n    team.name = user_name\n    team.wins = user_wins\n    team.losse
# ...

# %%
#its the last one, are you ready?
# yes, let's do it!

# %% [markdown]
# ## 9.16 LAB: Vending machine
#
# ### LAB ACTIVITY: LAB: Vending machine
#
# Given three integers as user inputs that represent the number of bottles of drinks to purchase, to restock, and to purchase afterward, create a VendingMachine object that performs the following operations:
# - Purchase the first input number of bottles of drinks- Restock the second input number of bottles of drinks- Purchase the last input number of bottles of drinks- Report inventoryA VendingMachine's initial inventory is 20 bottles of drinks.
# Ex: If the input is:
#
# ```
# 5
# 2
# 7
# ```
# the output is:
#
# ```
# Inventory: 10 bottles
# ```
#
# **Test Cases:**
# | # | Input | Expected Output | Points |
# |---|-------|-----------------|--------|
# | 1 | `5\n2\n7\n` | `Inventory: 10 bottles` | 4 |
# | 2 | `20\n0\n0\n` | `Inventory: 0 bottles` | 2 |
# | 3 | `0\n5\n10\n` | `Inventory: 15 bottles` | 2 |
# | 4 | `0\n0\n0\n` | `Inventory: 20 bottles` | 2 |
# *Total: 10 points*
#
# ```python
# class VendingMachine:
#
#     def __init__(self):
#         self.bottles = 20
#
#     def purchase(self, amount):
#         self.bottles = self.bottles - amount
#
#     def restock(self, amount):
#         self.bottles = self.bottles + amount
#
#     def get_inventory(self):
#         return self.bottles
#
#     def report(self):
#         print(f"Inventory: {self.bottles} bottles")
#
#
# if __name__ == "__main__":
#     # TODO: Create VendingMachine object
#     # TODO: Purchase first input number of bottles of drinks
#     # TODO: Restock second input number of bottles of drinks
#     # TODO: Purchase last input number of bottles of drinks
#     # TODO: Report inventory
# ```

# %%
'''## 9.16 LAB: Vending machine

### LAB ACTIVITY: LAB: Vending machine

Given three integers as user inputs that represent the number of bottles of drinks to purchase, to restock, and to purchase afterward, create a VendingMachine object that performs the following operations:
- Purchase the first input number of bottles of drinks- Restock the second input number of bottles of drinks- Purchase the last input number of bottles of drinks- Report inventoryA VendingMachine's initial inventory is 20 bottles of drinks.
Ex: If the input is:

```
5
2
7
```
the output is:

```
Inventory: 10 bottles
```

**Test Cases:**
| # | Input | Expected Output | Points |
|---|-------|-----------------|--------|
| 1 | `5\n2\n7\n` | `Inventory: 10 bottles` | 4 |
| 2 | `20\n0\n0\n` | `Inventory: 0 bottles` | 2 |
| 3 | `0\n5\n10\n` | `Inventory: 15 bottles` | 2 |
| 4 | `0\n0\n0\n` | `Inventory: 20 bottles` | 2 |
*Total: 10 points*

```python
class VendingMachine:

    def __init__(self):
        self.bottles = 20

    def purchase(self, amount):
        self.bottles = self.bottles - amount

    def restock(self, amount):
        self.bottles = self.bottles + amount

    def get_inventory(self):
        return self.bottles

    def report(self):
        print(f"Inventory: {self.bottles} bottles")


if __name__ == "__main__":
    # TODO: Create VendingMachine object
    # TODO: Purchase first input number of bottles of drinks
    # TODO: Restock second input number of bottles of drinks
    # TODO: Purchase last input number of bottles of drinks
    # TODO: Report inventory
```
'''
def lab_9_16():
    setin("5","2","7")  # Example usage, you can change the input value as needed
    class VendingMachine:

        def __init__(self):
            self.bottles = 20

        def purchase(self, amount):
            self.bottles = self.bottles - amount

        def restock(self, amount):
            self.bottles = self.bottles + amount

        def get_inventory(self):
            return self.bottles

        def report(self):
            print(f"Inventory: {self.bottles} bottles")


    if __name__ == "__main__":
        # Create VendingMachine object
        vending_machine = VendingMachine()

        # Purchase first input number of bottles of drinks
        vending_machine.purchase(int(input()))

        # Restock second input number of bottles of drinks
        vending_machine.restock(int(input()))

        # Purchase last input number of bottles of drinks
        vending_machine.purchase(int(input()))

        # Report inventory
        vending_machine.report()
lab_9_16()
# Out:
# '## 9.16 LAB: Vending machine\n\n### LAB ACTIVITY: LAB: Vending machine\n\nGiven three integers as user inputs that represent the number of bottles of drinks to purchase, to restock, and to purchase afterward, create a VendingMachine object that performs the following operations:\n- Purchase the first input number of bottles of drinks- Restock the second input number of bottles of drinks- Purchase the last input number of bottles of drinks- Report inventoryA VendingMachine\'s initial inventory is 20 bottles of drinks.\nEx: If the input is:\n\n```\n5\n2\n7\n```\nthe output is:\n\n```\nInventory: 10 bottles\n```\n\n**Test Cases:**\n| # | Input | Expected Output | Points |\n|---|-------|-----------------|--------|\n| 1 | `5\n2\n7\n` | `Inventory: 10 bottles` | 4 |\n| 2 | `20\n0\n0\n` | `Inventory: 0 bottles` | 2 |\n| 3 | `0\n5\n10\n` | `Inventory: 15 bottles` | 2 |\n| 4 | `0\n0\n0\n` | `Inventory: 20 bottles` | 2 |\n*Total: 10 points*\n\n```python\nclass VendingMachine:\n\n    def __ini
# ...

# %%
setin("5","2","7")  # Example usage, you can change the input value as needed
class VendingMachine:

    def __init__(self):
        self.bottles = 20

    def purchase(self, amount):
        self.bottles = self.bottles - amount

    def restock(self, amount):
        self.bottles = self.bottles + amount

    def get_inventory(self):
        return self.bottles

    def report(self):
        print(f"Inventory: {self.bottles} bottles")


if __name__ == "__main__":
    # Create VendingMachine object
    vending_machine = VendingMachine()

    # Purchase first input number of bottles of drinks
    vending_machine.purchase(int(input()))

    # Restock second input number of bottles of drinks
    vending_machine.restock(int(input()))

    # Purchase last input number of bottles of drinks
    vending_machine.purchase(int(input()))

    # Report inventory
    vending_machine.report()
# Out:
# 5
# 2
# 7
# Inventory: 10 bottles

# %%
#my lazie version
setin("5","2","7")  # Example usage, you can change the input value as needed
class VendingMachine:

    def __init__(self):
        self.bottles = 20

    def purchase(self, amount):
        self.bottles = self.bottles - amount

    def restock(self, amount):
        self.bottles = self.bottles + amount

    def get_inventory(self):
        return self.bottles

    def report(self):
        print(f"Inventory: {self.bottles} bottles")


if __name__ == "__main__":
    # TODO: Create VendingMachine object
    # TODO: Purchase first input number of bottles of drinks
    # TODO: Restock second input number of bottles of drinks
    # TODO: Purchase last input number of bottles of drinks
    # TODO: Report inventory
    vending_machine=VendingMachine()
    def o():
        return int(input())
    vending_machine.purchase(o())
    vending_machine.restock(o())
    vending_machine.purchase(o())
    vending_machine.report()
# Out:
# 5
# 2
# 7
# Inventory: 10 bottles

# %%
#this is a big boy,thre was a c9 seond part, should i use a c9 labs part? or continue doing it on hre?
# You can continue doing it here if you prefer, or you can use a C9 Labs part if you want to keep your work organized. It's up to you!
#thaanks!
