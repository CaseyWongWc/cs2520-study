# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
"""
participation activity
8.1.2: List basics.
1)
A program can modify the elements of an existing list.
2)
The size of a list is determined when the list is created and cannot change.
3)
All elements of a list must have the same type.

"""
#1) True

#2) False

#3) False
[1,"2",3.0,[4,5],(6,7),{8:9}]
# Out:
# '\nparticipation activity\n8.1.2: List basics.\n1)\nA program can modify the elements of an existing list.\n2)\nThe size of a list is determined when the list is created and cannot change.\n3)\nAll elements of a list must have the same type.\n\n'
# [1, '2', 3.0, [4, 5], (6, 7), {8: 9}]

# %%
"""Try 8.1.1: List's ith element can be directly accessed using [i]: Oldest people program.

Full screen
Consider the following program that allows a user to print the age of the Nth oldest known person to have ever lived. Note: The ages are in a list sorted from oldest to youngest.

1. Modify the program to print the correct ordinal number ("1st", "2nd", "3rd", "4th", or "5th") instead of "1th", "2th", "3th", "4th", or "5th".
2. For the oldest person, remove the ordinal number (1st) from the print statement to say, "The oldest person lived 122 years".

Reminder: List indices begin at 0, not 1, thus the print statement uses oldest_people[nth_person - 1], to access the nth_person element (element 1 at index 0, element 2 at index 1, etc.).
"""
oldest_people = [122, 119, 117, 117, 116]  # Source: Wikipedia.org

nth_person = int(input("Enter N (1-5): "))

if (nth_person >= 1) and (nth_person <= 5):
    if nth_person == 1:
        print(f"The oldest person lived {oldest_people[nth_person - 1]} years.")
    else:
        # Determine the correct ordinal suffix
        if nth_person == 2:
            ordinal = "2nd"
        elif nth_person == 3:
            ordinal = "3rd"
        else:
            ordinal = f"{nth_person}th"
        print(f"The {ordinal} oldest person lived {oldest_people[nth_person - 1]} years.")

# %%
"""participation activity
8.1.3: List indices.
Given the following code, what is the output of each code segment?
animals = ["cat", "dog", "bird", "raptor"]
print(animals[0])
1)
print(animals[0])

Check

Show answer
2)
print(animals[2])

Check

Show answer
3)
print(animals[0 + 1])

Check

Show answer
4)

i = 3
print(animals[i])

Check

Show answer

"""

animals = ["cat", "dog", "bird", "raptor"]
#1)
print(animals[0])  # Output: cat
#2)
print(animals[2])  # Output: bird
#3)
print(animals[0 + 1])  # Output: dog
#4)
i = 3
print(animals[i])  # Output: raptor

#?
animals = ["cat", "dog", "bird", "raptor"]
animals[0+1]==animals[1]
# Out:
# 'participation activity\n8.1.3: List indices.\nGiven the following code, what is the output of each code segment?\nanimals = ["cat", "dog", "bird", "raptor"]\nprint(animals[0])\n1)\nprint(animals[0])\n\nCheck\n\nShow answer\n2)\nprint(animals[2])\n\nCheck\n\nShow answer\n3)\nprint(animals[0 + 1])\n\nCheck\n\nShow answer\n4)\n\ni = 3\nprint(animals[i])\n\nCheck\n\nShow answer\n\n'
# cat
# bird
# dog
# raptor
# True
# 'bird'

# %%
"""Table 8.1.1: Some common list operations.
Operation	Description	Example code	Example output
my_list = [1, 2, 3]	Creates a list.	
my_list = [1, 2, 3]
print(my_list)
[1, 2, 3]
list(iter)	Creates a list.	
my_list = list("123")
print(my_list)
['1', '2', '3']
my_list[index]	Gets an element from a list.	
my_list = [1, 2, 3]
print(my_list[1])
2
my_list[start:end]	Gets a new list containing some of another list's elements.	
my_list = [1, 2, 3]
print(my_list[1:3])
[2, 3]
my_list1 + my_list2	Gets a new list with elements of my_list2 added to end of my_list1.	
my_list = [1, 2] + [3] 
print(my_list)
[1, 2, 3]
my_list[i] = x	Changes the value of the element at index i in-place.	
my_list = [1, 2, 3]
my_list[2] = 9 
print(my_list)
[1, 2, 9]
del my_list[i]	Deletes the element from index i from a list.	
my_list = [1, 2, 3]
del my_list[1]
print(my_list)
[1, 3]"""

my_list = [1, 2, 3]
print(my_list[:])  # Output: [1, 2, 3]
list("123")  # Output: ['1', '2', '3']
my_list[1]  # Output: 2
my_list[1:3]  # Output: [2, 3]
my_list = [1, 2] + [3]
print(my_list)  # Output: [1, 2, 3]
my_list[2] = 9
print(my_list)  # Output: [1, 2, 9]
del my_list[1]
print(my_list)  # Output: [1, 9]
# Out:
# 'Table 8.1.1: Some common list operations.\nOperation\tDescription\tExample code\tExample output\nmy_list = [1, 2, 3]\tCreates a list.\t\nmy_list = [1, 2, 3]\nprint(my_list)\n[1, 2, 3]\nlist(iter)\tCreates a list.\t\nmy_list = list("123")\nprint(my_list)\n[\'1\', \'2\', \'3\']\nmy_list[index]\tGets an element from a list.\t\nmy_list = [1, 2, 3]\nprint(my_list[1])\n2\nmy_list[start:end]\tGets a new list containing some of another list\'s elements.\t\nmy_list = [1, 2, 3]\nprint(my_list[1:3])\n[2, 3]\nmy_list1 + my_list2\tGets a new list with elements of my_list2 added to end of my_list1.\t\nmy_list = [1, 2] + [3] \nprint(my_list)\n[1, 2, 3]\nmy_list[i] = x\tChanges the value of the element at index i in-place.\t\nmy_list = [1, 2, 3]\nmy_list[2] = 9 \nprint(my_list)\n[1, 2, 9]\ndel my_list[i]\tDeletes the element from index i from a list.\t\nmy_list = [1, 2, 3]\ndel my_list[1]\nprint(my_list)\n[1, 3]'
# [1, 2, 3]
# ['1', '2', '3']
# 2
# [2, 3]
# [1, 2, 3]
# [1, 2, 9]
# [1, 9]

# %%
"""participation activity
8.1.5: Common list operations.
1)
Which statement deletes the third element from a list called my_list?
2)
Which operation does not perform an in-place modification?
3)
Which statement creates a copy of a list?

"""
#1) del my_list[2]
#2) my_list1 + my_list2
#3) my_list[:]
my_list = [1, 2, 3]
my_list1 = [4, 5, 6]
my_list2 = [7, 8, 9]
del my_list[2]
print(my_list)  # Output: [1, 2]
my_list3 = my_list1 + my_list2
# Out:
# 'participation activity\n8.1.5: Common list operations.\n1)\nWhich statement deletes the third element from a list called my_list?\n2)\nWhich operation does not perform an in-place modification?\n3)\nWhich statement creates a copy of a list?\n\n'
# [1, 2]
